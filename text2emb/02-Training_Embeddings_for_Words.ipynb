# %% [markdown]
# # Training Embeddings for Words
#
# This tutorial shows how to learn **word embeddings** from co-occurrence statistics.
#
# We use a simple NN architecture, a long with the conditional cost function used by the [Swivel](https://arxiv.org/pdf/1602.02215.pdf) algorithm.
#
# The learnt embeddings are then extracted from the model and saved as TSV file.
#
# The following are the steps of this tutorial:
#
#
# 1. Define input data metadata
# 2. Implement data input function
# 3. Create feature columns
# 4. Create a custome estimator
# 5. Define the train and evaluate experiment
# 6. Set the experiment parameters
# 7. Run the experiment
# 8. Extract the learnt **word embeddings** from the model
#
# <a href="https://colab.research.google.com/github/ksalama/data2cooc2emb2ann/blob/master/text2emb/02-Training_Embeddings_for_Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Setup

# %%
import os
import math
import numpy as np
import tensorflow as tf
from datetime import datetime

# %%
WORKSPACE = './workspace'
COOC_DIR = '{}/cooc'.format(WORKSPACE)
MODELS_DIR = '{}/models'.format(WORKSPACE)
SEED = 19831060

# %%
# !echo "Files:"
# !ls {COOC_DIR}/
# !echo ""

# !echo "info:"
# !head {COOC_DIR}/info.log
# !echo ""

# !echo "Vocab count"
# !wc -l  {COOC_DIR}/vocab.txt
# !echo ""
# Out:
# Files:
# cooc-00000-of-00016.tfrecords  cooc-00009-of-00016.tfrecords
# cooc-00001-of-00016.tfrecords  cooc-00010-of-00016.tfrecords
# cooc-00002-of-00016.tfrecords  cooc-00011-of-00016.tfrecords
# cooc-00003-of-00016.tfrecords  cooc-00012-of-00016.tfrecords
# cooc-00004-of-00016.tfrecords  cooc-00013-of-00016.tfrecords
# cooc-00005-of-00016.tfrecords  cooc-00014-of-00016.tfrecords
# cooc-00006-of-00016.tfrecords  cooc-00015-of-00016.tfrecords
# cooc-00007-of-00016.tfrecords  info.log
# cooc-00008-of-00016.tfrecords  vocab.txt
#
# info:
# min: -5.136295533922434
# P: 905289
# max: 9.184321336159051
# N: 3821288
#
# Vocab count
# 4632 ./workspace/cooc/vocab.txt

# %% [markdown]
# ## 1.  Metadata

# %%
FEATURES_SCHEMA = {
    'item1': tf.FixedLenFeature(dtype=tf.string, shape=()),
    'item2': tf.FixedLenFeature(dtype=tf.string, shape=()),
    'score': tf.FixedLenFeature(dtype=tf.float32, shape=()),
    'weight': tf.FixedLenFeature(dtype=tf.float32, shape=()),
    'type': tf.FixedLenFeature(dtype=tf.string, shape=())
}

WEIGHT_FEATURE_NAME = 'weight'
TARGET_FEATURE_NAME = 'score'

# %% [markdown]
# ## 2.  Data Input Function

# %%
def make_input_fn(
    file_pattern, batch_size=128, num_epochs=1, shuffle=False):

    def _input_fn():
        dataset = tf.data.experimental.make_batched_features_dataset(
            file_pattern,
            batch_size,
            features=FEATURES_SCHEMA,
            label_key=TARGET_FEATURE_NAME,
            reader=tf.data.TFRecordDataset,
            shuffle_buffer_size=batch_size * 2,
            num_epochs=num_epochs,
            shuffle=shuffle,
            sloppy_ordering=True,
            drop_final_batch=False
        )
        return dataset
    
    return _input_fn

# %% [markdown]
# ## 3. Feature Columns

# %%
def create_feature_columns(embedding_size, vocab_file):

    feature_columns = tf.feature_column.shared_embedding_columns(
        [
            tf.feature_column.categorical_column_with_vocabulary_file(
                key='item1', 
                vocabulary_file=vocab_file
            ),
            tf.feature_column.categorical_column_with_vocabulary_file(
                key='item2', 
                vocabulary_file=vocab_file
            )
        ],
        embedding_size
    )
        
    return feature_columns

# %% [markdown]
# ## 4.  Custom Estimator

# %%
def compute_loss(labels, predictions, weights, types):
    
    errors = predictions - labels
    
    positives = tf.cast(tf.equal(types, 'P'), tf.float32)
    negatives = 1 - positives
        
    p_loss = positives * (0.5 * weights * tf.math.square(errors))
    n_loss = negatives * (1.0 * weights * tf.math.softplus(errors))
    
    loss = p_loss + n_loss

    return tf.reduce_mean(loss)
   

def model_fn(features, labels, mode, params):
    
    feature_columns = create_feature_columns(
        params.embedding_size, params.vocab_file)
   
    item1_layer = tf.feature_column.input_layer(
        features={'item1': features['item1']}, feature_columns=[feature_columns[0]])

    item2_layer = tf.feature_column.input_layer(
        features={'item2': features['item2']}, feature_columns=[feature_columns[1]])

    predictions = tf.squeeze(
        tf.keras.layers.Dot(axes=1)([item1_layer, item2_layer]))
    
    loss = compute_loss(
        labels=labels, 
        predictions=predictions, 
        weights=features[WEIGHT_FEATURE_NAME], 
        types=features['type']
    )
    
    train_op=tf.train.AdamOptimizer(params.learning_rate).minimize(
        loss=loss, 
        global_step=tf.train.get_global_step()
    )
    
    return tf.estimator.EstimatorSpec(
        mode=mode,
        loss=loss,
        train_op=train_op
    )
    

def create_estimator(params, run_config):
    
    estimator = tf.estimator.Estimator(
        model_fn,
        params=params,
        config=run_config
    )
    
    return estimator

# %% [markdown]
# ## 5. Experiment

# %%
def run_experiment(estimator, params):
    
    train_data_files = params.train_data_files
    eval_data_files = params.eval_data_files
    
    # TrainSpec ####################################
    
    train_spec = tf.estimator.TrainSpec(
            input_fn=make_input_fn(
            train_data_files,
            batch_size=params.batch_size,
            num_epochs=None,
            shuffle=True
        ),
        max_steps=params.train_steps
    )

    # EvalSpec ####################################

    eval_spec = tf.estimator.EvalSpec(
        input_fn=make_input_fn(
            eval_data_files,
            batch_size=1#params.batch_size,
        ),
        steps=params.eval_steps,
        start_delay_secs=0,
        throttle_secs=params.eval_throttle_secs
    )
    ###############################################
    
    time_start = datetime.utcnow() 
    print("Experiment started...")
    print(".......................................") 

    tf.estimator.train_and_evaluate(
        estimator=estimator,
        train_spec=train_spec, 
        eval_spec=eval_spec
    )
    
    time_end = datetime.utcnow() 
    print(".......................................")
    print("Experiment finished.")

# %% [markdown]
# ## 6. Parameters

# %%
MODEL_NAME = 'cooc2emb-07'
model_dir = os.path.join(MODELS_DIR, MODEL_NAME)
info_file = os.path.join(COOC_DIR, 'info.log')

info_map = {}

if os.path.exists(info_file):
    with open(info_file) as f:
        for line in f.readlines():
            key, value = line.split(":")
            info_map[key] = float(value)
    
class HParams():
    pass


batch_size = 128 
learning_rate = 1.0e-04
multiplier = 8

dataset_size = int(info_map['P'] + info_map['N'])
steps_per_epoch = dataset_size / (batch_size * multiplier)
num_epochs = 10
num_steps = int(num_epochs * steps_per_epoch)

print("Dataset size: {}".format(dataset_size))
print("Batch size: {}".format(batch_size))
print("Steps per epoch: {}".format(int(steps_per_epoch)))
print("Epochs: {}".format(num_epochs))
print("Training steps: {}".format(num_steps))

params  = HParams()
params.train_data_files = "{}/cooc-*.tfrecords".format(COOC_DIR)
params.eval_data_files = "{}/cooc-*.tfrecords".format(COOC_DIR)
params.vocab_file = os.path.join(COOC_DIR,'vocab.txt')
params.embedding_size = 64
params.batch_size = batch_size * multiplier
params.train_steps = num_steps
params.learning_rate = learning_rate * multiplier
params.lr_first_cycle = steps_per_epoch // 2
params.eval_steps = 1
params.eval_throttle_secs = 0

print(vars(params))

run_config = tf.estimator.RunConfig(
    tf_random_seed=SEED,
    save_checkpoints_steps=steps_per_epoch // 5,
    keep_checkpoint_max=3,
    model_dir=model_dir,
)

print("Experiment parameters are set.")
# Out:
# Dataset size: 4726577
# Batch size: 128
# Steps per epoch: 4615
# Epochs: 10
# Training steps: 46157
# {'eval_data_files': './workspace/cooc/cooc-*.tfrecords', 'batch_size': 1024, 'train_data_files': './workspace/cooc/cooc-*.tfrecords', 'vocab_file': './workspace/cooc/vocab.txt', 'learning_rate': 0.0008, 'eval_steps': 1, 'eval_throttle_secs': 0, 'embedding_size': 64, 'lr_first_cycle': 2307.0, 'train_steps': 46157}
# Experiment parameters are set.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e: print(e)
else: print('No GPUs detected')
# Out:
# 1 Physical GPUs, 1 Logical GPU

# %% [markdown]
# ## 7. Run

# %%
tf.logging.set_verbosity(tf.logging.INFO)

if tf.gfile.Exists(run_config.model_dir):
    print("Removing previous artefacts...")
    tf.gfile.DeleteRecursively(run_config.model_dir)
            
estimator = create_estimator(params, run_config)
# %time run_experiment(estimator, params)
# Out:
# Removing previous artefacts...
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': None, '_keep_checkpoint_every_n_hours': 10000, '_global_id_in_cluster': 0, '_device_fn': None, '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_experimental_distribute': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 3, '_is_chief': True, '_task_id': 0, '_protocol': None, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_save_checkpoints_steps': 923.0, '_tf_random_seed': 19831060, '_train_distribute': None, '_evaluation_master': '', '_model_dir': './workspace/models/cooc2emb-07', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fd611fb5518>, '_master': '', '_task_type': 'worker', '_num_worker_replicas': 1, '_service': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# }
# Experiment started...
# .......................................
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 923.0 or save_checkpoints_secs None.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/data/util/random_seed.py:58: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/data/experimental/ops/readers.py:835: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/data/experimental/ops/readers.py:212: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column_v2.py:1049: VocabularyFileCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column.py:2548: VocabularyFileCategoricalColumn._get_sparse_tensors (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/feature_column/feature_column.py:2115: VocabularyFileCategoricalColumn._transform_feature (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:loss = 0.35395363, step = 0
# INFO:tensorflow:global_step/sec: 106.374
# INFO:tensorflow:loss = 0.3397051, step = 100 (0.941 sec)
# INFO:tensorflow:global_step/sec: 116.86
# INFO:tensorflow:loss = 0.2783463, step = 200 (0.856 sec)
# INFO:tensorflow:global_step/sec: 119.014
# INFO:tensorflow:loss = 0.40549797, step = 300 (0.840 sec)
# INFO:tensorflow:global_step/sec: 123.784
# INFO:tensorflow:loss = 0.2718066, step = 400 (0.808 sec)
# INFO:tensorflow:global_step/sec: 115.1
# INFO:tensorflow:loss = 0.34899965, step = 500 (0.869 sec)
# INFO:tensorflow:global_step/sec: 115.736
# INFO:tensorflow:loss = 0.30985087, step = 600 (0.864 sec)
# INFO:tensorflow:global_step/sec: 112.356
# INFO:tensorflow:loss = 0.3009722, step = 700 (0.890 sec)
# INFO:tensorflow:global_step/sec: 116.564
# INFO:tensorflow:loss = 0.32724765, step = 800 (0.858 sec)
# INFO:tensorflow:global_step/sec: 115.268
# INFO:tensorflow:loss = 0.3288333, step = 900 (0.867 sec)
# INFO:tensorflow:Saving checkpoints for 923 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:36:31Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-923
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:36:31
# INFO:tensorflow:Saving dict for global step 923: global_step = 923, loss = 0.022600226
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 923: ./workspace/models/cooc2emb-07/model.ckpt-923
# INFO:tensorflow:global_step/sec: 57.3605
# INFO:tensorflow:loss = 0.25036696, step = 1000 (1.743 sec)
# INFO:tensorflow:global_step/sec: 113.418
# INFO:tensorflow:loss = 0.31506413, step = 1100 (0.882 sec)
# INFO:tensorflow:global_step/sec: 115.216
# INFO:tensorflow:loss = 0.32524765, step = 1200 (0.868 sec)
# INFO:tensorflow:global_step/sec: 112.143
# INFO:tensorflow:loss = 0.53405654, step = 1300 (0.892 sec)
# INFO:tensorflow:global_step/sec: 117.002
# INFO:tensorflow:loss = 0.29150152, step = 1400 (0.855 sec)
# INFO:tensorflow:global_step/sec: 112.807
# INFO:tensorflow:loss = 0.24030356, step = 1500 (0.887 sec)
# INFO:tensorflow:global_step/sec: 118.677
# INFO:tensorflow:loss = 0.3087679, step = 1600 (0.843 sec)
# INFO:tensorflow:global_step/sec: 119.463
# INFO:tensorflow:loss = 0.28285557, step = 1700 (0.837 sec)
# INFO:tensorflow:global_step/sec: 111.252
# INFO:tensorflow:loss = 0.32710594, step = 1800 (0.899 sec)
# INFO:tensorflow:Saving checkpoints for 1846 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:36:39Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-1846
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:36:40
# INFO:tensorflow:Saving dict for global step 1846: global_step = 1846, loss = 0.023780018
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1846: ./workspace/models/cooc2emb-07/model.ckpt-1846
# INFO:tensorflow:global_step/sec: 59.5889
# INFO:tensorflow:loss = 0.39131737, step = 1900 (1.678 sec)
# INFO:tensorflow:global_step/sec: 119.171
# INFO:tensorflow:loss = 0.32124045, step = 2000 (0.839 sec)
# INFO:tensorflow:global_step/sec: 115.894
# INFO:tensorflow:loss = 0.41662565, step = 2100 (0.863 sec)
# INFO:tensorflow:global_step/sec: 115.245
# INFO:tensorflow:loss = 0.27733466, step = 2200 (0.868 sec)
# INFO:tensorflow:global_step/sec: 120.077
# INFO:tensorflow:loss = 0.25291413, step = 2300 (0.833 sec)
# INFO:tensorflow:global_step/sec: 117.2
# INFO:tensorflow:loss = 0.24613908, step = 2400 (0.853 sec)
# INFO:tensorflow:global_step/sec: 117.983
# INFO:tensorflow:loss = 0.34265468, step = 2500 (0.848 sec)
# INFO:tensorflow:global_step/sec: 118.93
# INFO:tensorflow:loss = 0.3049824, step = 2600 (0.841 sec)
# INFO:tensorflow:global_step/sec: 116.874
# INFO:tensorflow:loss = 0.28340885, step = 2700 (0.856 sec)
# INFO:tensorflow:Saving checkpoints for 2769 into ./workspace/models/cooc2emb-07/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:36:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-2769
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:36:48
# INFO:tensorflow:Saving dict for global step 2769: global_step = 2769, loss = 0.024153618
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2769: ./workspace/models/cooc2emb-07/model.ckpt-2769
# INFO:tensorflow:global_step/sec: 67.2181
# INFO:tensorflow:loss = 0.24659264, step = 2800 (1.488 sec)
# INFO:tensorflow:global_step/sec: 119.406
# INFO:tensorflow:loss = 0.3383647, step = 2900 (0.837 sec)
# INFO:tensorflow:global_step/sec: 114.465
# INFO:tensorflow:loss = 0.3676742, step = 3000 (0.874 sec)
# INFO:tensorflow:global_step/sec: 114.948
# INFO:tensorflow:loss = 0.29986212, step = 3100 (0.870 sec)
# INFO:tensorflow:global_step/sec: 111.46
# INFO:tensorflow:loss = 0.25760657, step = 3200 (0.897 sec)
# INFO:tensorflow:global_step/sec: 117.487
# INFO:tensorflow:loss = 0.34776685, step = 3300 (0.851 sec)
# INFO:tensorflow:global_step/sec: 116.771
# INFO:tensorflow:loss = 0.3263986, step = 3400 (0.856 sec)
# INFO:tensorflow:global_step/sec: 112.488
# INFO:tensorflow:loss = 0.27876598, step = 3500 (0.889 sec)
# INFO:tensorflow:global_step/sec: 117.707
# INFO:tensorflow:loss = 0.3154564, step = 3600 (0.850 sec)
# INFO:tensorflow:Saving checkpoints for 3692 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:36:57Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-3692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:36:57
# INFO:tensorflow:Saving dict for global step 3692: global_step = 3692, loss = 0.02596203
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3692: ./workspace/models/cooc2emb-07/model.ckpt-3692
# INFO:tensorflow:global_step/sec: 59.6714
# INFO:tensorflow:loss = 0.29338312, step = 3700 (1.675 sec)
# INFO:tensorflow:global_step/sec: 136.389
# INFO:tensorflow:loss = 0.32593483, step = 3800 (0.734 sec)
# INFO:tensorflow:global_step/sec: 111.423
# INFO:tensorflow:loss = 0.35459048, step = 3900 (0.897 sec)
# INFO:tensorflow:global_step/sec: 114.103
# INFO:tensorflow:loss = 0.4599342, step = 4000 (0.876 sec)
# INFO:tensorflow:global_step/sec: 112.629
# INFO:tensorflow:loss = 0.31144023, step = 4100 (0.888 sec)
# INFO:tensorflow:global_step/sec: 116.142
# INFO:tensorflow:loss = 0.3150859, step = 4200 (0.861 sec)
# INFO:tensorflow:global_step/sec: 111.492
# INFO:tensorflow:loss = 0.3321993, step = 4300 (0.897 sec)
# INFO:tensorflow:global_step/sec: 117.009
# INFO:tensorflow:loss = 0.33858937, step = 4400 (0.854 sec)
# INFO:tensorflow:global_step/sec: 113.982
# INFO:tensorflow:loss = 0.29742885, step = 4500 (0.878 sec)
# INFO:tensorflow:global_step/sec: 118.208
# INFO:tensorflow:loss = 0.259897, step = 4600 (0.846 sec)
# INFO:tensorflow:Saving checkpoints for 4615 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:37:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-4615
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:37:06
# INFO:tensorflow:Saving dict for global step 4615: global_step = 4615, loss = 0.02732278
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4615: ./workspace/models/cooc2emb-07/model.ckpt-4615
# INFO:tensorflow:global_step/sec: 80.8997
# INFO:tensorflow:loss = 0.2515345, step = 4700 (1.236 sec)
# INFO:tensorflow:global_step/sec: 115.25
# INFO:tensorflow:loss = 0.30758515, step = 4800 (0.868 sec)
# INFO:tensorflow:global_step/sec: 120.481
# INFO:tensorflow:loss = 0.25707835, step = 4900 (0.830 sec)
# INFO:tensorflow:global_step/sec: 117.878
# INFO:tensorflow:loss = 0.28269038, step = 5000 (0.848 sec)
# INFO:tensorflow:global_step/sec: 117.941
# INFO:tensorflow:loss = 0.30130994, step = 5100 (0.848 sec)
# INFO:tensorflow:global_step/sec: 122.068
# INFO:tensorflow:loss = 0.30205876, step = 5200 (0.819 sec)
# INFO:tensorflow:global_step/sec: 115.932
# INFO:tensorflow:loss = 0.30304998, step = 5300 (0.863 sec)
# INFO:tensorflow:global_step/sec: 115.77
# INFO:tensorflow:loss = 0.29368833, step = 5400 (0.864 sec)
# INFO:tensorflow:global_step/sec: 112.658
# INFO:tensorflow:loss = 0.24717763, step = 5500 (0.888 sec)
# INFO:tensorflow:Saving checkpoints for 5538 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:37:14Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-5538
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:37:14
# INFO:tensorflow:Saving dict for global step 5538: global_step = 5538, loss = 0.028119009
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5538: ./workspace/models/cooc2emb-07/model.ckpt-5538
# INFO:tensorflow:global_step/sec: 71.4952
# INFO:tensorflow:loss = 0.3107836, step = 5600 (1.399 sec)
# INFO:tensorflow:global_step/sec: 160.134
# INFO:tensorflow:loss = 0.27489626, step = 5700 (0.624 sec)
# INFO:tensorflow:global_step/sec: 117.084
# INFO:tensorflow:loss = 0.2696164, step = 5800 (0.854 sec)
# INFO:tensorflow:global_step/sec: 117.516
# INFO:tensorflow:loss = 0.24956304, step = 5900 (0.851 sec)
# INFO:tensorflow:global_step/sec: 120.475
# INFO:tensorflow:loss = 0.23993698, step = 6000 (0.830 sec)
# INFO:tensorflow:global_step/sec: 117.458
# INFO:tensorflow:loss = 0.26184675, step = 6100 (0.851 sec)
# INFO:tensorflow:global_step/sec: 111.996
# INFO:tensorflow:loss = 0.27601942, step = 6200 (0.893 sec)
# INFO:tensorflow:global_step/sec: 112.3
# INFO:tensorflow:loss = 0.2792406, step = 6300 (0.891 sec)
# INFO:tensorflow:global_step/sec: 120.418
# INFO:tensorflow:loss = 0.29095298, step = 6400 (0.830 sec)
# INFO:tensorflow:Saving checkpoints for 6461 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:37:22Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-6461
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:37:22
# INFO:tensorflow:Saving dict for global step 6461: global_step = 6461, loss = 0.035960957
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6461: ./workspace/models/cooc2emb-07/model.ckpt-6461
# INFO:tensorflow:global_step/sec: 68.0522
# INFO:tensorflow:loss = 0.26582366, step = 6500 (1.470 sec)
# INFO:tensorflow:global_step/sec: 290.362
# INFO:tensorflow:loss = 0.31280705, step = 6600 (0.345 sec)
# INFO:tensorflow:global_step/sec: 148.767
# INFO:tensorflow:loss = 0.26411155, step = 6700 (0.672 sec)
# INFO:tensorflow:global_step/sec: 110.478
# INFO:tensorflow:loss = 0.25144517, step = 6800 (0.906 sec)
# INFO:tensorflow:global_step/sec: 118.559
# INFO:tensorflow:loss = 0.27329344, step = 6900 (0.843 sec)
# INFO:tensorflow:global_step/sec: 117.25
# INFO:tensorflow:loss = 0.20989835, step = 7000 (0.853 sec)
# INFO:tensorflow:global_step/sec: 120.363
# INFO:tensorflow:loss = 0.2562157, step = 7100 (0.831 sec)
# INFO:tensorflow:global_step/sec: 115.616
# INFO:tensorflow:loss = 0.25948167, step = 7200 (0.865 sec)
# INFO:tensorflow:global_step/sec: 118.508
# INFO:tensorflow:loss = 0.26293522, step = 7300 (0.843 sec)
# INFO:tensorflow:Saving checkpoints for 7384 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:37:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-7384
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:37:30
# INFO:tensorflow:Saving dict for global step 7384: global_step = 7384, loss = 0.041273896
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7384: ./workspace/models/cooc2emb-07/model.ckpt-7384
# INFO:tensorflow:global_step/sec: 67.3417
# INFO:tensorflow:loss = 0.295558, step = 7400 (1.485 sec)
# INFO:tensorflow:global_step/sec: 298.371
# INFO:tensorflow:loss = 0.23047768, step = 7500 (0.335 sec)
# INFO:tensorflow:global_step/sec: 144.526
# INFO:tensorflow:loss = 0.2884467, step = 7600 (0.692 sec)
# INFO:tensorflow:global_step/sec: 116.355
# INFO:tensorflow:loss = 0.24640156, step = 7700 (0.859 sec)
# INFO:tensorflow:global_step/sec: 115.947
# INFO:tensorflow:loss = 0.23347491, step = 7800 (0.863 sec)
# INFO:tensorflow:global_step/sec: 116.302
# INFO:tensorflow:loss = 0.27835363, step = 7900 (0.860 sec)
# INFO:tensorflow:global_step/sec: 123.387
# INFO:tensorflow:loss = 0.2913787, step = 8000 (0.810 sec)
# INFO:tensorflow:global_step/sec: 112.291
# INFO:tensorflow:loss = 0.24523589, step = 8100 (0.891 sec)
# INFO:tensorflow:global_step/sec: 118.878
# INFO:tensorflow:loss = 0.24905223, step = 8200 (0.841 sec)
# INFO:tensorflow:global_step/sec: 117.209
# INFO:tensorflow:loss = 0.27567506, step = 8300 (0.853 sec)
# INFO:tensorflow:Saving checkpoints for 8307 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:37:38Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-8307
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:37:38
# INFO:tensorflow:Saving dict for global step 8307: global_step = 8307, loss = 0.05541422
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8307: ./workspace/models/cooc2emb-07/model.ckpt-8307
# INFO:tensorflow:global_step/sec: 77.1422
# INFO:tensorflow:loss = 0.2832516, step = 8400 (1.296 sec)
# INFO:tensorflow:global_step/sec: 242.637
# INFO:tensorflow:loss = 0.23726903, step = 8500 (0.412 sec)
# INFO:tensorflow:global_step/sec: 116.03
# INFO:tensorflow:loss = 0.24903601, step = 8600 (0.862 sec)
# INFO:tensorflow:global_step/sec: 117.329
# INFO:tensorflow:loss = 0.23280261, step = 8700 (0.852 sec)
# INFO:tensorflow:global_step/sec: 117.901
# INFO:tensorflow:loss = 0.27444324, step = 8800 (0.848 sec)
# INFO:tensorflow:global_step/sec: 113.906
# INFO:tensorflow:loss = 0.23234378, step = 8900 (0.878 sec)
# INFO:tensorflow:global_step/sec: 113.772
# INFO:tensorflow:loss = 0.2782142, step = 9000 (0.879 sec)
# INFO:tensorflow:global_step/sec: 117.062
# INFO:tensorflow:loss = 0.24627572, step = 9100 (0.854 sec)
# INFO:tensorflow:global_step/sec: 120.114
# INFO:tensorflow:loss = 0.23956075, step = 9200 (0.832 sec)
# INFO:tensorflow:Saving checkpoints for 9230 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:37:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-9230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:37:46
# INFO:tensorflow:Saving dict for global step 9230: global_step = 9230, loss = 0.07100965
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9230: ./workspace/models/cooc2emb-07/model.ckpt-9230
# INFO:tensorflow:global_step/sec: 74.1519
# INFO:tensorflow:loss = 0.22860518, step = 9300 (1.349 sec)
# INFO:tensorflow:global_step/sec: 294.231
# INFO:tensorflow:loss = 0.22871536, step = 9400 (0.340 sec)
# INFO:tensorflow:global_step/sec: 118.543
# INFO:tensorflow:loss = 0.30820802, step = 9500 (0.844 sec)
# INFO:tensorflow:global_step/sec: 123.264
# INFO:tensorflow:loss = 0.21524222, step = 9600 (0.811 sec)
# INFO:tensorflow:global_step/sec: 109.296
# INFO:tensorflow:loss = 0.23976478, step = 9700 (0.915 sec)
# INFO:tensorflow:global_step/sec: 114.271
# INFO:tensorflow:loss = 0.21484388, step = 9800 (0.875 sec)
# INFO:tensorflow:global_step/sec: 116.26
# INFO:tensorflow:loss = 0.2276888, step = 9900 (0.860 sec)
# INFO:tensorflow:global_step/sec: 113.137
# INFO:tensorflow:loss = 0.27023327, step = 10000 (0.884 sec)
# INFO:tensorflow:global_step/sec: 120.646
# INFO:tensorflow:loss = 0.2661252, step = 10100 (0.829 sec)
# INFO:tensorflow:Saving checkpoints for 10153 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:37:53Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-10153
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:37:54
# INFO:tensorflow:Saving dict for global step 10153: global_step = 10153, loss = 0.06930811
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10153: ./workspace/models/cooc2emb-07/model.ckpt-10153
# INFO:tensorflow:global_step/sec: 78.7109
# INFO:tensorflow:loss = 0.24254596, step = 10200 (1.270 sec)
# INFO:tensorflow:global_step/sec: 298.404
# INFO:tensorflow:loss = 0.22576948, step = 10300 (0.335 sec)
# INFO:tensorflow:global_step/sec: 121.329
# INFO:tensorflow:loss = 0.24185619, step = 10400 (0.824 sec)
# INFO:tensorflow:global_step/sec: 121.934
# INFO:tensorflow:loss = 0.26733452, step = 10500 (0.820 sec)
# INFO:tensorflow:global_step/sec: 121.156
# INFO:tensorflow:loss = 0.23252742, step = 10600 (0.825 sec)
# INFO:tensorflow:global_step/sec: 116.882
# INFO:tensorflow:loss = 0.2497117, step = 10700 (0.855 sec)
# INFO:tensorflow:global_step/sec: 113.512
# INFO:tensorflow:loss = 0.2309758, step = 10800 (0.881 sec)
# INFO:tensorflow:global_step/sec: 122.687
# INFO:tensorflow:loss = 0.23954955, step = 10900 (0.815 sec)
# INFO:tensorflow:global_step/sec: 120.279
# INFO:tensorflow:loss = 0.23007332, step = 11000 (0.832 sec)
# INFO:tensorflow:Saving checkpoints for 11076 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:38:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-11076
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:38:01
# INFO:tensorflow:Saving dict for global step 11076: global_step = 11076, loss = 0.09156914
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11076: ./workspace/models/cooc2emb-07/model.ckpt-11076
# INFO:tensorflow:global_step/sec: 64.6157
# INFO:tensorflow:loss = 0.22016208, step = 11100 (1.547 sec)
# INFO:tensorflow:global_step/sec: 300.968
# INFO:tensorflow:loss = 0.27699962, step = 11200 (0.333 sec)
# INFO:tensorflow:global_step/sec: 158.601
# INFO:tensorflow:loss = 0.22722903, step = 11300 (0.631 sec)
# INFO:tensorflow:global_step/sec: 119.71
# INFO:tensorflow:loss = 0.25280112, step = 11400 (0.835 sec)
# INFO:tensorflow:global_step/sec: 117.859
# INFO:tensorflow:loss = 0.22833243, step = 11500 (0.848 sec)
# INFO:tensorflow:global_step/sec: 131.641
# INFO:tensorflow:loss = 0.22845519, step = 11600 (0.760 sec)
# INFO:tensorflow:global_step/sec: 118.582
# INFO:tensorflow:loss = 0.21844795, step = 11700 (0.843 sec)
# INFO:tensorflow:global_step/sec: 113.142
# INFO:tensorflow:loss = 0.20629407, step = 11800 (0.884 sec)
# INFO:tensorflow:global_step/sec: 111.509
# INFO:tensorflow:loss = 0.22663002, step = 11900 (0.897 sec)
# INFO:tensorflow:Saving checkpoints for 11999 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:38:09Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-11999
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:38:09
# INFO:tensorflow:Saving dict for global step 11999: global_step = 11999, loss = 0.073756285
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11999: ./workspace/models/cooc2emb-07/model.ckpt-11999
# INFO:tensorflow:global_step/sec: 58.3231
# INFO:tensorflow:loss = 0.21584272, step = 12000 (1.714 sec)
# INFO:tensorflow:global_step/sec: 287.33
# INFO:tensorflow:loss = 0.22865978, step = 12100 (0.348 sec)
# INFO:tensorflow:global_step/sec: 226.595
# INFO:tensorflow:loss = 0.21085712, step = 12200 (0.441 sec)
# INFO:tensorflow:global_step/sec: 118.059
# INFO:tensorflow:loss = 0.27697706, step = 12300 (0.847 sec)
# INFO:tensorflow:global_step/sec: 122.054
# INFO:tensorflow:loss = 0.24855074, step = 12400 (0.819 sec)
# INFO:tensorflow:global_step/sec: 115.91
# INFO:tensorflow:loss = 0.24525367, step = 12500 (0.863 sec)
# INFO:tensorflow:global_step/sec: 123.354
# INFO:tensorflow:loss = 0.2628799, step = 12600 (0.811 sec)
# INFO:tensorflow:global_step/sec: 115.115
# INFO:tensorflow:loss = 0.24643824, step = 12700 (0.869 sec)
# INFO:tensorflow:global_step/sec: 117.814
# INFO:tensorflow:loss = 0.21462394, step = 12800 (0.849 sec)
# INFO:tensorflow:global_step/sec: 112.602
# INFO:tensorflow:loss = 0.20690587, step = 12900 (0.888 sec)
# INFO:tensorflow:Saving checkpoints for 12922 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:38:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-12922
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:38:17
# INFO:tensorflow:Saving dict for global step 12922: global_step = 12922, loss = 0.080493696
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12922: ./workspace/models/cooc2emb-07/model.ckpt-12922
# INFO:tensorflow:global_step/sec: 87.4983
# INFO:tensorflow:loss = 0.26167536, step = 13000 (1.143 sec)
# INFO:tensorflow:global_step/sec: 189.218
# INFO:tensorflow:loss = 0.21530278, step = 13100 (0.528 sec)
# INFO:tensorflow:global_step/sec: 121.549
# INFO:tensorflow:loss = 0.20745084, step = 13200 (0.823 sec)
# INFO:tensorflow:global_step/sec: 117.712
# INFO:tensorflow:loss = 0.24024789, step = 13300 (0.849 sec)
# INFO:tensorflow:global_step/sec: 116.428
# INFO:tensorflow:loss = 0.2326344, step = 13400 (0.859 sec)
# INFO:tensorflow:global_step/sec: 120.429
# INFO:tensorflow:loss = 0.19812652, step = 13500 (0.830 sec)
# INFO:tensorflow:global_step/sec: 118.812
# INFO:tensorflow:loss = 0.23853663, step = 13600 (0.842 sec)
# INFO:tensorflow:global_step/sec: 121.076
# INFO:tensorflow:loss = 0.2504559, step = 13700 (0.826 sec)
# INFO:tensorflow:global_step/sec: 125.565
# INFO:tensorflow:loss = 0.23973328, step = 13800 (0.796 sec)
# INFO:tensorflow:Saving checkpoints for 13845 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:38:24Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-13845
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:38:25
# INFO:tensorflow:Saving dict for global step 13845: global_step = 13845, loss = 0.091394976
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13845: ./workspace/models/cooc2emb-07/model.ckpt-13845
# INFO:tensorflow:global_step/sec: 71.1373
# INFO:tensorflow:loss = 0.19405685, step = 13900 (1.406 sec)
# INFO:tensorflow:global_step/sec: 293.141
# INFO:tensorflow:loss = 0.23775157, step = 14000 (0.341 sec)
# INFO:tensorflow:global_step/sec: 129.349
# INFO:tensorflow:loss = 0.20141324, step = 14100 (0.773 sec)
# INFO:tensorflow:global_step/sec: 123.948
# INFO:tensorflow:loss = 0.20113882, step = 14200 (0.806 sec)
# INFO:tensorflow:global_step/sec: 120.21
# INFO:tensorflow:loss = 0.21346748, step = 14300 (0.832 sec)
# INFO:tensorflow:global_step/sec: 117.814
# INFO:tensorflow:loss = 0.1877275, step = 14400 (0.849 sec)
# INFO:tensorflow:global_step/sec: 118.096
# INFO:tensorflow:loss = 0.23008719, step = 14500 (0.847 sec)
# INFO:tensorflow:global_step/sec: 115.834
# INFO:tensorflow:loss = 0.2045927, step = 14600 (0.863 sec)
# INFO:tensorflow:global_step/sec: 117.977
# INFO:tensorflow:loss = 0.19733971, step = 14700 (0.848 sec)
# INFO:tensorflow:Saving checkpoints for 14768 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:38:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-14768
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:38:32
# INFO:tensorflow:Saving dict for global step 14768: global_step = 14768, loss = 0.09569485
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14768: ./workspace/models/cooc2emb-07/model.ckpt-14768
# INFO:tensorflow:global_step/sec: 65.0764
# INFO:tensorflow:loss = 0.2326706, step = 14800 (1.537 sec)
# INFO:tensorflow:global_step/sec: 297.695
# INFO:tensorflow:loss = 0.24746181, step = 14900 (0.336 sec)
# INFO:tensorflow:global_step/sec: 143.386
# INFO:tensorflow:loss = 0.24843162, step = 15000 (0.697 sec)
# INFO:tensorflow:global_step/sec: 114.921
# INFO:tensorflow:loss = 0.22147642, step = 15100 (0.871 sec)
# INFO:tensorflow:global_step/sec: 115.243
# INFO:tensorflow:loss = 0.21673837, step = 15200 (0.867 sec)
# INFO:tensorflow:global_step/sec: 113.913
# INFO:tensorflow:loss = 0.24233156, step = 15300 (0.878 sec)
# INFO:tensorflow:global_step/sec: 113.271
# INFO:tensorflow:loss = 0.19803168, step = 15400 (0.883 sec)
# INFO:tensorflow:global_step/sec: 117.361
# INFO:tensorflow:loss = 0.20624433, step = 15500 (0.852 sec)
# INFO:tensorflow:global_step/sec: 119.174
# INFO:tensorflow:loss = 0.23887321, step = 15600 (0.839 sec)
# INFO:tensorflow:Saving checkpoints for 15691 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:38:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-15691
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:38:40
# INFO:tensorflow:Saving dict for global step 15691: global_step = 15691, loss = 0.088318355
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15691: ./workspace/models/cooc2emb-07/model.ckpt-15691
# INFO:tensorflow:global_step/sec: 64.6293
# INFO:tensorflow:loss = 0.19577241, step = 15700 (1.547 sec)
# INFO:tensorflow:global_step/sec: 288.208
# INFO:tensorflow:loss = 0.21445289, step = 15800 (0.347 sec)
# INFO:tensorflow:global_step/sec: 154.887
# INFO:tensorflow:loss = 0.239276, step = 15900 (0.645 sec)
# INFO:tensorflow:global_step/sec: 112.305
# INFO:tensorflow:loss = 0.21160617, step = 16000 (0.891 sec)
# INFO:tensorflow:global_step/sec: 112.723
# INFO:tensorflow:loss = 0.22598135, step = 16100 (0.887 sec)
# INFO:tensorflow:global_step/sec: 115.952
# INFO:tensorflow:loss = 0.22480766, step = 16200 (0.862 sec)
# INFO:tensorflow:global_step/sec: 115.804
# INFO:tensorflow:loss = 0.24122667, step = 16300 (0.863 sec)
# INFO:tensorflow:global_step/sec: 115.686
# INFO:tensorflow:loss = 0.22167045, step = 16400 (0.864 sec)
# INFO:tensorflow:global_step/sec: 117.681
# INFO:tensorflow:loss = 0.31691295, step = 16500 (0.850 sec)
# INFO:tensorflow:global_step/sec: 117.888
# INFO:tensorflow:loss = 0.208746, step = 16600 (0.848 sec)
# INFO:tensorflow:Saving checkpoints for 16614 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:38:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-16614
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:38:48
# INFO:tensorflow:Saving dict for global step 16614: global_step = 16614, loss = 0.10068831
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16614: ./workspace/models/cooc2emb-07/model.ckpt-16614
# INFO:tensorflow:global_step/sec: 79.4619
# INFO:tensorflow:loss = 0.2673146, step = 16700 (1.258 sec)
# INFO:tensorflow:global_step/sec: 232.225
# INFO:tensorflow:loss = 0.23298593, step = 16800 (0.432 sec)
# INFO:tensorflow:global_step/sec: 118.671
# INFO:tensorflow:loss = 0.23708083, step = 16900 (0.841 sec)
# INFO:tensorflow:global_step/sec: 127.39
# INFO:tensorflow:loss = 0.22691944, step = 17000 (0.785 sec)
# INFO:tensorflow:global_step/sec: 115.453
# INFO:tensorflow:loss = 0.20653203, step = 17100 (0.866 sec)
# INFO:tensorflow:global_step/sec: 121.347
# INFO:tensorflow:loss = 0.22438052, step = 17200 (0.824 sec)
# INFO:tensorflow:global_step/sec: 117.982
# INFO:tensorflow:loss = 0.22781098, step = 17300 (0.848 sec)
# INFO:tensorflow:global_step/sec: 118.73
# INFO:tensorflow:loss = 0.24040675, step = 17400 (0.842 sec)
# INFO:tensorflow:global_step/sec: 108.92
# INFO:tensorflow:loss = 0.22109354, step = 17500 (0.918 sec)
# INFO:tensorflow:Saving checkpoints for 17537 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:38:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-17537
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:38:56
# INFO:tensorflow:Saving dict for global step 17537: global_step = 17537, loss = 0.10451177
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17537: ./workspace/models/cooc2emb-07/model.ckpt-17537
# INFO:tensorflow:global_step/sec: 71.6689
# INFO:tensorflow:loss = 0.22869515, step = 17600 (1.395 sec)
# INFO:tensorflow:global_step/sec: 301.502
# INFO:tensorflow:loss = 0.19589557, step = 17700 (0.332 sec)
# INFO:tensorflow:global_step/sec: 131.335
# INFO:tensorflow:loss = 0.2301158, step = 17800 (0.762 sec)
# INFO:tensorflow:global_step/sec: 122.302
# INFO:tensorflow:loss = 0.2159896, step = 17900 (0.817 sec)
# INFO:tensorflow:global_step/sec: 117.244
# INFO:tensorflow:loss = 0.19601728, step = 18000 (0.853 sec)
# INFO:tensorflow:global_step/sec: 120.185
# INFO:tensorflow:loss = 0.21760923, step = 18100 (0.832 sec)
# INFO:tensorflow:global_step/sec: 117.74
# INFO:tensorflow:loss = 0.24181864, step = 18200 (0.849 sec)
# INFO:tensorflow:global_step/sec: 119.392
# INFO:tensorflow:loss = 0.21157746, step = 18300 (0.838 sec)
# INFO:tensorflow:global_step/sec: 121.914
# INFO:tensorflow:loss = 0.21590364, step = 18400 (0.820 sec)
# INFO:tensorflow:Saving checkpoints for 18460 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:39:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-18460
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:39:04
# INFO:tensorflow:Saving dict for global step 18460: global_step = 18460, loss = 0.09311326
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18460: ./workspace/models/cooc2emb-07/model.ckpt-18460
# INFO:tensorflow:global_step/sec: 76.3889
# INFO:tensorflow:loss = 0.20302838, step = 18500 (1.309 sec)
# INFO:tensorflow:global_step/sec: 300.398
# INFO:tensorflow:loss = 0.18118875, step = 18600 (0.333 sec)
# INFO:tensorflow:global_step/sec: 122.367
# INFO:tensorflow:loss = 0.18705203, step = 18700 (0.817 sec)
# INFO:tensorflow:global_step/sec: 124.743
# INFO:tensorflow:loss = 0.21456136, step = 18800 (0.802 sec)
# INFO:tensorflow:global_step/sec: 116.972
# INFO:tensorflow:loss = 0.21910538, step = 18900 (0.855 sec)
# INFO:tensorflow:global_step/sec: 121.194
# INFO:tensorflow:loss = 0.22073668, step = 19000 (0.825 sec)
# INFO:tensorflow:global_step/sec: 116.584
# INFO:tensorflow:loss = 0.19837621, step = 19100 (0.858 sec)
# INFO:tensorflow:global_step/sec: 119.796
# INFO:tensorflow:loss = 0.23014507, step = 19200 (0.835 sec)
# INFO:tensorflow:global_step/sec: 116.876
# INFO:tensorflow:loss = 0.21109296, step = 19300 (0.855 sec)
# INFO:tensorflow:Saving checkpoints for 19383 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:39:11Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-19383
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:39:12
# INFO:tensorflow:Saving dict for global step 19383: global_step = 19383, loss = 0.10256825
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 19383: ./workspace/models/cooc2emb-07/model.ckpt-19383
# INFO:tensorflow:global_step/sec: 61.8223
# INFO:tensorflow:loss = 0.21910745, step = 19400 (1.617 sec)
# INFO:tensorflow:global_step/sec: 285.541
# INFO:tensorflow:loss = 0.2702969, step = 19500 (0.351 sec)
# INFO:tensorflow:global_step/sec: 181.151
# INFO:tensorflow:loss = 0.25298077, step = 19600 (0.552 sec)
# INFO:tensorflow:global_step/sec: 117.708
# INFO:tensorflow:loss = 0.19402474, step = 19700 (0.849 sec)
# INFO:tensorflow:global_step/sec: 115.516
# INFO:tensorflow:loss = 0.21808676, step = 19800 (0.866 sec)
# INFO:tensorflow:global_step/sec: 121.131
# INFO:tensorflow:loss = 0.19526562, step = 19900 (0.826 sec)
# INFO:tensorflow:global_step/sec: 118.047
# INFO:tensorflow:loss = 0.1987498, step = 20000 (0.847 sec)
# INFO:tensorflow:global_step/sec: 118.913
# INFO:tensorflow:loss = 0.19153923, step = 20100 (0.841 sec)
# INFO:tensorflow:global_step/sec: 122.053
# INFO:tensorflow:loss = 0.22660169, step = 20200 (0.819 sec)
# INFO:tensorflow:global_step/sec: 120.854
# INFO:tensorflow:loss = 0.18525332, step = 20300 (0.827 sec)
# INFO:tensorflow:Saving checkpoints for 20306 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:39:19Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-20306
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:39:19
# ...
# INFO:tensorflow:global_step/sec: 121.98
# INFO:tensorflow:loss = 0.2372938, step = 39600 (0.820 sec)
# INFO:tensorflow:Saving checkpoints for 39689 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:42:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-39689
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:42:02
# INFO:tensorflow:Saving dict for global step 39689: global_step = 39689, loss = 0.06828619
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 39689: ./workspace/models/cooc2emb-07/model.ckpt-39689
# INFO:tensorflow:global_step/sec: 68.1098
# INFO:tensorflow:loss = 0.21428981, step = 39700 (1.468 sec)
# INFO:tensorflow:global_step/sec: 295.869
# INFO:tensorflow:loss = 0.19238055, step = 39800 (0.338 sec)
# INFO:tensorflow:global_step/sec: 150.14
# INFO:tensorflow:loss = 0.19305186, step = 39900 (0.666 sec)
# INFO:tensorflow:global_step/sec: 117.218
# INFO:tensorflow:loss = 0.19880706, step = 40000 (0.853 sec)
# INFO:tensorflow:global_step/sec: 127.794
# INFO:tensorflow:loss = 0.21701202, step = 40100 (0.783 sec)
# INFO:tensorflow:global_step/sec: 122.776
# INFO:tensorflow:loss = 0.19439876, step = 40200 (0.814 sec)
# INFO:tensorflow:global_step/sec: 115.161
# INFO:tensorflow:loss = 0.2062434, step = 40300 (0.869 sec)
# INFO:tensorflow:global_step/sec: 122.471
# INFO:tensorflow:loss = 0.2320348, step = 40400 (0.817 sec)
# INFO:tensorflow:global_step/sec: 118.914
# INFO:tensorflow:loss = 0.20586091, step = 40500 (0.841 sec)
# INFO:tensorflow:global_step/sec: 123.469
# INFO:tensorflow:loss = 0.2057617, step = 40600 (0.810 sec)
# INFO:tensorflow:Saving checkpoints for 40612 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:42:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-40612
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:42:10
# INFO:tensorflow:Saving dict for global step 40612: global_step = 40612, loss = 0.062384564
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40612: ./workspace/models/cooc2emb-07/model.ckpt-40612
# INFO:tensorflow:global_step/sec: 79.4817
# INFO:tensorflow:loss = 0.20524098, step = 40700 (1.258 sec)
# INFO:tensorflow:global_step/sec: 237.529
# INFO:tensorflow:loss = 0.22928475, step = 40800 (0.421 sec)
# INFO:tensorflow:global_step/sec: 118.114
# INFO:tensorflow:loss = 0.1925452, step = 40900 (0.847 sec)
# INFO:tensorflow:global_step/sec: 111.919
# INFO:tensorflow:loss = 0.18963632, step = 41000 (0.893 sec)
# INFO:tensorflow:global_step/sec: 117.364
# INFO:tensorflow:loss = 0.20070855, step = 41100 (0.854 sec)
# INFO:tensorflow:global_step/sec: 119.809
# INFO:tensorflow:loss = 0.21159583, step = 41200 (0.833 sec)
# INFO:tensorflow:global_step/sec: 122.831
# INFO:tensorflow:loss = 0.21822833, step = 41300 (0.814 sec)
# INFO:tensorflow:global_step/sec: 117.779
# INFO:tensorflow:loss = 0.20184472, step = 41400 (0.849 sec)
# INFO:tensorflow:global_step/sec: 116.339
# INFO:tensorflow:loss = 0.22613408, step = 41500 (0.860 sec)
# INFO:tensorflow:Saving checkpoints for 41535 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:42:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-41535
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:42:18
# INFO:tensorflow:Saving dict for global step 41535: global_step = 41535, loss = 0.07858542
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 41535: ./workspace/models/cooc2emb-07/model.ckpt-41535
# INFO:tensorflow:global_step/sec: 70.8994
# INFO:tensorflow:loss = 0.19900477, step = 41600 (1.410 sec)
# INFO:tensorflow:global_step/sec: 294.825
# INFO:tensorflow:loss = 0.19562536, step = 41700 (0.339 sec)
# INFO:tensorflow:global_step/sec: 133.185
# INFO:tensorflow:loss = 0.19461349, step = 41800 (0.751 sec)
# INFO:tensorflow:global_step/sec: 114.35
# INFO:tensorflow:loss = 0.20164987, step = 41900 (0.874 sec)
# INFO:tensorflow:global_step/sec: 122.461
# INFO:tensorflow:loss = 0.17166857, step = 42000 (0.817 sec)
# INFO:tensorflow:global_step/sec: 117.302
# INFO:tensorflow:loss = 0.22970994, step = 42100 (0.853 sec)
# INFO:tensorflow:global_step/sec: 122.825
# INFO:tensorflow:loss = 0.20275004, step = 42200 (0.814 sec)
# INFO:tensorflow:global_step/sec: 117.157
# INFO:tensorflow:loss = 0.20757191, step = 42300 (0.853 sec)
# INFO:tensorflow:global_step/sec: 117.996
# INFO:tensorflow:loss = 0.21472938, step = 42400 (0.848 sec)
# INFO:tensorflow:Saving checkpoints for 42458 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:42:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-42458
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:42:25
# INFO:tensorflow:Saving dict for global step 42458: global_step = 42458, loss = 0.071695074
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 42458: ./workspace/models/cooc2emb-07/model.ckpt-42458
# INFO:tensorflow:global_step/sec: 76.6315
# INFO:tensorflow:loss = 0.19985592, step = 42500 (1.305 sec)
# INFO:tensorflow:global_step/sec: 274.115
# INFO:tensorflow:loss = 0.2176761, step = 42600 (0.365 sec)
# INFO:tensorflow:global_step/sec: 119.215
# INFO:tensorflow:loss = 0.20501052, step = 42700 (0.839 sec)
# INFO:tensorflow:global_step/sec: 120.333
# INFO:tensorflow:loss = 0.19787638, step = 42800 (0.831 sec)
# INFO:tensorflow:global_step/sec: 120.158
# INFO:tensorflow:loss = 0.21989858, step = 42900 (0.832 sec)
# INFO:tensorflow:global_step/sec: 123.086
# INFO:tensorflow:loss = 0.21247172, step = 43000 (0.812 sec)
# INFO:tensorflow:global_step/sec: 118.686
# INFO:tensorflow:loss = 0.22358465, step = 43100 (0.843 sec)
# INFO:tensorflow:global_step/sec: 118.338
# INFO:tensorflow:loss = 0.22725062, step = 43200 (0.845 sec)
# INFO:tensorflow:global_step/sec: 119.034
# INFO:tensorflow:loss = 0.21252275, step = 43300 (0.840 sec)
# INFO:tensorflow:Saving checkpoints for 43381 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:42:33Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-43381
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:42:33
# INFO:tensorflow:Saving dict for global step 43381: global_step = 43381, loss = 0.08212724
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 43381: ./workspace/models/cooc2emb-07/model.ckpt-43381
# INFO:tensorflow:global_step/sec: 60.4722
# INFO:tensorflow:loss = 0.17413637, step = 43400 (1.653 sec)
# INFO:tensorflow:global_step/sec: 289.67
# INFO:tensorflow:loss = 0.20449328, step = 43500 (0.345 sec)
# INFO:tensorflow:global_step/sec: 207.535
# INFO:tensorflow:loss = 0.22499216, step = 43600 (0.482 sec)
# INFO:tensorflow:global_step/sec: 114.123
# INFO:tensorflow:loss = 0.20668036, step = 43700 (0.876 sec)
# INFO:tensorflow:global_step/sec: 119.984
# INFO:tensorflow:loss = 0.21960726, step = 43800 (0.833 sec)
# INFO:tensorflow:global_step/sec: 113.174
# INFO:tensorflow:loss = 0.18430807, step = 43900 (0.884 sec)
# INFO:tensorflow:global_step/sec: 118.798
# INFO:tensorflow:loss = 0.19083378, step = 44000 (0.842 sec)
# INFO:tensorflow:global_step/sec: 120.268
# INFO:tensorflow:loss = 0.20233859, step = 44100 (0.831 sec)
# INFO:tensorflow:global_step/sec: 117.746
# INFO:tensorflow:loss = 0.24810115, step = 44200 (0.849 sec)
# INFO:tensorflow:global_step/sec: 116.906
# INFO:tensorflow:loss = 0.19436489, step = 44300 (0.855 sec)
# INFO:tensorflow:Saving checkpoints for 44304 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:42:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-44304
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:42:41
# INFO:tensorflow:Saving dict for global step 44304: global_step = 44304, loss = 0.07281095
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44304: ./workspace/models/cooc2emb-07/model.ckpt-44304
# INFO:tensorflow:global_step/sec: 84.0253
# INFO:tensorflow:loss = 0.19980976, step = 44400 (1.190 sec)
# INFO:tensorflow:global_step/sec: 254.171
# INFO:tensorflow:loss = 0.19256254, step = 44500 (0.393 sec)
# INFO:tensorflow:global_step/sec: 117.935
# INFO:tensorflow:loss = 0.19777517, step = 44600 (0.848 sec)
# INFO:tensorflow:global_step/sec: 119.82
# INFO:tensorflow:loss = 0.19803953, step = 44700 (0.835 sec)
# INFO:tensorflow:global_step/sec: 117.678
# INFO:tensorflow:loss = 0.20621075, step = 44800 (0.850 sec)
# INFO:tensorflow:global_step/sec: 117.434
# INFO:tensorflow:loss = 0.19842881, step = 44900 (0.852 sec)
# INFO:tensorflow:global_step/sec: 118.017
# INFO:tensorflow:loss = 0.210855, step = 45000 (0.847 sec)
# INFO:tensorflow:global_step/sec: 112.435
# INFO:tensorflow:loss = 0.20102008, step = 45100 (0.890 sec)
# INFO:tensorflow:global_step/sec: 119.422
# INFO:tensorflow:loss = 0.18319292, step = 45200 (0.837 sec)
# INFO:tensorflow:Saving checkpoints for 45227 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:42:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-45227
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:42:49
# INFO:tensorflow:Saving dict for global step 45227: global_step = 45227, loss = 0.06379913
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45227: ./workspace/models/cooc2emb-07/model.ckpt-45227
# INFO:tensorflow:global_step/sec: 85.0564
# INFO:tensorflow:loss = 0.20519602, step = 45300 (1.176 sec)
# INFO:tensorflow:global_step/sec: 205.974
# INFO:tensorflow:loss = 0.2065246, step = 45400 (0.486 sec)
# INFO:tensorflow:global_step/sec: 117.194
# INFO:tensorflow:loss = 0.20980898, step = 45500 (0.853 sec)
# INFO:tensorflow:global_step/sec: 115.823
# INFO:tensorflow:loss = 0.19628622, step = 45600 (0.863 sec)
# INFO:tensorflow:global_step/sec: 107.207
# INFO:tensorflow:loss = 0.19191977, step = 45700 (0.933 sec)
# INFO:tensorflow:global_step/sec: 116.689
# INFO:tensorflow:loss = 0.20310158, step = 45800 (0.857 sec)
# INFO:tensorflow:global_step/sec: 113.028
# INFO:tensorflow:loss = 0.20396978, step = 45900 (0.885 sec)
# INFO:tensorflow:global_step/sec: 121.584
# INFO:tensorflow:loss = 0.19186932, step = 46000 (0.822 sec)
# INFO:tensorflow:global_step/sec: 113.957
# INFO:tensorflow:loss = 0.18317723, step = 46100 (0.878 sec)
# INFO:tensorflow:Saving checkpoints for 46150 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:42:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-46150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:42:57
# INFO:tensorflow:Saving dict for global step 46150: global_step = 46150, loss = 0.07220526
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46150: ./workspace/models/cooc2emb-07/model.ckpt-46150
# INFO:tensorflow:Saving checkpoints for 46157 into ./workspace/models/cooc2emb-07/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4632 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4632 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-10-08T13:42:57Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-46157
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-10-08-13:42:58
# INFO:tensorflow:Saving dict for global step 46157: global_step = 46157, loss = 0.07205242
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46157: ./workspace/models/cooc2emb-07/model.ckpt-46157
# INFO:tensorflow:Loss for final step: 0.18822902.
# .......................................
# Experiment finished.
# CPU times: user 14min 28s, sys: 6min 45s, total: 21min 13s
# Wall time: 6min 36s

# %% [markdown]
# ## 8. Extract Word embeddings

# %%
def extract_embeddings(model_dir, checkpoint):
    
    with tf.Session() as sess:
        saver = tf.train.import_meta_graph(os.path.join(model_dir, 'model.ckpt-{}.meta'.format(checkpoint)))
        saver.restore(sess, os.path.join(model_dir, 'model.ckpt-{}'.format(checkpoint)))
        graph = tf.get_default_graph()
        weights_tensor = graph.get_tensor_by_name('input_layer/item1_item2_shared_embedding/embedding_weights:0')
        weights = np.array(sess.run(weights_tensor))

    return weights

# %%
checkpoint = params.train_steps
embeddings = extract_embeddings(model_dir, checkpoint)
print(len(embeddings))
print(embeddings[0])
# Out:
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-07/model.ckpt-46157
# 4632
# [ 1.0213016  -0.10725072  0.7739918   0.0332012   0.42940634  0.1397516
#   1.0675998  -0.73517615  0.8547443  -0.43006274 -0.5750132  -0.3696358
#   0.5030041  -0.275972   -0.27586427 -0.41647613 -0.56597006 -0.57236856
#  -0.67539805 -0.3738892   0.3473007   0.26539868 -0.42769083 -0.39912197
#  -0.59455264  0.06485956  0.01481059  0.45336306 -0.23120002  0.25990224
#   0.8420276   1.107458    0.21145105 -0.76536393  0.736067   -0.40591478
#   0.77940476 -0.47856522  0.15879287 -0.31453386  0.64187175  0.7946321
#   0.5779661   0.13116291  0.47162905 -0.7195507   0.53635824  0.5119927
#  -0.06278135 -0.49129912 -0.30125576  0.15781142  0.38197124 -0.10838864
#   0.41809973  0.35847008 -0.04960598 -0.22166592 -0.40517446 -0.2888908
#   0.4890815  -0.13018125 -0.19192408 -0.5896855 ]

# %%
vocab_path = os.path.join(COOC_DIR,'vocab.txt')
output_path = os.path.join(WORKSPACE,'embeddings.tsv')

if tf.io.gfile.exists(output_path):
    print("Removing {} ...".format(output_path))
    tf.io.gfile.remove(output_path)

def write_embeddings_to_tsv():
    with open(output_path, 'w') as out_f:
        with open(vocab_path) as vocab_f:
            for index, item in enumerate(vocab_f):
                embedding = embeddings[index]
                print('\t'.join([item.strip()] + [str(x) for x in embedding]), file=out_f)
    
    print("Embeddings are written to: {}".format(output_path))
                
write_embeddings_to_tsv()
# Out:
# Removing ./workspace/embeddings.tsv ...
# Embeddings are written to: ./workspace/embeddings.tsv

# %%
# !head {output_path}
# Out:
# comparisons	1.0213016	-0.10725072	0.7739918	0.033201203	0.42940634	0.1397516	1.0675998	-0.73517615	0.8547443	-0.43006274	-0.5750132	-0.3696358	0.5030041	-0.275972	-0.27586427	-0.41647613	-0.56597006	-0.57236856	-0.67539805	-0.3738892	0.3473007	0.26539868	-0.42769083	-0.39912197	-0.59455264	0.06485956	0.014810595	0.45336306	-0.23120002	0.25990224	0.8420276	1.107458	0.21145105	-0.76536393	0.736067	-0.40591478	0.77940476	-0.47856522	0.15879287	-0.31453386	0.64187175	0.7946321	0.5779661	0.13116291	0.47162905	-0.7195507	0.53635824	0.5119927	-0.06278135	-0.49129912	-0.30125576	0.15781142	0.38197124	-0.10838864	0.41809973	0.35847008	-0.049605977	-0.22166592	-0.40517446	-0.2888908	0.4890815	-0.13018125	-0.19192408	-0.5896855
# vampires	0.035619188	0.04893078	-0.084809445	-0.06471856	0.52670044	-0.0055025746	-0.037620332	0.016188823	0.07806883	0.08989796	0.06998612	0.08039018	0.33301553	-0.29314372	-0.4904764	-0.23849678	-0.13123038	0.34412712	0.057331108	0.040416718	-0.40215397	0.41187695	-0.31136	-0.31043845	0.3586613	0.05413555	0.23774204	-0.3533565	-0.45456254	0.053738378	-0.011898253	0.25466457	-0.05543736	0.11313206	0.093134955	0.14783454	-0.29120252	0.4105265	-0.28370652	-0.41901538	-0.15609051	0.07025394	-0.6010917	0.6548282	0.2791787	-0.58038425	-0.0032665	0.15552609	-0.2941126	-0.29215062	-0.0039014847	-0.49357954	-0.2389503	-0.5646528	-0.1124064	-0.0075617325	-0.44797155	-0.20475863	0.07670909	-0.009014583	0.6173781	0.036304176	-0.48776087	0.085021526
# essential	0.6706159	0.8791079	0.17867759	0.6906307	-0.44553217	-0.9306068	0.18104033	-0.17848574	0.35441247	-0.44475862	-0.1228004	0.17021658	0.76154953	-0.1691907	0.053248324	-0.6493337	0.15510385	-0.18625335	-0.67071366	-0.6453672	0.5522343	0.21892886	-0.94606507	-0.13406944	-0.25522473	0.457136	0.5330317	0.28863195	-0.2510237	0.3486081	0.41973856	0.4068672	0.5044748	-0.56315607	0.033367693	-0.29043153	0.8330734	-0.80669117	-0.7467535	0.6551852	0.55712557	0.055097517	0.36522347	0.48504698	0.5873206	-0.33367917	0.7375996	-0.123454854	-0.5299391	0.254413	-0.14427145	-0.7487254	0.00412411	0.75566316	0.42711502	-0.008496809	-0.18767603	0.509568	-0.7034257	-0.5684829	-0.26691258	-1.0899578	-0.32173073	0.45427448
# pie	0.13003469	0.059616104	0.37285352	-0.262914	-0.096688084	0.3782504	0.09125581	-0.2518946	-0.5172839	-0.0491752	-0.663864	-0.21588479	-0.40368885	0.026780605	0.03834121	0.30341345	0.25679576	-0.008273633	-0.22287463	0.27220955	0.015482845	0.38929453	-0.20414317	-0.13890287	0.39075056	-0.1399597	-0.13811672	0.29373938	0.063603014	-0.2654983	0.07583316	-0.30681148	-0.18328375	0.2194613	0.19988519	-0.30921286	0.05013214	-0.1999986	-0.36074588	0.36793783	0.045009736	0.18362388	0.38179487	-0.275349	0.22425605	0.037129603	0.255558	0.20049626	-0.4103416	0.35385346	-0.499716	-0.20196687	-0.31612846	0.40304333	0.4515037	-0.094949156	-0.3363638	0.2906642	-0.114737466	-0.5620189	-0.24184708	-0.07591031	0.11312027	-0.25603724
# wasted	0.04632763	0.39957568	0.30586907	0.22579986	0.38090155	-0.24053213	0.49658504	-0.4916816	0.19437107	-0.17011373	0.2565031	0.39176205	-0.3564182	0.33008337	0.4329995	-0.19299278	0.45833507	-0.3414763	0.16968961	-0.34685162	0.14510329	-0.08103837	0.011489317	0.02929106	-0.24803571	0.20150806	0.3351766	0.024490278	0.19636765	0.06883318	0.089666545	0.33031762	0.6192484	0.6434695	0.21900718	-0.6476731	0.094833404	-0.15577447	0.076503314	-0.013500632	-0.16032052	0.4558977	0.10404221	-0.13254951	0.16298302	0.7775218	-0.024565203	-0.47256136	0.118571624	-0.27300546	-0.28380138	0.15512116	-0.18894525	-0.04272309	0.14873004	-0.1146956	-0.0882188	-0.12306859	-0.26032075	-0.010565158	-0.1999302	0.06753108	0.030559173	-0.021763802
# constantly	0.057143386	0.16309416	0.30136436	0.02053512	0.3065074	-0.1873746	0.15972067	0.15203273	0.13458392	0.12341061	-0.033556104	0.49070555	-0.34175548	0.13350284	-0.111500025	-0.3409948	-0.07743499	0.10185955	0.1900803	-0.05048504	0.16855887	0.03212821	-0.06191243	-0.04885468	0.24219264	0.22031239	0.45014557	0.16769902	-0.1715522	0.17149194	-0.27753785	0.034187026	-0.05535068	0.0026363516	-0.09848862	-0.035224754	0.39973202	-0.29991665	0.24397582	-0.23584688	-0.25524518	0.17038141	0.21119358	-0.3304222	0.08943687	0.047245674	-0.061213173	0.23558879	0.16644056	0.37194362	-0.2968423	-0.060302142	-0.0064773457	-0.34561577	0.54460824	0.20873784	-0.1909875	0.14718892	-0.12851296	-0.06906906	0.29888448	0.28201976	-0.002478998	-0.20770901
# building	0.014659427	0.5664743	0.052265357	0.14797449	-0.03165743	0.046086434	0.14877729	-0.12369577	0.29591346	-0.25808695	0.23600475	-0.24048986	-0.098082386	-0.44867644	0.06864245	0.25253716	-0.08648646	0.24757257	0.04181107	0.17824124	0.251977	-0.4017806	-0.016080704	-0.12595983	0.6443086	-0.249707	0.031537395	-0.16287737	-0.004584746	-0.009649912	0.04310942	0.28960887	0.10408763	-0.27921882	0.33237672	0.16760004	0.0054767383	-0.07896135	-0.110462025	-0.26006413	0.11505993	0.050409745	-0.15789329	-0.27397847	0.25125784	-0.36010426	-0.11956102	0.09207387	0.21481666	0.30698562	-0.5079774	0.15378767	-0.098840065	-0.098527886	-0.17235887	-0.07482367	0.26050588	0.2909509	0.355751	-0.32723758	-0.04208275	0.13025191	-0.28099257	0.39109263
# necessarily	0.24082841	0.8816162	-0.18623425	-0.47338173	0.35690942	-0.32125598	0.10503365	0.04962059	-0.07170971	0.36220556	-0.14518294	-0.35665745	0.5064103	-0.0027684942	-0.077772245	-0.33152273	0.48597845	-0.07059508	-0.2564101	-0.007510326	0.3285826	0.58029455	-0.041264396	0.11316465	0.0396288	0.090317994	0.15445733	0.36028552	-0.17899267	-0.30225798	0.27825588	-0.25072974	0.35849407	-0.28495222	0.115028925	0.033614684	0.274119	0.21120313	0.42119795	0.49503538	0.11433186	0.15519702	0.32819778	-0.13349424	0.28551918	-0.24914594	-0.19624272	0.21970394	-0.3928709	-0.08609157	0.507654	-0.62992036	0.33227617	-0.11158198	-0.70188206	-0.22428712	-0.20621066	-0.2619791	-0.36437407	0.23653893	-0.40251625	0.1651137	0.2352354	0.2297826
# laugh	0.34824327	-0.05112317	-0.054026593	-0.27386114	0.6093126	0.3818846	-2.7137703e-05	-0.2777404	0.10518515	0.32352906	-0.7015299	-0.31790426	-0.2237607	0.07574166	-0.1608596	-0.2124845	0.08637591	-0.2732815	-0.2495301	0.119980864	0.27908233	0.03066836	-0.1460864	0.22444701	-0.22084378	-0.238395	0.22491401	0.1335706	0.07039315	0.006898593	0.014401524	-0.19371237	-0.5344346	-0.2577983	-0.18993661	0.123133235	0.512366	0.25946343	-0.11835328	-0.06269814	0.050728045	0.22419532	-0.22263347	-0.0663231	0.02141849	-0.28784063	-0.08299235	-0.21569218	-0.018524805	-0.005920699	0.08996821	0.2205306	0.055445425	0.20731814	-0.38033214	0.28885826	0.3284116	-0.294601	-0.1586047	0.22176656	-0.27753764	0.066524625	0.07291914	0.20366511
# gem	-0.0693172	0.48215273	0.66438395	-0.43060955	0.22525926	-0.17968461	0.29497206	0.41422784	0.56454563	-0.475677	-0.26498646	-0.41834348	0.18803266	0.31469318	-0.77135515	0.22994162	-0.20230456	-0.7018894	-0.4651575	-0.54456365	-0.3058139	0.4726078	-0.19837485	-0.76630217	-0.25394085	0.26885766	-0.3632476	0.4676747	-0.4184058	0.0072534457	0.53622544	0.1841269	0.49646217	-0.42692283	0.36349297	0.2314063	0.5166777	0.06415167	0.27898833	-0.18845907	0.56900173	0.06819718	0.278401	0.16827227	1.0320631	-0.23418611	0.5382942	0.3732666	-0.4717441	0.14045277	-0.7468627	0.10849257	-0.20937929	0.8794154	0.5739633	-0.82354265	-0.38490385	0.09474844	0.1838022	-0.6101374	0.9204797	-0.12166365	0.01883188	0.24207066
