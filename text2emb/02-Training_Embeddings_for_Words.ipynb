# %% [markdown]
# # Training Embeddings for Words
#
# This tutorial shows how to learn **word embeddings** from co-occurrence statistics.
#
# We use a simple NN architecture, a long with the conditional cost function used by the [Swivel](https://arxiv.org/pdf/1602.02215.pdf) algorithm.
#
# The learnt embeddings are then extracted from the model and saved as TSV file.
#
# The following are the steps of this tutorial:
#
#
# 1. Define input data metadata
# 2. Implement data input function
# 3. Create feature columns
# 4. Create a custome estimator
# 5. Define the train and evaluate experiment
# 6. Set the experiment parameters
# 7. Run the experiment
# 8. Extract the learnt **word embeddings** from the model
#
# <a href="https://colab.research.google.com/github/ksalama/data2cooc2emb2ann/blob/master/movie2ann/02-Training_Embeddings_for_Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Setup

# %%
# !pip install -r ../requirements.txt

# %%
import os
import math
import numpy as np
import tensorflow as tf
from tensorflow import data
from datetime import datetime

# %%
WORKSPACE = './workspace'
COOC_DIR = '{}/cooc'.format(WORKSPACE)
MODELS_DIR = '{}/models'.format(WORKSPACE)
SEED = 19831060

# %%
# !echo "Files:"
# !ls {COOC_DIR}/
# !echo ""

# !echo "info:"
# !head {COOC_DIR}/info.log
# !echo ""

# !echo "vocab file:"
# !head {COOC_DIR}/vocab.txt
# !echo ""
# Out:
# Files:
# cooc-00000-of-00007.tfrecords cooc-00005-of-00007.tfrecords
# cooc-00001-of-00007.tfrecords cooc-00006-of-00007.tfrecords
# cooc-00002-of-00007.tfrecords info.log
# cooc-00003-of-00007.tfrecords vocab.txt
# cooc-00004-of-00007.tfrecords
#
# info:
# P: 1123186
# N: 105886
# min: -3.29281
# max: 11.45451
#
# vocab file:
# sum
# cocoa
# introduced
# ride
# trespass
# might
# fabrics
# thoris
# protection
# part

# %% [markdown]
# ## 1.  Metadata

# %%
FEATURES_SCHEMA = {
    'item1': tf.FixedLenFeature(dtype=tf.string, shape=()),
    'item2': tf.FixedLenFeature(dtype=tf.string, shape=()),
    'score': tf.FixedLenFeature(dtype=tf.float32, shape=()),
    'weight': tf.FixedLenFeature(dtype=tf.float32, shape=()),
    'type': tf.FixedLenFeature(dtype=tf.string, shape=())
}

WEIGHT_FEATURE_NAME = 'weight'
TARGET_FEATURE_NAME = 'score'

# %% [markdown]
# ## 2.  Data Input Function

# %%
def make_input_fn(file_pattern, 
                  batch_size=128, num_epochs=1, mode=tf.estimator.ModeKeys.EVAL):

    def _input_fn():
        dataset = tf.data.experimental.make_batched_features_dataset(
            file_pattern,
            batch_size,
            features=FEATURES_SCHEMA,
            label_key=TARGET_FEATURE_NAME,
            reader=tf.data.TFRecordDataset,
            shuffle_buffer_size=batch_size * 10,
            reader_num_threads=1,
            parser_num_threads=2,
            num_epochs=num_epochs,
            shuffle=(mode==tf.estimator.ModeKeys.TRAIN),
            sloppy_ordering=True,
            drop_final_batch=True
        )
        return dataset
    
    return _input_fn

# %% [markdown]
# ## 3. Feature Columns

# %%
def create_feature_columns(embedding_size, vocab1_file, vocab2_file):
    
    feature_columns = []

    feature_columns.append(
        tf.feature_column.embedding_column(
            tf.feature_column.categorical_column_with_vocabulary_file(
                key='item1', 
                vocabulary_file=vocab1_file
            ), 
            embedding_size
        )
    )

    feature_columns.append(
        tf.feature_column.embedding_column(
            tf.feature_column.categorical_column_with_vocabulary_file(
                key='item2', 
                vocabulary_file=vocab2_file
            ), 
            embedding_size
        )
    )
        
    return feature_columns

# %% [markdown]
# ## 4.  Custom Estimator

# %%
def compute_loss(labels, predictions, weights, types):
    
    def _positive_sample_cost(errors, weights):
        return 0.5 * weights * tf.math.square(errors)
    
    def _negative_sample_cost(errors, weights):
        return weights * tf.math.log(1 + tf.exp(errors))
    
    errors = predictions - labels
    
    p_loss = _positive_sample_cost(errors, weights)
    n_loss = _negative_sample_cost(errors, weights)
    loss = tf.where(tf.equal(types, 'P'), p_loss, n_loss)
    
    return tf.reduce_sum(loss)

def model_fn(features, labels, mode, params):
    
    items1 = features['item1']
    feature_columns = create_feature_columns(
        params.embedding_size, params.vocab1_file, params.vocab2_file)
    
    item1_layer = tf.feature_column.input_layer(
        features={'item1': items1}, feature_columns=[feature_columns[0]])
    
    if mode != tf.estimator.ModeKeys.PREDICT:
        items2 = features['item2']
        item2_layer = tf.feature_column.input_layer(
            features={'item2': items2}, feature_columns=[feature_columns[1]])
        
        dot_product = tf.keras.layers.Dot(axes=1)([item1_layer, item2_layer])
        logits = (params.max_value - params.min_value) * tf.sigmoid(dot_product) + params.min_value 

    predictions = None
    export_outputs = None
    loss = None
    train_op = None

    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions =  item1_layer
        export_outputs = {'predictions': tf.estimator.export.PredictOutput(predictions)}
    else:
        types = features['type']
        weights = features[WEIGHT_FEATURE_NAME]
        
#         loss = tf.losses.mean_squared_error(
#             labels=labels, 
#             predictions=tf.squeeze(logits),
#             weights=weights
#         )

        loss = compute_loss(
            labels=labels, 
            predictions=tf.squeeze(logits), 
            weights=weights, 
            types=types
        )
        
        train_op=tf.train.AdamOptimizer(params.learning_rate).minimize(
            loss=loss, global_step=tf.train.get_global_step())
        
    
    return tf.estimator.EstimatorSpec(
        mode=mode,
        predictions=predictions,
        export_outputs=export_outputs,
        loss=loss,
        train_op=train_op
    )


def create_estimator(params, run_config):
    
    estimator = tf.estimator.Estimator(
        model_fn,
        params=params,
        config=run_config
    )
    
    return estimator

# %% [markdown]
# ## 5. Experiment

# %%
def run_experiment(params, run_config):
    
    train_data_files = params.train_data_files
    eval_data_files = params.eval_data_files
    
    # TrainSpec ####################################
    train_input_fn = make_input_fn(
        train_data_files,
        batch_size=params.batch_size,
        num_epochs=None,
        mode=tf.estimator.ModeKeys.TRAIN
    )
    
    train_spec = tf.estimator.TrainSpec(
        input_fn = train_input_fn,
        max_steps=params.traning_steps
    )
    ###############################################    
    
    # EvalSpec ####################################
    eval_input_fn = make_input_fn(
        eval_data_files,
        num_epochs=None,
        batch_size=params.batch_size,
    )

    eval_spec = tf.estimator.EvalSpec(
        name=datetime.utcnow().strftime("%H%M%S"),
        input_fn = eval_input_fn,
        steps=params.eval_steps,
        start_delay_secs=0,
        throttle_secs=params.eval_throttle_secs
    )
    ###############################################

    tf.logging.set_verbosity(tf.logging.INFO)
    
    if tf.gfile.Exists(run_config.model_dir):
        print("Removing previous artefacts...")
        tf.gfile.DeleteRecursively(run_config.model_dir)
            
    print("")
    estimator = create_estimator(params, run_config)
    print("")
    
    time_start = datetime.utcnow() 
    print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
    print(".......................................") 

    tf.estimator.train_and_evaluate(
        estimator=estimator,
        train_spec=train_spec, 
        eval_spec=eval_spec
    )

    time_end = datetime.utcnow() 
    print(".......................................")
    print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
    print("")
    time_elapsed = time_end - time_start
    print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
    
    return estimator

# %% [markdown]
# ## 6. Parameters

# %%
MODEL_NAME = 'cooc2emb-01'
model_dir = os.path.join(MODELS_DIR, MODEL_NAME)
info_file = os.path.join(COOC_DIR, 'info.log')
min_value = 15
max_value = -5

info_map = {}

if os.path.exists(info_file):
    try:
        with open(info_file) as f:
            for line in f.readlines():
                key, value = line.split(":")
                info_map[key] = float(value)
        min_value = math.floor(info_map['min'])
        max_value = math.ceil(info_map['max'])
    except: pass
    
class HParams():
    pass

params  = HParams()
params.train_data_files = "{}/cooc-*.tfrecords".format(COOC_DIR)
params.eval_data_files = "{}/cooc-*.tfrecords".format(COOC_DIR)
params.vocab1_file = os.path.join(COOC_DIR,'vocab.txt')
params.vocab2_file = os.path.join(COOC_DIR,'vocab.txt')
params.embedding_size = 128
params.min_value = min_value
params.max_value = max_value
params.batch_size = 265
params.traning_steps = 30000
params.learning_rate = 0.001
params.eval_steps = 1
params.eval_throttle_secs = 0

print(vars(params))

run_config = tf.estimator.RunConfig(
    tf_random_seed=SEED,
    save_checkpoints_steps=1000,
    keep_checkpoint_max=3,
    model_dir=model_dir,
)
# Out:
# {'train_data_files': './workspace/cooc/cooc-*.tfrecords', 'eval_data_files': './workspace/cooc/cooc-*.tfrecords', 'vocab1_file': './workspace/cooc/vocab.txt', 'vocab2_file': './workspace/cooc/vocab.txt', 'embedding_size': 128, 'min_value': -4, 'max_value': 12, 'batch_size': 265, 'traning_steps': 30000, 'learning_rate': 0.001, 'eval_steps': 1, 'eval_throttle_secs': 0}

# %% [markdown]
# ## 7. Run

# %%
estimator = run_experiment(params, run_config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './workspace/models/cooc2emb-01', '_tf_random_seed': 19831060, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x12d45a4e0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# Experiment started at 13:46:06
# .......................................
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/data/util/random_seed.py:58: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/data/experimental/ops/readers.py:835: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/data/experimental/ops/readers.py:212: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py:205: EmbeddingColumn._get_dense_tensor (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column_v2.py:3140: VocabularyFileCategoricalColumn._get_sparse_tensors (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py:2115: VocabularyFileCategoricalColumn._transform_feature (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column_v2.py:3080: VocabularyFileCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py:206: EmbeddingColumn._variable_shape (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:loss = 533.4608, step = 1
# INFO:tensorflow:global_step/sec: 182.373
# INFO:tensorflow:loss = 416.30438, step = 101 (0.546 sec)
# INFO:tensorflow:global_step/sec: 202.851
# INFO:tensorflow:loss = 820.62213, step = 201 (0.493 sec)
# INFO:tensorflow:global_step/sec: 158.618
# INFO:tensorflow:loss = 472.3457, step = 301 (0.631 sec)
# INFO:tensorflow:global_step/sec: 130.376
# INFO:tensorflow:loss = 354.78714, step = 401 (0.768 sec)
# INFO:tensorflow:global_step/sec: 120.954
# INFO:tensorflow:loss = 296.55563, step = 501 (0.825 sec)
# INFO:tensorflow:global_step/sec: 178.489
# INFO:tensorflow:loss = 535.0836, step = 601 (0.560 sec)
# INFO:tensorflow:global_step/sec: 146.612
# INFO:tensorflow:loss = 588.00586, step = 701 (0.684 sec)
# INFO:tensorflow:global_step/sec: 175.841
# INFO:tensorflow:loss = 505.98636, step = 801 (0.567 sec)
# INFO:tensorflow:global_step/sec: 199.992
# INFO:tensorflow:loss = 455.4432, step = 901 (0.500 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:46:15Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:46:15
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 153.97975
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./workspace/models/cooc2emb-01/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 52.267
# INFO:tensorflow:loss = 350.5269, step = 1001 (1.915 sec)
# INFO:tensorflow:global_step/sec: 161.445
# INFO:tensorflow:loss = 422.83356, step = 1101 (0.628 sec)
# INFO:tensorflow:global_step/sec: 166.753
# INFO:tensorflow:loss = 598.6262, step = 1201 (0.589 sec)
# INFO:tensorflow:global_step/sec: 173.807
# INFO:tensorflow:loss = 493.87988, step = 1301 (0.575 sec)
# INFO:tensorflow:global_step/sec: 218.464
# INFO:tensorflow:loss = 388.08447, step = 1401 (0.458 sec)
# INFO:tensorflow:global_step/sec: 193.51
# INFO:tensorflow:loss = 283.7814, step = 1501 (0.517 sec)
# INFO:tensorflow:global_step/sec: 175.643
# INFO:tensorflow:loss = 1022.3289, step = 1601 (0.569 sec)
# INFO:tensorflow:global_step/sec: 252.806
# INFO:tensorflow:loss = 317.87204, step = 1701 (0.395 sec)
# INFO:tensorflow:global_step/sec: 256.786
# INFO:tensorflow:loss = 380.73544, step = 1801 (0.390 sec)
# INFO:tensorflow:global_step/sec: 249.372
# INFO:tensorflow:loss = 394.83218, step = 1901 (0.401 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:46:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:46:22
# INFO:tensorflow:Saving dict for global step 2000: global_step = 2000, loss = 148.77588
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: ./workspace/models/cooc2emb-01/model.ckpt-2000
# INFO:tensorflow:global_step/sec: 60.0771
# INFO:tensorflow:loss = 350.60965, step = 2001 (1.670 sec)
# INFO:tensorflow:global_step/sec: 215.907
# INFO:tensorflow:loss = 308.5189, step = 2101 (0.458 sec)
# INFO:tensorflow:global_step/sec: 228.25
# INFO:tensorflow:loss = 259.59067, step = 2201 (0.438 sec)
# INFO:tensorflow:global_step/sec: 229.28
# INFO:tensorflow:loss = 292.23523, step = 2301 (0.436 sec)
# INFO:tensorflow:global_step/sec: 228.81
# INFO:tensorflow:loss = 368.4754, step = 2401 (0.437 sec)
# INFO:tensorflow:global_step/sec: 243.679
# INFO:tensorflow:loss = 276.5235, step = 2501 (0.410 sec)
# INFO:tensorflow:global_step/sec: 215.138
# INFO:tensorflow:loss = 344.9206, step = 2601 (0.465 sec)
# INFO:tensorflow:global_step/sec: 208.491
# INFO:tensorflow:loss = 603.67334, step = 2701 (0.480 sec)
# INFO:tensorflow:global_step/sec: 131.972
# INFO:tensorflow:loss = 253.02402, step = 2801 (0.758 sec)
# INFO:tensorflow:global_step/sec: 156.349
# INFO:tensorflow:loss = 931.85895, step = 2901 (0.643 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into ./workspace/models/cooc2emb-01/model.ckpt.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:46:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:46:28
# INFO:tensorflow:Saving dict for global step 3000: global_step = 3000, loss = 144.67934
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: ./workspace/models/cooc2emb-01/model.ckpt-3000
# INFO:tensorflow:global_step/sec: 59.1296
# INFO:tensorflow:loss = 358.70694, step = 3001 (1.689 sec)
# INFO:tensorflow:global_step/sec: 190.88
# INFO:tensorflow:loss = 392.84616, step = 3101 (0.522 sec)
# INFO:tensorflow:global_step/sec: 232.048
# INFO:tensorflow:loss = 244.56761, step = 3201 (0.431 sec)
# INFO:tensorflow:global_step/sec: 186.36
# INFO:tensorflow:loss = 418.83984, step = 3301 (0.538 sec)
# INFO:tensorflow:global_step/sec: 191.21
# INFO:tensorflow:loss = 235.91357, step = 3401 (0.522 sec)
# INFO:tensorflow:global_step/sec: 160.839
# INFO:tensorflow:loss = 349.7719, step = 3501 (0.622 sec)
# INFO:tensorflow:global_step/sec: 184.84
# INFO:tensorflow:loss = 269.4994, step = 3601 (0.541 sec)
# INFO:tensorflow:global_step/sec: 192.307
# INFO:tensorflow:loss = 232.04343, step = 3701 (0.520 sec)
# INFO:tensorflow:global_step/sec: 204.644
# INFO:tensorflow:loss = 303.33997, step = 3801 (0.489 sec)
# INFO:tensorflow:global_step/sec: 176.781
# INFO:tensorflow:loss = 389.55017, step = 3901 (0.566 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:46:34Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:46:34
# INFO:tensorflow:Saving dict for global step 4000: global_step = 4000, loss = 147.38762
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: ./workspace/models/cooc2emb-01/model.ckpt-4000
# INFO:tensorflow:global_step/sec: 67.1212
# INFO:tensorflow:loss = 480.0223, step = 4001 (1.493 sec)
# INFO:tensorflow:global_step/sec: 146.728
# INFO:tensorflow:loss = 217.13387, step = 4101 (0.678 sec)
# INFO:tensorflow:global_step/sec: 217.349
# INFO:tensorflow:loss = 291.31537, step = 4201 (0.460 sec)
# INFO:tensorflow:global_step/sec: 162.087
# INFO:tensorflow:loss = 169.75978, step = 4301 (0.617 sec)
# INFO:tensorflow:global_step/sec: 188.595
# INFO:tensorflow:loss = 436.77814, step = 4401 (0.530 sec)
# INFO:tensorflow:global_step/sec: 215.386
# INFO:tensorflow:loss = 296.68414, step = 4501 (0.465 sec)
# INFO:tensorflow:global_step/sec: 216.004
# INFO:tensorflow:loss = 446.45493, step = 4601 (0.462 sec)
# INFO:tensorflow:global_step/sec: 230.06
# INFO:tensorflow:loss = 109.2952, step = 4701 (0.435 sec)
# INFO:tensorflow:global_step/sec: 230.671
# INFO:tensorflow:loss = 181.17122, step = 4801 (0.433 sec)
# INFO:tensorflow:global_step/sec: 171.058
# INFO:tensorflow:loss = 109.62749, step = 4901 (0.584 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:46:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:46:40
# INFO:tensorflow:Saving dict for global step 5000: global_step = 5000, loss = 150.1204
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: ./workspace/models/cooc2emb-01/model.ckpt-5000
# INFO:tensorflow:global_step/sec: 62.5474
# INFO:tensorflow:loss = 127.316734, step = 5001 (1.601 sec)
# INFO:tensorflow:global_step/sec: 221.97
# INFO:tensorflow:loss = 284.2875, step = 5101 (0.448 sec)
# INFO:tensorflow:global_step/sec: 242.038
# INFO:tensorflow:loss = 255.98628, step = 5201 (0.413 sec)
# INFO:tensorflow:global_step/sec: 248.739
# INFO:tensorflow:loss = 177.02512, step = 5301 (0.402 sec)
# INFO:tensorflow:global_step/sec: 248.697
# INFO:tensorflow:loss = 323.58157, step = 5401 (0.402 sec)
# INFO:tensorflow:global_step/sec: 237.796
# INFO:tensorflow:loss = 247.27838, step = 5501 (0.421 sec)
# INFO:tensorflow:global_step/sec: 182.079
# INFO:tensorflow:loss = 185.15872, step = 5601 (0.549 sec)
# INFO:tensorflow:global_step/sec: 266.073
# INFO:tensorflow:loss = 132.28767, step = 5701 (0.376 sec)
# INFO:tensorflow:global_step/sec: 260.966
# INFO:tensorflow:loss = 226.41444, step = 5801 (0.383 sec)
# INFO:tensorflow:global_step/sec: 263.114
# INFO:tensorflow:loss = 244.47987, step = 5901 (0.381 sec)
# INFO:tensorflow:Saving checkpoints for 6000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:46:45Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:46:46
# INFO:tensorflow:Saving dict for global step 6000: global_step = 6000, loss = 75.0855
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: ./workspace/models/cooc2emb-01/model.ckpt-6000
# INFO:tensorflow:global_step/sec: 74.4625
# INFO:tensorflow:loss = 221.29164, step = 6001 (1.343 sec)
# INFO:tensorflow:global_step/sec: 207.567
# INFO:tensorflow:loss = 240.08403, step = 6101 (0.482 sec)
# INFO:tensorflow:global_step/sec: 223.769
# INFO:tensorflow:loss = 116.76948, step = 6201 (0.447 sec)
# INFO:tensorflow:global_step/sec: 220.434
# INFO:tensorflow:loss = 134.69981, step = 6301 (0.454 sec)
# INFO:tensorflow:global_step/sec: 203.259
# INFO:tensorflow:loss = 214.10757, step = 6401 (0.494 sec)
# INFO:tensorflow:global_step/sec: 209.199
# INFO:tensorflow:loss = 102.13979, step = 6501 (0.476 sec)
# INFO:tensorflow:global_step/sec: 219.559
# INFO:tensorflow:loss = 211.7761, step = 6601 (0.455 sec)
# INFO:tensorflow:global_step/sec: 224.213
# INFO:tensorflow:loss = 104.71283, step = 6701 (0.446 sec)
# INFO:tensorflow:global_step/sec: 223.327
# INFO:tensorflow:loss = 127.76811, step = 6801 (0.448 sec)
# INFO:tensorflow:global_step/sec: 217.886
# INFO:tensorflow:loss = 202.71956, step = 6901 (0.459 sec)
# INFO:tensorflow:Saving checkpoints for 7000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:46:51Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:46:51
# INFO:tensorflow:Saving dict for global step 7000: global_step = 7000, loss = 74.46636
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7000: ./workspace/models/cooc2emb-01/model.ckpt-7000
# INFO:tensorflow:global_step/sec: 64.2799
# INFO:tensorflow:loss = 128.16235, step = 7001 (1.556 sec)
# INFO:tensorflow:global_step/sec: 201.639
# INFO:tensorflow:loss = 157.6337, step = 7101 (0.495 sec)
# INFO:tensorflow:global_step/sec: 228.97
# INFO:tensorflow:loss = 133.82338, step = 7201 (0.437 sec)
# INFO:tensorflow:global_step/sec: 231.014
# INFO:tensorflow:loss = 139.02509, step = 7301 (0.433 sec)
# INFO:tensorflow:global_step/sec: 239.819
# INFO:tensorflow:loss = 118.85853, step = 7401 (0.417 sec)
# INFO:tensorflow:global_step/sec: 228.066
# INFO:tensorflow:loss = 95.660576, step = 7501 (0.438 sec)
# INFO:tensorflow:global_step/sec: 236.983
# INFO:tensorflow:loss = 318.43265, step = 7601 (0.422 sec)
# INFO:tensorflow:global_step/sec: 226.616
# INFO:tensorflow:loss = 196.44266, step = 7701 (0.441 sec)
# INFO:tensorflow:global_step/sec: 235.362
# INFO:tensorflow:loss = 136.1908, step = 7801 (0.425 sec)
# INFO:tensorflow:global_step/sec: 236.934
# INFO:tensorflow:loss = 128.81812, step = 7901 (0.422 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:46:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:46:57
# INFO:tensorflow:Saving dict for global step 8000: global_step = 8000, loss = 75.80399
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: ./workspace/models/cooc2emb-01/model.ckpt-8000
# INFO:tensorflow:global_step/sec: 71.5066
# INFO:tensorflow:loss = 224.91809, step = 8001 (1.399 sec)
# INFO:tensorflow:global_step/sec: 218.355
# INFO:tensorflow:loss = 83.78002, step = 8101 (0.458 sec)
# INFO:tensorflow:global_step/sec: 271.168
# INFO:tensorflow:loss = 114.31158, step = 8201 (0.369 sec)
# INFO:tensorflow:global_step/sec: 273.735
# INFO:tensorflow:loss = 287.55188, step = 8301 (0.365 sec)
# INFO:tensorflow:global_step/sec: 285.717
# INFO:tensorflow:loss = 160.0424, step = 8401 (0.350 sec)
# INFO:tensorflow:global_step/sec: 248.184
# INFO:tensorflow:loss = 119.3425, step = 8501 (0.403 sec)
# INFO:tensorflow:global_step/sec: 240.227
# INFO:tensorflow:loss = 259.59012, step = 8601 (0.416 sec)
# INFO:tensorflow:global_step/sec: 225.879
# INFO:tensorflow:loss = 160.15637, step = 8701 (0.443 sec)
# INFO:tensorflow:global_step/sec: 235.693
# INFO:tensorflow:loss = 147.65736, step = 8801 (0.425 sec)
# INFO:tensorflow:global_step/sec: 232.87
# INFO:tensorflow:loss = 101.154724, step = 8901 (0.429 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:47:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:47:02
# INFO:tensorflow:Saving dict for global step 9000: global_step = 9000, loss = 79.51082
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: ./workspace/models/cooc2emb-01/model.ckpt-9000
# INFO:tensorflow:global_step/sec: 76.5526
# INFO:tensorflow:loss = 180.28967, step = 9001 (1.307 sec)
# INFO:tensorflow:global_step/sec: 220.527
# INFO:tensorflow:loss = 148.45726, step = 9101 (0.453 sec)
# INFO:tensorflow:global_step/sec: 233.426
# INFO:tensorflow:loss = 148.46855, step = 9201 (0.429 sec)
# INFO:tensorflow:global_step/sec: 221.458
# INFO:tensorflow:loss = 122.95598, step = 9301 (0.452 sec)
# INFO:tensorflow:global_step/sec: 217.473
# INFO:tensorflow:loss = 165.40877, step = 9401 (0.460 sec)
# INFO:tensorflow:global_step/sec: 221.282
# INFO:tensorflow:loss = 93.23185, step = 9501 (0.452 sec)
# INFO:tensorflow:global_step/sec: 219.941
# INFO:tensorflow:loss = 115.446594, step = 9601 (0.455 sec)
# INFO:tensorflow:global_step/sec: 217.266
# INFO:tensorflow:loss = 94.60494, step = 9701 (0.461 sec)
# INFO:tensorflow:global_step/sec: 212.893
# INFO:tensorflow:loss = 88.93497, step = 9801 (0.469 sec)
# INFO:tensorflow:global_step/sec: 221.899
# INFO:tensorflow:loss = 92.01679, step = 9901 (0.451 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:47:07Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:47:08
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, loss = 53.724598
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: ./workspace/models/cooc2emb-01/model.ckpt-10000
# INFO:tensorflow:global_step/sec: 51.4172
# INFO:tensorflow:loss = 131.75343, step = 10001 (1.946 sec)
# INFO:tensorflow:global_step/sec: 211.186
# INFO:tensorflow:loss = 98.12294, step = 10101 (0.473 sec)
# INFO:tensorflow:global_step/sec: 270.309
# INFO:tensorflow:loss = 92.770805, step = 10201 (0.369 sec)
# INFO:tensorflow:global_step/sec: 230.717
# INFO:tensorflow:loss = 102.596176, step = 10301 (0.434 sec)
# INFO:tensorflow:global_step/sec: 252.479
# INFO:tensorflow:loss = 91.956795, step = 10401 (0.396 sec)
# INFO:tensorflow:global_step/sec: 228.79
# INFO:tensorflow:loss = 81.76729, step = 10501 (0.437 sec)
# INFO:tensorflow:global_step/sec: 213.667
# INFO:tensorflow:loss = 80.74664, step = 10601 (0.468 sec)
# INFO:tensorflow:global_step/sec: 211.161
# INFO:tensorflow:loss = 73.73151, step = 10701 (0.474 sec)
# INFO:tensorflow:global_step/sec: 199.539
# INFO:tensorflow:loss = 136.9018, step = 10801 (0.501 sec)
# INFO:tensorflow:global_step/sec: 212.37
# INFO:tensorflow:loss = 109.27521, step = 10901 (0.471 sec)
# INFO:tensorflow:Saving checkpoints for 11000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:47:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-11000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:47:13
# INFO:tensorflow:Saving dict for global step 11000: global_step = 11000, loss = 54.71193
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11000: ./workspace/models/cooc2emb-01/model.ckpt-11000
# INFO:tensorflow:global_step/sec: 69.3339
# INFO:tensorflow:loss = 89.22093, step = 11001 (1.443 sec)
# INFO:tensorflow:global_step/sec: 227.67
# INFO:tensorflow:loss = 81.44673, step = 11101 (0.438 sec)
# INFO:tensorflow:global_step/sec: 251.121
# INFO:tensorflow:loss = 70.189514, step = 11201 (0.397 sec)
# INFO:tensorflow:global_step/sec: 264.213
# INFO:tensorflow:loss = 137.58115, step = 11301 (0.378 sec)
# INFO:tensorflow:global_step/sec: 254.864
# INFO:tensorflow:loss = 101.3676, step = 11401 (0.393 sec)
# INFO:tensorflow:global_step/sec: 233.578
# INFO:tensorflow:loss = 118.018074, step = 11501 (0.428 sec)
# INFO:tensorflow:global_step/sec: 227.939
# INFO:tensorflow:loss = 74.87761, step = 11601 (0.439 sec)
# INFO:tensorflow:global_step/sec: 230.617
# INFO:tensorflow:loss = 69.91487, step = 11701 (0.434 sec)
# INFO:tensorflow:global_step/sec: 223.034
# INFO:tensorflow:loss = 96.83378, step = 11801 (0.448 sec)
# INFO:tensorflow:global_step/sec: 238.979
# INFO:tensorflow:loss = 89.68684, step = 11901 (0.419 sec)
# INFO:tensorflow:Saving checkpoints for 12000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:47:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-12000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:47:18
# INFO:tensorflow:Saving dict for global step 12000: global_step = 12000, loss = 56.80806
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12000: ./workspace/models/cooc2emb-01/model.ckpt-12000
# INFO:tensorflow:global_step/sec: 73.9836
# INFO:tensorflow:loss = 84.20348, step = 12001 (1.351 sec)
# INFO:tensorflow:global_step/sec: 235.639
# INFO:tensorflow:loss = 83.262985, step = 12101 (0.425 sec)
# INFO:tensorflow:global_step/sec: 234.382
# INFO:tensorflow:loss = 93.5512, step = 12201 (0.427 sec)
# INFO:tensorflow:global_step/sec: 225.541
# INFO:tensorflow:loss = 86.87986, step = 12301 (0.444 sec)
# INFO:tensorflow:global_step/sec: 217.47
# INFO:tensorflow:loss = 92.77724, step = 12401 (0.460 sec)
# INFO:tensorflow:global_step/sec: 250.859
# INFO:tensorflow:loss = 107.76064, step = 12501 (0.398 sec)
# INFO:tensorflow:global_step/sec: 235.173
# INFO:tensorflow:loss = 60.041462, step = 12601 (0.426 sec)
# INFO:tensorflow:global_step/sec: 213.345
# INFO:tensorflow:loss = 95.90189, step = 12701 (0.469 sec)
# INFO:tensorflow:global_step/sec: 211.212
# INFO:tensorflow:loss = 119.73781, step = 12801 (0.473 sec)
# INFO:tensorflow:global_step/sec: 218.535
# INFO:tensorflow:loss = 118.259346, step = 12901 (0.458 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:47:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:47:24
# INFO:tensorflow:Saving dict for global step 13000: global_step = 13000, loss = 60.493774
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13000: ./workspace/models/cooc2emb-01/model.ckpt-13000
# INFO:tensorflow:global_step/sec: 60.026
# INFO:tensorflow:loss = 91.84486, step = 13001 (1.668 sec)
# INFO:tensorflow:global_step/sec: 135.786
# INFO:tensorflow:loss = 87.88068, step = 13101 (0.735 sec)
# INFO:tensorflow:global_step/sec: 136.919
# INFO:tensorflow:loss = 92.34535, step = 13201 (0.730 sec)
# INFO:tensorflow:global_step/sec: 147.675
# INFO:tensorflow:loss = 94.01558, step = 13301 (0.678 sec)
# INFO:tensorflow:global_step/sec: 156.596
# INFO:tensorflow:loss = 80.5742, step = 13401 (0.638 sec)
# INFO:tensorflow:global_step/sec: 173.72
# INFO:tensorflow:loss = 87.66031, step = 13501 (0.576 sec)
# INFO:tensorflow:global_step/sec: 201.78
# INFO:tensorflow:loss = 142.02843, step = 13601 (0.495 sec)
# INFO:tensorflow:global_step/sec: 198.733
# INFO:tensorflow:loss = 128.15382, step = 13701 (0.503 sec)
# INFO:tensorflow:global_step/sec: 186.655
# INFO:tensorflow:loss = 100.517815, step = 13801 (0.536 sec)
# INFO:tensorflow:global_step/sec: 218.429
# INFO:tensorflow:loss = 103.00946, step = 13901 (0.458 sec)
# INFO:tensorflow:Saving checkpoints for 14000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:47:31Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:47:31
# INFO:tensorflow:Saving dict for global step 14000: global_step = 14000, loss = 59.308674
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14000: ./workspace/models/cooc2emb-01/model.ckpt-14000
# INFO:tensorflow:global_step/sec: 58.3208
# INFO:tensorflow:loss = 67.987045, step = 14001 (1.715 sec)
# INFO:tensorflow:global_step/sec: 154.836
# INFO:tensorflow:loss = 66.03491, step = 14101 (0.645 sec)
# INFO:tensorflow:global_step/sec: 208.922
# INFO:tensorflow:loss = 59.85261, step = 14201 (0.478 sec)
# INFO:tensorflow:global_step/sec: 217.277
# INFO:tensorflow:loss = 45.55705, step = 14301 (0.460 sec)
# INFO:tensorflow:global_step/sec: 246.829
# INFO:tensorflow:loss = 59.93783, step = 14401 (0.405 sec)
# INFO:tensorflow:global_step/sec: 257.882
# INFO:tensorflow:loss = 57.7028, step = 14501 (0.389 sec)
# INFO:tensorflow:global_step/sec: 242.265
# INFO:tensorflow:loss = 60.085968, step = 14601 (0.411 sec)
# INFO:tensorflow:global_step/sec: 257.951
# INFO:tensorflow:loss = 53.95191, step = 14701 (0.388 sec)
# INFO:tensorflow:global_step/sec: 231.109
# INFO:tensorflow:loss = 57.85878, step = 14801 (0.433 sec)
# INFO:tensorflow:global_step/sec: 260.069
# INFO:tensorflow:loss = 67.07056, step = 14901 (0.384 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:47:36Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:47:37
# INFO:tensorflow:Saving dict for global step 15000: global_step = 15000, loss = 63.106068
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15000: ./workspace/models/cooc2emb-01/model.ckpt-15000
# INFO:tensorflow:global_step/sec: 62.4822
# INFO:tensorflow:loss = 65.56097, step = 15001 (1.605 sec)
# INFO:tensorflow:global_step/sec: 204.561
# INFO:tensorflow:loss = 64.99097, step = 15101 (0.490 sec)
# INFO:tensorflow:global_step/sec: 226.693
# INFO:tensorflow:loss = 84.19123, step = 15201 (0.436 sec)
# INFO:tensorflow:global_step/sec: 233.14
# INFO:tensorflow:loss = 77.586754, step = 15301 (0.429 sec)
# INFO:tensorflow:global_step/sec: 234.523
# INFO:tensorflow:loss = 124.92033, step = 15401 (0.426 sec)
# INFO:tensorflow:global_step/sec: 226.323
# INFO:tensorflow:loss = 88.17713, step = 15501 (0.442 sec)
# INFO:tensorflow:global_step/sec: 228.006
# INFO:tensorflow:loss = 89.682365, step = 15601 (0.438 sec)
# INFO:tensorflow:global_step/sec: 226.297
# INFO:tensorflow:loss = 98.97555, step = 15701 (0.442 sec)
# INFO:tensorflow:global_step/sec: 236.974
# INFO:tensorflow:loss = 76.533775, step = 15801 (0.422 sec)
# INFO:tensorflow:global_step/sec: 216.186
# INFO:tensorflow:loss = 105.545944, step = 15901 (0.462 sec)
# INFO:tensorflow:Saving checkpoints for 16000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:47:42Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-16000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:47:42
# INFO:tensorflow:Saving dict for global step 16000: global_step = 16000, loss = 46.987534
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16000: ./workspace/models/cooc2emb-01/model.ckpt-16000
# INFO:tensorflow:global_step/sec: 69.5127
# INFO:tensorflow:loss = 79.202095, step = 16001 (1.443 sec)
# INFO:tensorflow:global_step/sec: 215.454
# INFO:tensorflow:loss = 87.76276, step = 16101 (0.460 sec)
# INFO:tensorflow:global_step/sec: 232.07
# INFO:tensorflow:loss = 109.53492, step = 16201 (0.431 sec)
# INFO:tensorflow:global_step/sec: 203.921
# INFO:tensorflow:loss = 66.15445, step = 16301 (0.490 sec)
# INFO:tensorflow:global_step/sec: 204.65
# INFO:tensorflow:loss = 54.364708, step = 16401 (0.489 sec)
# INFO:tensorflow:global_step/sec: 209.169
# INFO:tensorflow:loss = 72.073586, step = 16501 (0.478 sec)
# INFO:tensorflow:global_step/sec: 161.717
# INFO:tensorflow:loss = 81.97604, step = 16601 (0.619 sec)
# INFO:tensorflow:global_step/sec: 112.544
# INFO:tensorflow:loss = 85.84026, step = 16701 (0.888 sec)
# INFO:tensorflow:global_step/sec: 173.175
# INFO:tensorflow:loss = 68.25799, step = 16801 (0.578 sec)
# INFO:tensorflow:global_step/sec: 159.666
# INFO:tensorflow:loss = 111.90373, step = 16901 (0.627 sec)
# INFO:tensorflow:Saving checkpoints for 17000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:47:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-17000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:47:49
# INFO:tensorflow:Saving dict for global step 17000: global_step = 17000, loss = 49.687798
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17000: ./workspace/models/cooc2emb-01/model.ckpt-17000
# INFO:tensorflow:global_step/sec: 64.1871
# INFO:tensorflow:loss = 76.23258, step = 17001 (1.557 sec)
# INFO:tensorflow:global_step/sec: 161.743
# INFO:tensorflow:loss = 122.71914, step = 17101 (0.619 sec)
# INFO:tensorflow:global_step/sec: 189.06
# INFO:tensorflow:loss = 76.01202, step = 17201 (0.528 sec)
# INFO:tensorflow:global_step/sec: 189.888
# INFO:tensorflow:loss = 65.13731, step = 17301 (0.527 sec)
# INFO:tensorflow:global_step/sec: 243.39
# INFO:tensorflow:loss = 100.023285, step = 17401 (0.410 sec)
# INFO:tensorflow:global_step/sec: 228.643
# INFO:tensorflow:loss = 72.787605, step = 17501 (0.437 sec)
# INFO:tensorflow:global_step/sec: 248.518
# INFO:tensorflow:loss = 62.92665, step = 17601 (0.402 sec)
# INFO:tensorflow:global_step/sec: 254.714
# INFO:tensorflow:loss = 86.24591, step = 17701 (0.393 sec)
# INFO:tensorflow:global_step/sec: 240.943
# INFO:tensorflow:loss = 55.37762, step = 17801 (0.416 sec)
# INFO:tensorflow:global_step/sec: 210.782
# INFO:tensorflow:loss = 92.25747, step = 17901 (0.474 sec)
# INFO:tensorflow:Saving checkpoints for 18000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:47:54Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-18000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:47:54
# INFO:tensorflow:Saving dict for global step 18000: global_step = 18000, loss = 52.553753
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18000: ./workspace/models/cooc2emb-01/model.ckpt-18000
# INFO:tensorflow:global_step/sec: 61.7338
# INFO:tensorflow:loss = 84.03018, step = 18001 (1.620 sec)
# INFO:tensorflow:global_step/sec: 211.705
# INFO:tensorflow:loss = 85.17458, step = 18101 (0.472 sec)
# INFO:tensorflow:global_step/sec: 214.152
# INFO:tensorflow:loss = 85.09501, step = 18201 (0.467 sec)
# INFO:tensorflow:global_step/sec: 220.286
# INFO:tensorflow:loss = 109.69714, step = 18301 (0.454 sec)
# INFO:tensorflow:global_step/sec: 155.019
# INFO:tensorflow:loss = 62.44353, step = 18401 (0.645 sec)
# INFO:tensorflow:global_step/sec: 219.991
# INFO:tensorflow:loss = 86.702614, step = 18501 (0.455 sec)
# INFO:tensorflow:global_step/sec: 209.615
# INFO:tensorflow:loss = 53.86373, step = 18601 (0.477 sec)
# INFO:tensorflow:global_step/sec: 221.329
# INFO:tensorflow:loss = 53.96476, step = 18701 (0.452 sec)
# INFO:tensorflow:global_step/sec: 197.089
# INFO:tensorflow:loss = 77.96291, step = 18801 (0.510 sec)
# INFO:tensorflow:global_step/sec: 209.093
# INFO:tensorflow:loss = 110.61129, step = 18901 (0.477 sec)
# INFO:tensorflow:Saving checkpoints for 19000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:48:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-19000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:48:00
# INFO:tensorflow:Saving dict for global step 19000: global_step = 19000, loss = 54.03686
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 19000: ./workspace/models/cooc2emb-01/model.ckpt-19000
# INFO:tensorflow:global_step/sec: 61.7858
# INFO:tensorflow:loss = 49.522736, step = 19001 (1.618 sec)
# INFO:tensorflow:global_step/sec: 196.101
# INFO:tensorflow:loss = 52.317482, step = 19101 (0.510 sec)
# INFO:tensorflow:global_step/sec: 218.532
# INFO:tensorflow:loss = 52.258377, step = 19201 (0.458 sec)
# INFO:tensorflow:global_step/sec: 216.037
# INFO:tensorflow:loss = 48.761524, step = 19301 (0.462 sec)
# INFO:tensorflow:global_step/sec: 226.329
# INFO:tensorflow:loss = 58.89731, step = 19401 (0.442 sec)
# INFO:tensorflow:global_step/sec: 218.541
# INFO:tensorflow:loss = 59.641304, step = 19501 (0.458 sec)
# INFO:tensorflow:global_step/sec: 217.105
# INFO:tensorflow:loss = 52.451, step = 19601 (0.461 sec)
# INFO:tensorflow:global_step/sec: 208.58
# INFO:tensorflow:loss = 57.921146, step = 19701 (0.479 sec)
# INFO:tensorflow:global_step/sec: 176.339
# INFO:tensorflow:loss = 42.933846, step = 19801 (0.567 sec)
# INFO:tensorflow:global_step/sec: 159.738
# INFO:tensorflow:loss = 52.213184, step = 19901 (0.628 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:48:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:48:07
# INFO:tensorflow:Saving dict for global step 20000: global_step = 20000, loss = 57.759243
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: ./workspace/models/cooc2emb-01/model.ckpt-20000
# INFO:tensorflow:global_step/sec: 53.511
# INFO:tensorflow:loss = 48.695896, step = 20001 (1.867 sec)
# INFO:tensorflow:global_step/sec: 200.771
# INFO:tensorflow:loss = 54.78212, step = 20101 (0.498 sec)
# INFO:tensorflow:global_step/sec: 212.572
# INFO:tensorflow:loss = 45.474518, step = 20201 (0.470 sec)
# INFO:tensorflow:global_step/sec: 217.725
# INFO:tensorflow:loss = 59.651257, step = 20301 (0.459 sec)
# INFO:tensorflow:global_step/sec: 216.134
# INFO:tensorflow:loss = 72.50078, step = 20401 (0.463 sec)
# INFO:tensorflow:global_step/sec: 220.694
# INFO:tensorflow:loss = 64.53343, step = 20501 (0.453 sec)
# INFO:tensorflow:global_step/sec: 215.538
# INFO:tensorflow:loss = 88.5863, step = 20601 (0.464 sec)
# INFO:tensorflow:global_step/sec: 221.49
# INFO:tensorflow:loss = 64.44973, step = 20701 (0.451 sec)
# INFO:tensorflow:global_step/sec: 213.183
# ...
# INFO:tensorflow:loss = 66.19406, step = 22201 (0.462 sec)
# INFO:tensorflow:global_step/sec: 225.601
# INFO:tensorflow:loss = 73.45271, step = 22301 (0.443 sec)
# INFO:tensorflow:global_step/sec: 237.316
# INFO:tensorflow:loss = 69.72717, step = 22401 (0.422 sec)
# INFO:tensorflow:global_step/sec: 216.882
# INFO:tensorflow:loss = 60.400604, step = 22501 (0.460 sec)
# INFO:tensorflow:global_step/sec: 254.078
# INFO:tensorflow:loss = 51.556335, step = 22601 (0.393 sec)
# INFO:tensorflow:global_step/sec: 243.935
# INFO:tensorflow:loss = 66.5056, step = 22701 (0.410 sec)
# INFO:tensorflow:global_step/sec: 247.825
# INFO:tensorflow:loss = 63.059235, step = 22801 (0.403 sec)
# INFO:tensorflow:global_step/sec: 241.47
# INFO:tensorflow:loss = 76.47255, step = 22901 (0.418 sec)
# INFO:tensorflow:Saving checkpoints for 23000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:48:24Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-23000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:48:24
# INFO:tensorflow:Saving dict for global step 23000: global_step = 23000, loss = 39.580837
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 23000: ./workspace/models/cooc2emb-01/model.ckpt-23000
# INFO:tensorflow:global_step/sec: 60.7134
# INFO:tensorflow:loss = 57.75789, step = 23001 (1.644 sec)
# INFO:tensorflow:global_step/sec: 237.25
# INFO:tensorflow:loss = 68.791115, step = 23101 (0.421 sec)
# INFO:tensorflow:global_step/sec: 267.941
# INFO:tensorflow:loss = 47.222908, step = 23201 (0.373 sec)
# INFO:tensorflow:global_step/sec: 251.15
# INFO:tensorflow:loss = 56.134106, step = 23301 (0.398 sec)
# INFO:tensorflow:global_step/sec: 253.537
# INFO:tensorflow:loss = 50.45808, step = 23401 (0.394 sec)
# INFO:tensorflow:global_step/sec: 267.647
# INFO:tensorflow:loss = 63.370277, step = 23501 (0.374 sec)
# INFO:tensorflow:global_step/sec: 253.677
# INFO:tensorflow:loss = 53.98537, step = 23601 (0.394 sec)
# INFO:tensorflow:global_step/sec: 259.444
# INFO:tensorflow:loss = 76.65022, step = 23701 (0.386 sec)
# INFO:tensorflow:global_step/sec: 261.641
# INFO:tensorflow:loss = 60.749264, step = 23801 (0.382 sec)
# INFO:tensorflow:global_step/sec: 249.913
# INFO:tensorflow:loss = 41.758717, step = 23901 (0.400 sec)
# INFO:tensorflow:Saving checkpoints for 24000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:48:29Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-24000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:48:29
# INFO:tensorflow:Saving dict for global step 24000: global_step = 24000, loss = 29.725952
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 24000: ./workspace/models/cooc2emb-01/model.ckpt-24000
# INFO:tensorflow:global_step/sec: 66.5254
# INFO:tensorflow:loss = 48.128746, step = 24001 (1.504 sec)
# INFO:tensorflow:global_step/sec: 205.571
# INFO:tensorflow:loss = 66.29514, step = 24101 (0.486 sec)
# INFO:tensorflow:global_step/sec: 221.822
# INFO:tensorflow:loss = 63.634575, step = 24201 (0.450 sec)
# INFO:tensorflow:global_step/sec: 213.445
# INFO:tensorflow:loss = 65.10395, step = 24301 (0.469 sec)
# INFO:tensorflow:global_step/sec: 202.682
# INFO:tensorflow:loss = 60.918156, step = 24401 (0.493 sec)
# INFO:tensorflow:global_step/sec: 207.992
# INFO:tensorflow:loss = 50.965935, step = 24501 (0.481 sec)
# INFO:tensorflow:global_step/sec: 200.937
# INFO:tensorflow:loss = 43.795334, step = 24601 (0.498 sec)
# INFO:tensorflow:global_step/sec: 207.785
# INFO:tensorflow:loss = 51.852196, step = 24701 (0.482 sec)
# INFO:tensorflow:global_step/sec: 202.362
# INFO:tensorflow:loss = 47.90438, step = 24801 (0.494 sec)
# INFO:tensorflow:global_step/sec: 190.191
# INFO:tensorflow:loss = 48.01472, step = 24901 (0.526 sec)
# INFO:tensorflow:Saving checkpoints for 25000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:48:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:48:35
# INFO:tensorflow:Saving dict for global step 25000: global_step = 25000, loss = 32.27624
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 25000: ./workspace/models/cooc2emb-01/model.ckpt-25000
# INFO:tensorflow:global_step/sec: 59.1411
# INFO:tensorflow:loss = 52.213284, step = 25001 (1.691 sec)
# INFO:tensorflow:global_step/sec: 184.334
# INFO:tensorflow:loss = 48.475887, step = 25101 (0.542 sec)
# INFO:tensorflow:global_step/sec: 221.117
# INFO:tensorflow:loss = 72.548195, step = 25201 (0.452 sec)
# INFO:tensorflow:global_step/sec: 216.735
# INFO:tensorflow:loss = 53.701, step = 25301 (0.462 sec)
# INFO:tensorflow:global_step/sec: 209.02
# INFO:tensorflow:loss = 39.157948, step = 25401 (0.479 sec)
# INFO:tensorflow:global_step/sec: 211.737
# INFO:tensorflow:loss = 68.87771, step = 25501 (0.472 sec)
# INFO:tensorflow:global_step/sec: 222.413
# INFO:tensorflow:loss = 77.05466, step = 25601 (0.450 sec)
# INFO:tensorflow:global_step/sec: 214.909
# INFO:tensorflow:loss = 57.435314, step = 25701 (0.465 sec)
# INFO:tensorflow:global_step/sec: 218.914
# INFO:tensorflow:loss = 65.060844, step = 25801 (0.457 sec)
# INFO:tensorflow:global_step/sec: 185.968
# INFO:tensorflow:loss = 55.56697, step = 25901 (0.538 sec)
# INFO:tensorflow:Saving checkpoints for 26000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:48:42Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-26000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:48:43
# INFO:tensorflow:Saving dict for global step 26000: global_step = 26000, loss = 37.42558
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 26000: ./workspace/models/cooc2emb-01/model.ckpt-26000
# INFO:tensorflow:global_step/sec: 30.4095
# INFO:tensorflow:loss = 64.922226, step = 26001 (3.289 sec)
# INFO:tensorflow:global_step/sec: 219.122
# INFO:tensorflow:loss = 71.99718, step = 26101 (0.456 sec)
# INFO:tensorflow:global_step/sec: 210.659
# INFO:tensorflow:loss = 49.618362, step = 26201 (0.474 sec)
# INFO:tensorflow:global_step/sec: 205.412
# INFO:tensorflow:loss = 62.008522, step = 26301 (0.487 sec)
# INFO:tensorflow:global_step/sec: 225.389
# INFO:tensorflow:loss = 83.75003, step = 26401 (0.443 sec)
# INFO:tensorflow:global_step/sec: 246.757
# INFO:tensorflow:loss = 66.88526, step = 26501 (0.405 sec)
# INFO:tensorflow:global_step/sec: 248.4
# INFO:tensorflow:loss = 65.408165, step = 26601 (0.403 sec)
# INFO:tensorflow:global_step/sec: 239.748
# INFO:tensorflow:loss = 48.408504, step = 26701 (0.417 sec)
# INFO:tensorflow:global_step/sec: 250.606
# INFO:tensorflow:loss = 69.86278, step = 26801 (0.399 sec)
# INFO:tensorflow:global_step/sec: 241.937
# INFO:tensorflow:loss = 59.93508, step = 26901 (0.413 sec)
# INFO:tensorflow:Saving checkpoints for 27000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:48:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-27000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:48:48
# INFO:tensorflow:Saving dict for global step 27000: global_step = 27000, loss = 40.497723
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 27000: ./workspace/models/cooc2emb-01/model.ckpt-27000
# INFO:tensorflow:global_step/sec: 65.6049
# INFO:tensorflow:loss = 53.60815, step = 27001 (1.524 sec)
# INFO:tensorflow:global_step/sec: 201.883
# INFO:tensorflow:loss = 53.004105, step = 27101 (0.496 sec)
# INFO:tensorflow:global_step/sec: 231.088
# INFO:tensorflow:loss = 48.078136, step = 27201 (0.432 sec)
# INFO:tensorflow:global_step/sec: 230.771
# INFO:tensorflow:loss = 48.47184, step = 27301 (0.433 sec)
# INFO:tensorflow:global_step/sec: 247.316
# INFO:tensorflow:loss = 55.122482, step = 27401 (0.404 sec)
# INFO:tensorflow:global_step/sec: 215.83
# INFO:tensorflow:loss = 82.55761, step = 27501 (0.464 sec)
# INFO:tensorflow:global_step/sec: 206.68
# INFO:tensorflow:loss = 54.35909, step = 27601 (0.484 sec)
# INFO:tensorflow:global_step/sec: 207.253
# INFO:tensorflow:loss = 72.018684, step = 27701 (0.482 sec)
# INFO:tensorflow:global_step/sec: 209.322
# INFO:tensorflow:loss = 62.591255, step = 27801 (0.478 sec)
# INFO:tensorflow:global_step/sec: 207.245
# INFO:tensorflow:loss = 51.877407, step = 27901 (0.482 sec)
# INFO:tensorflow:Saving checkpoints for 28000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:48:54Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-28000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:48:54
# INFO:tensorflow:Saving dict for global step 28000: global_step = 28000, loss = 41.827663
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 28000: ./workspace/models/cooc2emb-01/model.ckpt-28000
# INFO:tensorflow:global_step/sec: 54.2732
# INFO:tensorflow:loss = 44.20539, step = 28001 (1.843 sec)
# INFO:tensorflow:global_step/sec: 196.711
# INFO:tensorflow:loss = 56.479603, step = 28101 (0.508 sec)
# INFO:tensorflow:global_step/sec: 223.783
# INFO:tensorflow:loss = 50.366367, step = 28201 (0.447 sec)
# INFO:tensorflow:global_step/sec: 216.447
# INFO:tensorflow:loss = 45.24392, step = 28301 (0.462 sec)
# INFO:tensorflow:global_step/sec: 222.733
# INFO:tensorflow:loss = 42.100204, step = 28401 (0.449 sec)
# INFO:tensorflow:global_step/sec: 215.337
# INFO:tensorflow:loss = 46.764065, step = 28501 (0.464 sec)
# INFO:tensorflow:global_step/sec: 222.995
# INFO:tensorflow:loss = 41.588303, step = 28601 (0.448 sec)
# INFO:tensorflow:global_step/sec: 221.235
# INFO:tensorflow:loss = 55.334026, step = 28701 (0.452 sec)
# INFO:tensorflow:global_step/sec: 226.084
# INFO:tensorflow:loss = 48.13242, step = 28801 (0.442 sec)
# INFO:tensorflow:global_step/sec: 223.409
# INFO:tensorflow:loss = 79.12752, step = 28901 (0.448 sec)
# INFO:tensorflow:Saving checkpoints for 29000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:49:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-29000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:49:00
# INFO:tensorflow:Saving dict for global step 29000: global_step = 29000, loss = 40.92314
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 29000: ./workspace/models/cooc2emb-01/model.ckpt-29000
# INFO:tensorflow:global_step/sec: 56.555
# INFO:tensorflow:loss = 51.070713, step = 29001 (1.768 sec)
# INFO:tensorflow:global_step/sec: 206.415
# INFO:tensorflow:loss = 42.836803, step = 29101 (0.485 sec)
# INFO:tensorflow:global_step/sec: 216.581
# INFO:tensorflow:loss = 56.2931, step = 29201 (0.462 sec)
# INFO:tensorflow:global_step/sec: 180.083
# INFO:tensorflow:loss = 49.86462, step = 29301 (0.556 sec)
# INFO:tensorflow:global_step/sec: 198.602
# INFO:tensorflow:loss = 69.960365, step = 29401 (0.503 sec)
# INFO:tensorflow:global_step/sec: 190.186
# INFO:tensorflow:loss = 53.347416, step = 29501 (0.526 sec)
# INFO:tensorflow:global_step/sec: 204.039
# INFO:tensorflow:loss = 87.608284, step = 29601 (0.490 sec)
# INFO:tensorflow:global_step/sec: 190.589
# INFO:tensorflow:loss = 50.301926, step = 29701 (0.525 sec)
# INFO:tensorflow:global_step/sec: 189.754
# INFO:tensorflow:loss = 48.48297, step = 29801 (0.528 sec)
# INFO:tensorflow:global_step/sec: 193.149
# INFO:tensorflow:loss = 51.37583, step = 29901 (0.517 sec)
# INFO:tensorflow:Saving checkpoints for 30000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 4618 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 4618 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-28T14:49:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-30000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-28-14:49:06
# INFO:tensorflow:Saving dict for global step 30000: global_step = 30000, loss = 42.27002
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 30000: ./workspace/models/cooc2emb-01/model.ckpt-30000
# INFO:tensorflow:Loss for final step: 50.745518.
# .......................................
# Experiment finished at 13:49:06
#
# Experiment elapsed time: 180.333395 seconds

# %% [markdown]
# ## 8. Extract Word embeddings

# %%
def extract_embeddings():
    
    with tf.Session() as sess:
        saver = tf.train.import_meta_graph(os.path.join(model_dir, 'model.ckpt-{}.meta'.format(params.traning_steps)))
        saver.restore(sess, os.path.join(model_dir, 'model.ckpt-{}'.format(params.traning_steps)))
        graph = tf.get_default_graph()
        weights_tensor = graph.get_tensor_by_name('input_layer_1/item2_embedding/embedding_weights:0')
        weights = np.array(sess.run(weights_tensor))

    return weights

# %%
embeddings = extract_embeddings()
print(len(embeddings))
print(embeddings[0])
# Out:
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-30000
# 4618
# [-1.62278153e-02  8.35192669e-03  6.37334958e-02 -7.49534443e-02
#  -5.90263829e-02 -1.98351722e-02  2.44442914e-02  4.09853049e-02
#  -1.63244009e-01 -1.00082673e-01  1.88681215e-01  1.36155501e-01
#   4.47690189e-02  8.76321867e-02  1.43647134e-01  1.22811340e-01
#   1.12567902e-01 -4.14417386e-02  8.52247477e-02 -4.53575291e-02
#   1.25810191e-01  5.29873855e-02 -6.09087311e-02 -5.50278611e-02
#  -3.59600633e-02 -9.22060683e-02 -2.23044003e-03  1.50493518e-01
#  -1.47038862e-01 -2.06213906e-01 -7.73831382e-02 -3.29067148e-02
#  -7.39928335e-02  1.62057698e-01 -3.79122123e-02  6.15024455e-02
#   3.83931510e-02  2.13978380e-01  1.44554079e-01  5.28540574e-02
#   2.23463103e-02  8.26468244e-02 -3.66577767e-02  3.64660248e-02
#  -1.31757438e-01 -3.34521569e-02  8.68275166e-02  8.15316290e-03
#  -1.66728690e-01  4.85628545e-02 -1.59075826e-01  1.51271209e-01
#   5.37051633e-02  1.61711991e-01  5.98695874e-02  1.47865608e-01
#   2.17810124e-01 -1.10231638e-01  1.86903417e-01 -1.80809528e-01
#  -7.49192759e-02  1.31206810e-01 -9.65925008e-02 -1.05005972e-01
#  -7.02184960e-02 -1.33302566e-02 -1.35760546e-01  9.26273037e-03
#   3.88726555e-02  9.49632451e-02 -8.59845430e-02  1.32083714e-01
#   9.69963323e-04 -9.30874571e-02 -7.11770803e-02 -1.81946322e-01
#  -1.25662148e-01  1.22365177e-01  5.92569746e-02 -2.14287803e-01
#  -7.68036023e-02 -1.70375258e-02  5.02373017e-02 -6.25884458e-02
#  -1.62138149e-01  2.60828938e-02 -2.09069252e-01  3.18163037e-02
#  -8.87508243e-02 -2.92841811e-03  1.35850802e-01  2.03303322e-02
#  -8.95440876e-02 -7.84900039e-02  1.00041330e-02 -7.10473284e-02
#  -1.28400922e-01 -3.63092241e-03 -2.86436621e-02  5.69684841e-02
#   1.64936006e-01  6.22732053e-03 -1.44074215e-02  2.04105482e-01
#   7.71432593e-02 -1.98392078e-01 -1.67059060e-02 -4.35808748e-02
#  -7.77396858e-02  7.12290555e-02  2.15911984e-01  1.05758920e-01
#   1.42211467e-01  4.99001369e-02  9.35247913e-02  1.21496335e-01
#  -3.77762951e-02  2.08138376e-02  8.61427560e-02 -1.47668615e-01
#   1.19178258e-01  1.65285140e-01  1.91097468e-01  1.98946713e-04
#   1.50197744e-01  1.29202530e-01 -5.86500652e-02  1.60378981e-02]

# %%
vocab_path = os.path.join(COOC_DIR,'vocab.txt')
output_path = os.path.join(WORKSPACE,'embeddings.tsv')

def write_embeddings_to_tsv():
    with open(output_path, 'w') as out_f:
        with open(vocab_path) as vocab_f:
            for index, item in enumerate(vocab_f):
                embedding = embeddings[index]
                print('\t'.join([item.strip()] + [str(x) for x in embedding]), file=out_f)
                
write_embeddings_to_tsv()

# %%
# !head {output_path}
# Out:
# sum	-0.016227815	0.008351927	0.063733496	-0.074953444	-0.059026383	-0.019835172	0.024444291	0.040985305	-0.16324401	-0.10008267	0.18868122	0.1361555	0.04476902	0.08763219	0.14364713	0.12281134	0.1125679	-0.04144174	0.08522475	-0.04535753	0.12581019	0.052987386	-0.06090873	-0.05502786	-0.035960063	-0.09220607	-0.00223044	0.15049352	-0.14703886	-0.2062139	-0.07738314	-0.032906715	-0.07399283	0.1620577	-0.037912212	0.061502445	0.03839315	0.21397838	0.14455408	0.052854057	0.02234631	0.082646824	-0.036657777	0.036466025	-0.13175744	-0.033452157	0.08682752	0.008153163	-0.16672869	0.048562855	-0.15907583	0.15127121	0.053705163	0.16171199	0.059869587	0.14786561	0.21781012	-0.11023164	0.18690342	-0.18080953	-0.074919276	0.13120681	-0.0965925	-0.10500597	-0.070218496	-0.013330257	-0.13576055	0.00926273	0.038872655	0.094963245	-0.08598454	0.13208371	0.0009699633	-0.09308746	-0.07117708	-0.18194632	-0.12566215	0.12236518	0.059256975	-0.2142878	-0.0768036	-0.017037526	0.0502373	-0.062588446	-0.16213815	0.026082894	-0.20906925	0.031816304	-0.088750824	-0.002928418	0.1358508	0.020330332	-0.08954409	-0.078490004	0.010004133	-0.07104733	-0.12840092	-0.0036309224	-0.028643662	0.056968484	0.164936	0.0062273205	-0.014407421	0.20410548	0.07714326	-0.19839208	-0.016705906	-0.043580875	-0.077739686	0.071229056	0.21591198	0.10575892	0.14221147	0.049900137	0.09352479	0.121496335	-0.037776295	0.020813838	0.086142756	-0.14766861	0.11917826	0.16528514	0.19109747	0.00019894671	0.15019774	0.12920253	-0.058650065	0.016037898
# cocoa	0.15678877	0.20189242	0.02462687	-0.14184925	-0.061700143	-0.1328613	0.131543	0.055212032	0.00950254	-0.06115278	-0.11918371	0.17711952	0.21941583	0.11925065	-0.06399558	-0.015395551	-0.014538366	0.07495966	0.16479643	0.059685238	0.14845711	0.053749282	-0.014431721	0.13085221	0.08446795	-0.11220647	0.10140727	-0.03445791	-0.12958242	-0.3097914	0.3236723	0.062918805	-0.06509114	-0.04238771	0.16094917	-0.109888926	-0.04701111	-0.062282685	0.056563962	0.022861408	-0.08386754	-0.1355483	-0.08814279	0.02219509	-0.07512718	-0.01805568	0.1956264	0.06737957	-0.23157188	-0.18005233	-0.1579019	0.022442412	0.14498834	0.05440641	0.19785032	0.027600959	0.060266044	-0.18304147	-0.13131402	-0.084319755	-0.10270203	-0.07587683	-0.2626924	-0.06306824	-0.051139332	-0.2585218	-0.027456002	0.03641099	0.071565524	-0.09120515	-0.11330065	0.057156116	0.009723439	0.009942948	-0.059018563	-0.2447595	-0.14858374	-0.06882205	0.09601772	0.03476151	-0.009661124	0.18912697	0.032468114	-0.022175094	-0.05383194	-0.024671659	-0.048344333	-0.038593333	0.132749	0.1264168	-0.08292547	-0.12710564	0.0048909523	0.048507236	-0.103701495	0.020170487	-0.26749185	-0.026559595	-0.22205031	0.08072652	-0.10819935	-0.17807756	-0.17365447	0.020206036	-0.16859743	0.1376663	0.042536575	-0.031483844	0.21424602	0.08232388	-0.108059876	-0.033368785	-0.13993667	0.021808458	-0.2516193	-0.10238091	0.015365849	0.036832873	-0.084888764	-0.07802984	0.19929725	-0.035203457	0.15963928	0.13672946	0.045911223	0.29728895	0.08601384	-0.27933615
# introduced	-0.120785095	-0.041908562	0.015407336	-0.04810179	-0.12525132	-0.082497664	0.039437965	0.055956885	0.20071372	-0.19482885	-0.2184596	0.14260577	-0.008088712	-0.1202145	0.030169379	0.018849218	0.13078584	0.06745855	0.14758033	-0.15941095	0.028698573	0.04051296	-0.19893037	0.019211495	0.026989631	0.05953988	-0.081705965	0.057259295	0.04402736	0.04144636	0.10929711	-0.11998064	-0.026477206	-0.0013904783	0.16826425	-0.29278004	0.17870116	0.12073755	0.24074572	-0.10029652	0.27174607	-0.028114196	0.011506468	0.11009233	0.04342459	-0.16800179	0.1509493	0.104104415	0.034723092	-0.04319732	-0.10050402	0.2036098	0.012552722	0.021987874	-0.01978041	0.017816875	-0.07824396	-0.010890646	0.19115445	0.04972576	-0.12791842	-0.103515334	-0.22027369	0.07721265	0.021563219	0.0013445045	-0.04615101	-0.13470969	-0.057207048	-0.1850778	0.21108815	0.15297478	-0.043424074	-0.21330689	-0.018438337	-0.10923052	-0.18909414	0.061540343	-0.098655656	0.014868539	0.09394669	0.06732572	0.20470092	-0.05991871	-0.07580077	-0.070014335	-0.02521846	-0.06284319	-0.1515704	-0.057149734	0.1033624	-0.101656124	0.07890027	0.22578545	-0.20218562	0.09272672	-0.077879995	-0.11687026	-0.09004766	0.066587865	0.22256234	-0.12812608	-0.10956763	0.1006068	0.07692698	-0.029337138	-0.12790322	-0.05831705	0.025325308	0.117665224	0.15190902	-0.15925181	0.021141982	0.04973393	0.06519893	0.077991076	0.12841156	-0.06500591	0.023323715	-0.04336085	-0.04004108	0.04664416	0.2795903	0.15969332	-0.07613052	0.070817634	0.103407055	0.21154676
# ride	0.12044683	-0.031469762	0.037280075	0.11486163	0.010025102	0.12124384	0.070725	0.10471809	-0.1069158	-0.021925516	0.018526256	0.056547437	0.06164586	0.084880926	0.04864915	0.04251641	0.048343927	0.067469	-0.036013335	-0.053734493	0.15098763	-0.11905263	-0.11053489	-0.016412085	-0.08562377	0.16190106	-0.0024698928	0.047126573	-0.105064824	-0.07279837	0.13345352	-0.01848352	0.034789868	0.11933385	0.10029973	-0.18048123	0.07974894	-0.0053130384	0.10582071	-0.027218875	0.22402902	-0.11346902	0.08267208	0.16078892	-0.09726501	-0.066444956	-0.10635291	-0.021645136	0.012357183	0.116234764	-0.06560927	0.0014145585	0.13292235	0.10162445	0.09268906	0.06782739	0.064269334	-0.12720762	0.08129767	0.16496637	-0.1783316	0.0046433415	0.052388962	-0.0635953	0.018549316	-0.093168765	-0.1575649	0.075481616	-0.15875795	0.17504677	0.16930418	0.14593999	0.15536863	0.021725077	0.0033596682	0.0099064065	-0.20964082	0.05348916	0.003563242	0.0855872	0.021576487	-0.05056827	0.26409897	0.0031330679	-0.011406685	0.003092931	-0.055089694	0.18271963	-0.12991038	0.028801197	-0.0070819785	-0.30675694	-0.027011551	0.0038928702	-0.08559987	-0.16147967	0.024937524	-0.11374774	-0.11779932	0.015020049	0.24045785	-0.11726632	0.22064868	-0.0033836747	0.10837696	-0.12519608	-0.06399831	-0.03206301	-0.025473766	0.15605567	0.17852576	0.17385104	0.010969205	-0.020254076	-0.0003455396	-0.061298188	-0.08420128	0.027646134	-0.018201888	-0.08440973	0.06701275	0.2284334	0.0037474902	0.08718812	0.16724159	0.12814955	0.06503015	0.006330103
# trespass	-0.23632851	-0.033582486	0.043991715	-0.066619284	0.11266938	0.07929865	0.05062796	0.04143586	-0.16923176	-0.10653849	-0.18962237	-0.02060705	0.015691664	0.09814198	0.06751919	-0.123806044	0.16143246	-0.0018314339	-0.017548256	-0.15015766	-0.029972067	0.061442994	0.045384374	0.14837034	0.050193075	-0.16436625	0.06062015	-0.085488655	-0.072660625	-0.13666664	0.013217668	0.066868566	0.072180286	0.13158818	0.13839707	0.15732665	0.063417494	0.101903096	-0.05403653	0.037755933	-0.014428007	-0.10183019	0.066035286	0.14061792	0.03738516	0.03067624	0.022470463	-0.14290239	-0.10104307	-0.037731394	0.1256734	0.2691783	0.02562533	0.19249664	-0.034112	-0.008296104	0.028424606	-0.2000132	0.029109707	-0.0436679	-0.2011818	-0.19620186	-0.05744745	0.06818025	-0.13403894	0.013277196	-0.032348875	0.016861964	-0.093672164	0.12304288	-0.05483387	0.16985671	0.08575838	-0.05174421	-0.26779464	-0.05734396	0.25543135	-0.12584421	0.044745047	-0.11999352	0.16308121	0.045797847	0.050876953	-0.18104914	-0.13761489	0.24712668	0.029737085	0.12680615	0.019402148	0.060500395	-0.13090234	-0.22867417	-0.04907577	-0.12221602	0.035181142	-0.086851336	-0.10876468	-0.06441361	-0.18501064	-0.102050066	0.06884263	0.003169954	0.22360331	0.10064888	-0.079747766	0.049145877	-0.22897002	-0.026100611	-0.046749108	-0.13787922	0.11543759	-0.017201008	0.26716554	0.20927913	-0.15736105	0.028093794	0.013273035	-0.06605771	-0.04279049	-0.08931312	0.09666165	-0.013730066	-0.12383275	0.13434286	0.050351623	0.042170092	-0.051318277	-0.1648823
# might	0.034321196	-0.07511591	0.0062059225	0.09252489	-0.23824513	0.1483776	-0.14504576	0.18383402	-0.10065231	-0.10179766	0.04788534	0.065073654	0.020514613	-0.06094867	0.01950456	0.10387967	-0.16128616	-0.039830264	0.05176196	0.1238782	-0.10708224	0.19059005	-0.035576656	-0.07023761	0.05489442	0.039067116	0.16895385	0.08672015	0.0759878	0.042342313	0.010187586	0.1424823	-0.032445133	0.051704522	0.059504397	0.020282531	-0.054145113	-0.06341834	-0.006781871	-0.0286931	-0.0030881495	-0.02473061	-0.11042486	-0.08303377	0.11193976	0.05346553	-0.10920613	-0.09045345	0.18942934	0.017323293	0.047643032	0.157167	0.022355495	-0.027002404	0.1289247	0.16182123	-0.12448819	0.1547549	-0.14320071	0.053649098	-0.15725297	-0.22831094	0.010069106	0.020545324	0.07971159	-0.00750865	0.09420425	0.13225183	-0.11899551	0.047147844	-0.13135159	0.099837124	-0.03991998	-0.111303225	-0.033516977	-0.23910862	-0.055363923	-0.099325284	-0.009843311	0.015095205	-0.11283492	0.007887563	-0.068385616	0.12180002	0.048192192	-0.06220705	0.14001118	0.16499949	0.06604286	-0.08951001	-0.07520022	0.05902792	-0.036889307	-0.2755087	0.021253137	-0.03658448	-0.06757574	-0.06868056	0.07084082	-0.12314971	0.02133602	0.020523323	-0.0037123987	0.047562044	-0.007875879	0.05276776	-0.15625587	0.03556045	0.014746135	-0.002642872	0.0750679	-0.09733313	-0.02166828	-0.1504503	-0.06114547	0.022813769	0.017425906	0.017399682	-0.126188	-0.06033703	-8.915329e-05	-0.07332769	-0.03981847	0.12703407	-0.0069058156	-0.10099555	-0.05955369	0.072310165
# fabrics	-0.062467664	0.005485449	-0.17785491	-0.070033	0.018904027	0.16701771	-0.026640669	0.13668005	-0.24697782	-0.07642923	0.042838167	-0.06527772	0.25746748	-0.13299182	0.031174788	0.019514509	0.29821235	-0.019197827	-0.10364397	0.052373912	0.03541217	-0.17824444	-0.042314295	0.082125105	-0.0052073523	0.124020755	-0.16447593	-0.023263823	0.2991194	-0.017571298	-0.013842552	0.3483789	0.0013586421	0.024358375	0.09254719	-0.10122844	0.21096708	-0.081146516	0.051454175	-0.001707384	0.14471893	-0.17364438	0.24255137	0.07500832	-0.104590714	0.05041931	-0.0025302172	-0.1253429	-0.1477403	-0.04858788	0.0011820327	-0.050675478	-0.029478386	0.15536283	0.037166554	0.015668584	0.15656054	-0.10518397	0.0044838553	-0.05656672	0.17264023	-0.13572782	-0.071034685	-0.21553768	-0.00606179	-0.021843126	-0.100236036	-0.009596119	0.16371246	-0.09674992	0.0568717	-0.014990641	-0.08442662	-0.007097596	-0.054381263	-0.06250651	0.13834189	0.29841077	0.12696034	0.09051056	0.011048443	0.23630248	-0.03323685	0.15206656	-0.021384891	-0.100692436	-0.019336127	0.12713955	-0.14979294	-0.065090984	0.11425599	0.008299992	-0.1354053	0.2259788	-0.11792781	0.19595993	-0.21108411	-0.09881505	-0.059282772	0.06563731	-0.13082415	-0.14459792	0.15201016	-0.08584661	-0.17498858	0.030106327	0.09123685	0.13487613	0.12768486	-0.18031587	-0.1559908	0.19538178	-0.26297602	-0.046197988	0.12640601	-0.120320484	-0.109653346	-0.23297624	-0.14121915	-0.14507192	0.21596019	0.03159105	0.21373884	0.044267677	0.21409307	0.23653655	0.17938872	-0.09988838
# thoris	0.012896392	0.02680538	0.13691509	0.115887925	-0.21266611	-0.0015765544	-0.20069502	-0.047932442	0.043340847	-0.08145109	0.03667213	0.21984163	0.094363056	-0.03467988	0.17664675	-0.019826306	0.033621892	0.18618746	0.26797938	0.024236634	-0.037423052	0.14179826	0.03074495	0.07974826	0.12805791	0.2668622	-0.15495922	0.26217097	0.11595846	0.13057417	-0.18021831	0.08689071	-0.058984686	0.12681635	0.17538989	0.060780227	-0.021220405	-0.048916057	-0.21693693	-0.2369941	0.13405602	0.020520067	0.1402783	0.07693004	0.17020941	0.1164101	0.0614844	0.04127522	-0.036629573	0.065210916	-0.02911263	0.0651727	0.12190488	0.019212712	0.100656286	0.15896928	0.17570946	-0.09041252	0.15076122	-0.05926213	-0.19035897	-0.05089107	-0.08174011	0.17385258	-0.160415	-0.24669255	0.121660836	0.034016807	0.0019170434	0.027259625	0.0829497	0.04578773	0.15600473	0.059193272	-0.20365955	-0.089842476	-0.30768415	0.095112056	0.030709438	-0.011017016	-0.13213535	0.016444914	0.16763324	-0.04392304	-0.032598402	0.0035136656	-0.006634891	0.098560736	-0.023589745	-0.16451657	0.07633708	-0.07828139	0.0048831957	-0.029577743	0.06371051	-0.24469092	-0.15181135	-0.15963885	-0.07799096	0.18271281	-0.023697067	-0.07582793	0.012134018	-0.007613233	-0.12096697	-0.23566258	-0.06443422	-0.16753756	0.02742768	-0.016227769	0.023001753	0.03927454	0.12423531	0.022874318	0.014157673	-0.16930325	0.22512643	0.14277175	0.11086908	0.044575185	0.21815914	-0.004266462	0.06681442	0.04424828	-0.06512871	0.056687962	0.29677358	0.074958675
# protection	0.041421104	0.005421515	-0.08126104	-0.039795928	-0.05269271	0.013206555	0.13712427	0.16644785	-0.106593885	-0.011023671	-0.09727198	0.06480992	0.11083316	-0.16705869	0.018567445	-0.014937197	0.07479024	0.07001147	0.158967	0.0758495	0.025068281	-0.13469145	-0.0137213105	0.053036626	0.074267864	0.031051734	-0.07785271	0.09669432	0.02276389	0.027708318	0.026759164	-0.05360352	-0.009573352	-0.048925295	0.19839245	-0.052150413	0.09650146	-0.011353638	0.095871516	0.10837615	0.109647535	0.12165981	-0.05945014	-0.050102275	0.015760947	-0.20357852	-0.0183505	-0.058540937	-0.09977439	0.18715812	-0.028357638	-0.04678235	0.059104234	0.20485087	0.073123194	0.09272369	0.07220002	-0.072080866	0.08147127	-0.06660887	-0.035412036	0.0074570207	-0.12444466	-0.10708638	-0.13753936	-0.00749065	-0.035734266	-0.11720068	-0.08771887	-0.08007007	-0.10611355	0.113355085	0.078964055	-0.120664164	0.114718914	-0.12600233	-0.18058236	0.025753556	0.012254621	-0.0024821488	-0.07006054	0.056427144	-0.08552852	-0.07801711	-0.039877627	-0.04387776	-0.029856488	0.22167772	-0.018320432	0.05234711	-0.08243255	-0.12880261	-0.08500613	-0.17309761	-0.035667676	0.025972698	-0.03339519	-0.052512888	-0.14013459	-0.14981195	0.13258444	-0.044926222	0.09877446	0.12960717	0.07289802	-0.013628883	-0.018757334	-0.040507264	0.09794091	0.05519123	0.15129444	0.09016239	0.16762345	-0.032095343	-0.18078008	0.18034664	-0.052714493	0.03160991	0.05979759	0.041442353	0.083891615	0.055193596	0.15000644	0.17754968	0.047728755	0.024408879	-0.099530764	0.17865391
# part	-0.10635317	-0.23538363	0.08367799	0.049299955	-0.00066102576	-0.12593229	-0.09733122	0.06499674	-0.19781305	-0.17966974	0.12651037	0.14843838	0.023084112	0.10261094	0.0053013964	-0.020639993	0.122227475	0.05040673	0.1354472	0.05233345	0.034006312	-0.051997557	0.027966592	-0.038481005	-0.2011715	0.042262536	0.08348733	-0.02094107	-0.05611868	-0.033703044	-0.11258829	0.11343553	0.058961354	0.17476876	0.11727701	-0.08145517	0.0006141732	-0.06864862	-0.15095317	-0.04327266	0.24241038	0.043896496	0.003935478	-0.015543751	-0.02389434	0.043530975	-0.110284135	-0.11669779	-0.056789506	-0.02899009	0.0008924153	0.16242449	-0.23624566	0.021491433	0.080821194	-0.147335	-0.067965634	0.16360499	0.14293736	0.062091626	-0.17742138	-0.19709733	0.06556752	0.012418556	-0.0214344	-0.15811059	-0.028583566	0.03948752	0.08250639	-0.2339944	-0.024530374	-0.12659521	0.036489964	-0.049899627	0.102694	-0.073510036	0.020923395	-0.13665114	0.20517184	-0.12281253	-0.13564527	0.14673592	-0.12728974	0.10124743	0.081450924	0.009000672	-0.018362207	0.074682325	-0.082373194	0.06289397	-0.07720597	0.121809855	-0.06442075	-0.20077322	-0.05652473	-0.05122786	0.15743794	-0.076821566	-0.0116858715	0.009692239	-0.04581199	-0.05542611	-0.001292418	-0.024013083	-0.044494674	0.11519428	-0.04775657	0.23386258	0.054811396	-0.043803334	-0.03007829	-0.086875014	-0.21974479	-0.20965017	0.02855678	-0.16206047	0.05202114	0.05268183	-0.12790574	0.037658274	-0.03918095	0.11028359	0.027974816	0.30000645	0.035504628	0.06477725	0.13234214	0.10387723
