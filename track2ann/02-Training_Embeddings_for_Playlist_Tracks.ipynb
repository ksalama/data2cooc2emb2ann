# %% [markdown]
# # Training Embeddings for Playlist Tracks
#
# This tutorial shows how to learn **item embeddings** from co-occurrence statistics.
#
# We use the following model architecture, a long with the conditional cost function used by the [Swivel](https://arxiv.org/pdf/1602.02215.pdf) algorithm.
#
# The learnt embeddings are then extracted from the model and saved as TSV file.
#
# <img src="cooc2emb.png" width="600" height="400"/>
#
# The following are the steps of this tutorial:
#
#
# 1. Define input data metadata
# 2. Implement data input function
# 3. Create feature columns
# 4. Create a custome estimator
# 5. Define the train and evaluate experiment
# 6. Set the experiment parameters
# 7. Run the experiment
# 8. Extract the learnt embeddings from the model
# 9. Export the saved model to serve as an embedding lookup
#
#
# <a href="https://colab.research.google.com/github/ksalama/data2cooc2emb2ann/blob/master/track2ann/02-Training_Embeddings_for_Playlist_Tracks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Setup

# %%
# !pip install -r ../requirements.txt

# %%
import os
import math
import numpy as np
import tensorflow as tf
from tensorflow import data
from datetime import datetime

# %%
WORKSPACE = './workspace'
COOC_DIR = '{}/cooc'.format(WORKSPACE)
MODELS_DIR = '{}/models'.format(WORKSPACE)
SEED = 19831060

# %%
# !echo "Files:"
# !ls {COOC_DIR}/
# !echo ""

# !echo "info:"
# !head {COOC_DIR}/info.log
# !echo ""

# !echo "vocab file:"
# !head {COOC_DIR}/vocab.txt
# Out:
# Files:
# cooc-00000-of-00001.tfrecords info2.log
# info.log                      vocab.txt
#
# info:
# P: 2249477
# N: 486352
# max: 13.33242
# min: 2.2812
#
# vocab file:
# 3140490
# 1174666
# 4124042
# 1176202
# 4190858
# 1110922
# 914570
# 980106
# 63370
# 849802

# %% [markdown]
# ## 1.  Metadata

# %%
FEATURES_SCHEMA = {
    'item1': tf.FixedLenFeature(dtype=tf.string, shape=()),
    'item2': tf.FixedLenFeature(dtype=tf.string, shape=()),
    'score': tf.FixedLenFeature(dtype=tf.float32, shape=()),
    'weight': tf.FixedLenFeature(dtype=tf.float32, shape=()),
    'type': tf.FixedLenFeature(dtype=tf.string, shape=())
}

WEIGHT_FEATURE_NAME = 'weight'
TARGET_FEATURE_NAME = 'score'

# %% [markdown]
# ## 2.  Data Input Function

# %%
def make_input_fn(file_pattern, 
                  batch_size=128, num_epochs=1, mode=tf.estimator.ModeKeys.EVAL):

    def _input_fn():
        dataset = tf.data.experimental.make_batched_features_dataset(
            file_pattern,
            batch_size,
            features=FEATURES_SCHEMA,
            label_key=TARGET_FEATURE_NAME,
            reader=tf.data.TFRecordDataset,
            shuffle_buffer_size=batch_size * 10,
            reader_num_threads=1,
            parser_num_threads=2,
            num_epochs=num_epochs,
            shuffle=(mode==tf.estimator.ModeKeys.TRAIN),
            sloppy_ordering=True,
            drop_final_batch=True
        )
        return dataset
    
    return _input_fn

# %%
# tf.enable_eager_execution()

# DATA_FILES = "{}/cooc-*.tfrecords".format(COOC_DIR)

# dataset = make_input_fn(DATA_FILES, batch_size=5)()
# for features, target in dataset.take(1):
#     print()
#     print("Input features:")
#     for key in features:
#         print("-{}:{}".format(key, features[key]))
#     print("Targets:")
#     print(target)

# %% [markdown]
# ## 3. Feature Columns

# %%
def create_feature_columns(embedding_size, vocab1_file, vocab2_file):
    
    feature_columns = []
    
    feature_columns.append(
        tf.feature_column.embedding_column(
            tf.feature_column.categorical_column_with_vocabulary_file(
                key='item1', 
                vocabulary_file=vocab1_file
            ), 
            embedding_size
        )
    )
    
    feature_columns.append(
        tf.feature_column.embedding_column(
            tf.feature_column.categorical_column_with_vocabulary_file(
                key='item2', 
                vocabulary_file=vocab2_file
            ), 
            embedding_size
        )
    )
        
    return feature_columns

# %% [markdown]
# ## 4.  Custom Estimator

# %%
def compute_loss(labels, predictions, weights, types):
    
    def _positive_sample_cost(errors, weights):
        return 0.5 * weights * tf.math.square(errors)
    
    def _negative_sample_cost(errors, weights):
        return weights * tf.math.log(1 + tf.exp(errors))
    
    errors = predictions - labels
    
    p_loss = _positive_sample_cost(errors, weights)
    n_loss = _negative_sample_cost(errors, weights)
    loss = tf.where(tf.equal(types, 'P'), p_loss, n_loss)
    
    return tf.reduce_sum(loss)

def model_fn(features, labels, mode, params):
    
    items1 = features['item1']
    feature_columns = create_feature_columns(
        params.embedding_size, params.vocab1_file, params.vocab2_file)
    
    # TODO: add bias to the input_layer
    item1_layer = tf.feature_column.input_layer(
        features={'item1': items1}, feature_columns=[feature_columns[0]])
    
    if mode != tf.estimator.ModeKeys.PREDICT:
        items2 = features['item2']
        item2_layer = tf.feature_column.input_layer(
            features={'item2': items2}, feature_columns=[feature_columns[1]])
        
        dot_product = tf.keras.layers.Dot(axes=1)([item1_layer, item2_layer])
        logits = (params.max_value - params.min_value) * tf.sigmoid(dot_product) + params.min_value 

    predictions = None
    export_outputs = None
    loss = None
    train_op = None

    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions =  item1_layer
        export_outputs = {'predictions': tf.estimator.export.PredictOutput(predictions)}
    else:
        types = features['type']
        weights = features[WEIGHT_FEATURE_NAME]
        
#         loss = tf.losses.mean_squared_error(
#             labels=labels, 
#             predictions=tf.squeeze(logits),
#             weights=weights
#         )

        loss = compute_loss(
            labels=labels, 
            predictions=tf.squeeze(logits), 
            weights=weights, 
            types=types
        )
        
        train_op=tf.train.AdamOptimizer(params.learning_rate).minimize(
            loss=loss, global_step=tf.train.get_global_step())
    
    return tf.estimator.EstimatorSpec(
        mode=mode,
        predictions=predictions,
        export_outputs=export_outputs,
        loss=loss,
        train_op=train_op
    )


def create_estimator(params, run_config):
    
    estimator = tf.estimator.Estimator(
        model_fn,
        params=params,
        config=run_config
    )
    
    return estimator

# %% [markdown]
# ## 5. Experiment

# %%
def run_experiment(params, run_config):
    
    train_data_files = params.train_data_files
    eval_data_files = params.eval_data_files
    
    # TrainSpec ####################################
    train_input_fn = make_input_fn(
        train_data_files,
        batch_size=params.batch_size,
        num_epochs=None,
        mode=tf.estimator.ModeKeys.TRAIN
    )
    
    train_spec = tf.estimator.TrainSpec(
        input_fn = train_input_fn,
        max_steps=params.traning_steps
    )
    ###############################################    
    
    # EvalSpec ####################################
    eval_input_fn = make_input_fn(
        eval_data_files,
        num_epochs=None, #1
        batch_size=params.batch_size,
    )

    eval_spec = tf.estimator.EvalSpec(
        name=datetime.utcnow().strftime("%H%M%S"),
        input_fn = eval_input_fn,
        steps=params.eval_steps,
        start_delay_secs=0,
        throttle_secs=params.eval_throttle_secs
    )
    ###############################################

    tf.logging.set_verbosity(tf.logging.INFO)
    
    if tf.gfile.Exists(run_config.model_dir):
        print("Removing previous artefacts...")
        tf.gfile.DeleteRecursively(run_config.model_dir)
            
    print("")
    estimator = create_estimator(params, run_config)
    print("")
    
    time_start = datetime.utcnow() 
    print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
    print(".......................................") 

    tf.estimator.train_and_evaluate(
        estimator=estimator,
        train_spec=train_spec, 
        eval_spec=eval_spec
    )

    time_end = datetime.utcnow() 
    print(".......................................")
    print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
    print("")
    time_elapsed = time_end - time_start
    print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
    
    return estimator

# %% [markdown]
# ## 6. Parameters

# %%
MODEL_NAME = 'cooc2emb-01'
model_dir = os.path.join(MODELS_DIR, MODEL_NAME)
info_file = os.path.join(COOC_DIR, 'info.log')
min_value = 15
max_value = -5

info_map = {}

if os.path.exists(info_file):
    try:
        with open(info_file) as f:
            for line in f.readlines():
                key, value = line.split(":")
                info_map[key] = float(value)
        min_value = math.floor(info_map['min'])
        max_value = math.ceil(info_map['max'])
    except: pass
    
class HParams():
    pass

params  = HParams()
params.train_data_files = "{}/cooc-*.tfrecords".format(COOC_DIR)
params.eval_data_files = "{}/cooc-*.tfrecords".format(COOC_DIR)
params.vocab1_file = os.path.join(COOC_DIR,'vocab.txt')
params.vocab2_file = os.path.join(COOC_DIR,'vocab.txt')
params.embedding_size = 32
params.min_value = min_value
params.max_value = max_value
params.batch_size = 265
params.traning_steps = 50000
params.learning_rate = 0.001
params.eval_steps = 1
params.eval_throttle_secs = 0

print(vars(params))

run_config = tf.estimator.RunConfig(
    tf_random_seed=SEED,
    save_checkpoints_steps=1000,
    keep_checkpoint_max=3,
    model_dir=model_dir,
)
# Out:
# {'train_data_files': './workspace/cooc/cooc-*.tfrecords', 'eval_data_files': './workspace/cooc/cooc-*.tfrecords', 'vocab1_file': './workspace/cooc/vocab.txt', 'vocab2_file': './workspace/cooc/vocab.txt', 'embedding_size': 32, 'min_value': 2, 'max_value': 14, 'batch_size': 265, 'traning_steps': 50000, 'learning_rate': 0.001, 'eval_steps': 1, 'eval_throttle_secs': 0}

# %% [markdown]
# ## 7. Run

# %%
estimator = run_experiment(params, run_config)
# Out:
# Removing previous artefacts...
#
# INFO:tensorflow:Using config: {'_model_dir': './workspace/models/cooc2emb-01', '_tf_random_seed': 19831060, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x12d410f98>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# Experiment started at 01:25:43
# .......................................
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/data/util/random_seed.py:58: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/data/experimental/ops/readers.py:835: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/data/experimental/ops/readers.py:212: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py:205: EmbeddingColumn._get_dense_tensor (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column_v2.py:3140: VocabularyFileCategoricalColumn._get_sparse_tensors (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py:2115: VocabularyFileCategoricalColumn._transform_feature (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column_v2.py:3080: VocabularyFileCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py:206: EmbeddingColumn._variable_shape (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:loss = 316.44455, step = 1
# INFO:tensorflow:global_step/sec: 120.594
# INFO:tensorflow:loss = 449.4657, step = 101 (0.830 sec)
# INFO:tensorflow:global_step/sec: 81.841
# INFO:tensorflow:loss = 429.09973, step = 201 (1.222 sec)
# INFO:tensorflow:global_step/sec: 118.244
# INFO:tensorflow:loss = 564.16656, step = 301 (0.845 sec)
# INFO:tensorflow:global_step/sec: 122.255
# INFO:tensorflow:loss = 393.97418, step = 401 (0.818 sec)
# INFO:tensorflow:global_step/sec: 116.666
# INFO:tensorflow:loss = 402.2496, step = 501 (0.857 sec)
# INFO:tensorflow:global_step/sec: 129.46
# INFO:tensorflow:loss = 470.42355, step = 601 (0.772 sec)
# INFO:tensorflow:global_step/sec: 139.271
# INFO:tensorflow:loss = 357.87515, step = 701 (0.718 sec)
# INFO:tensorflow:global_step/sec: 106.354
# INFO:tensorflow:loss = 346.44647, step = 801 (0.941 sec)
# INFO:tensorflow:global_step/sec: 102.889
# INFO:tensorflow:loss = 383.99417, step = 901 (0.971 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:25:55Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:25:55
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 254.78947
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./workspace/models/cooc2emb-01/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 40.3583
# INFO:tensorflow:loss = 362.19202, step = 1001 (2.479 sec)
# INFO:tensorflow:global_step/sec: 85.1185
# INFO:tensorflow:loss = 397.5473, step = 1101 (1.174 sec)
# INFO:tensorflow:global_step/sec: 103.58
# INFO:tensorflow:loss = 380.37415, step = 1201 (0.965 sec)
# INFO:tensorflow:global_step/sec: 106.884
# INFO:tensorflow:loss = 434.37445, step = 1301 (0.936 sec)
# INFO:tensorflow:global_step/sec: 84.3021
# INFO:tensorflow:loss = 370.93167, step = 1401 (1.186 sec)
# INFO:tensorflow:global_step/sec: 111.525
# INFO:tensorflow:loss = 425.75818, step = 1501 (0.896 sec)
# INFO:tensorflow:global_step/sec: 112.567
# INFO:tensorflow:loss = 362.93527, step = 1601 (0.889 sec)
# INFO:tensorflow:global_step/sec: 108.073
# INFO:tensorflow:loss = 365.197, step = 1701 (0.925 sec)
# INFO:tensorflow:global_step/sec: 122.345
# INFO:tensorflow:loss = 331.50336, step = 1801 (0.817 sec)
# INFO:tensorflow:global_step/sec: 116.61
# INFO:tensorflow:loss = 336.998, step = 1901 (0.858 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:26:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:26:06
# INFO:tensorflow:Saving dict for global step 2000: global_step = 2000, loss = 260.37854
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: ./workspace/models/cooc2emb-01/model.ckpt-2000
# INFO:tensorflow:global_step/sec: 46.1415
# INFO:tensorflow:loss = 449.054, step = 2001 (2.168 sec)
# INFO:tensorflow:global_step/sec: 92.3999
# INFO:tensorflow:loss = 300.45917, step = 2101 (1.082 sec)
# INFO:tensorflow:global_step/sec: 100.136
# INFO:tensorflow:loss = 440.49954, step = 2201 (0.999 sec)
# INFO:tensorflow:global_step/sec: 95.7936
# INFO:tensorflow:loss = 424.3484, step = 2301 (1.044 sec)
# INFO:tensorflow:global_step/sec: 91.2467
# INFO:tensorflow:loss = 379.57693, step = 2401 (1.097 sec)
# INFO:tensorflow:global_step/sec: 123.946
# INFO:tensorflow:loss = 367.91156, step = 2501 (0.805 sec)
# INFO:tensorflow:global_step/sec: 127.528
# INFO:tensorflow:loss = 346.81085, step = 2601 (0.784 sec)
# INFO:tensorflow:global_step/sec: 97.3444
# INFO:tensorflow:loss = 356.2684, step = 2701 (1.027 sec)
# INFO:tensorflow:global_step/sec: 98.9324
# INFO:tensorflow:loss = 338.74585, step = 2801 (1.011 sec)
# INFO:tensorflow:global_step/sec: 98.3231
# INFO:tensorflow:loss = 332.79236, step = 2901 (1.018 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into ./workspace/models/cooc2emb-01/model.ckpt.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:26:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:26:18
# INFO:tensorflow:Saving dict for global step 3000: global_step = 3000, loss = 264.79935
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: ./workspace/models/cooc2emb-01/model.ckpt-3000
# INFO:tensorflow:global_step/sec: 36.7691
# INFO:tensorflow:loss = 337.861, step = 3001 (2.719 sec)
# INFO:tensorflow:global_step/sec: 95.5309
# INFO:tensorflow:loss = 341.8582, step = 3101 (1.046 sec)
# INFO:tensorflow:global_step/sec: 82.2915
# INFO:tensorflow:loss = 387.19876, step = 3201 (1.215 sec)
# INFO:tensorflow:global_step/sec: 85.2441
# INFO:tensorflow:loss = 299.75702, step = 3301 (1.174 sec)
# INFO:tensorflow:global_step/sec: 88.225
# INFO:tensorflow:loss = 347.85724, step = 3401 (1.133 sec)
# INFO:tensorflow:global_step/sec: 92.3375
# INFO:tensorflow:loss = 343.30322, step = 3501 (1.083 sec)
# INFO:tensorflow:global_step/sec: 104.625
# INFO:tensorflow:loss = 300.31473, step = 3601 (0.955 sec)
# INFO:tensorflow:global_step/sec: 111.181
# INFO:tensorflow:loss = 357.48218, step = 3701 (0.900 sec)
# INFO:tensorflow:global_step/sec: 105.14
# INFO:tensorflow:loss = 461.87085, step = 3801 (0.952 sec)
# INFO:tensorflow:global_step/sec: 82.761
# INFO:tensorflow:loss = 303.54422, step = 3901 (1.208 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:26:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:26:30
# INFO:tensorflow:Saving dict for global step 4000: global_step = 4000, loss = 275.84015
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: ./workspace/models/cooc2emb-01/model.ckpt-4000
# INFO:tensorflow:global_step/sec: 35.997
# INFO:tensorflow:loss = 411.939, step = 4001 (2.778 sec)
# INFO:tensorflow:global_step/sec: 63.6287
# INFO:tensorflow:loss = 275.45682, step = 4101 (1.572 sec)
# INFO:tensorflow:global_step/sec: 60.4577
# INFO:tensorflow:loss = 342.9289, step = 4201 (1.655 sec)
# INFO:tensorflow:global_step/sec: 57.3582
# INFO:tensorflow:loss = 363.21887, step = 4301 (1.742 sec)
# INFO:tensorflow:global_step/sec: 76.4231
# INFO:tensorflow:loss = 342.45767, step = 4401 (1.308 sec)
# INFO:tensorflow:global_step/sec: 80.3041
# INFO:tensorflow:loss = 323.88232, step = 4501 (1.246 sec)
# INFO:tensorflow:global_step/sec: 77.9459
# INFO:tensorflow:loss = 333.65372, step = 4601 (1.284 sec)
# INFO:tensorflow:global_step/sec: 61.7913
# INFO:tensorflow:loss = 497.91858, step = 4701 (1.618 sec)
# INFO:tensorflow:global_step/sec: 67.9035
# INFO:tensorflow:loss = 432.3147, step = 4801 (1.472 sec)
# INFO:tensorflow:global_step/sec: 56.5292
# INFO:tensorflow:loss = 324.36563, step = 4901 (1.770 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:26:47Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:26:48
# INFO:tensorflow:Saving dict for global step 5000: global_step = 5000, loss = 286.10925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: ./workspace/models/cooc2emb-01/model.ckpt-5000
# INFO:tensorflow:global_step/sec: 25.5702
# INFO:tensorflow:loss = 438.59958, step = 5001 (3.910 sec)
# INFO:tensorflow:global_step/sec: 64.2724
# INFO:tensorflow:loss = 302.27322, step = 5101 (1.556 sec)
# INFO:tensorflow:global_step/sec: 83.1319
# INFO:tensorflow:loss = 411.52512, step = 5201 (1.202 sec)
# INFO:tensorflow:global_step/sec: 84.2538
# INFO:tensorflow:loss = 346.1227, step = 5301 (1.188 sec)
# INFO:tensorflow:global_step/sec: 98.3335
# INFO:tensorflow:loss = 347.53174, step = 5401 (1.015 sec)
# INFO:tensorflow:global_step/sec: 103.626
# INFO:tensorflow:loss = 374.92783, step = 5501 (0.965 sec)
# INFO:tensorflow:global_step/sec: 92.8231
# INFO:tensorflow:loss = 328.6417, step = 5601 (1.077 sec)
# INFO:tensorflow:global_step/sec: 81.3651
# INFO:tensorflow:loss = 355.55032, step = 5701 (1.230 sec)
# INFO:tensorflow:global_step/sec: 91.0267
# INFO:tensorflow:loss = 333.2782, step = 5801 (1.099 sec)
# INFO:tensorflow:global_step/sec: 90.8633
# INFO:tensorflow:loss = 332.38705, step = 5901 (1.100 sec)
# INFO:tensorflow:Saving checkpoints for 6000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:27:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:27:01
# INFO:tensorflow:Saving dict for global step 6000: global_step = 6000, loss = 300.52246
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: ./workspace/models/cooc2emb-01/model.ckpt-6000
# INFO:tensorflow:global_step/sec: 39.4119
# INFO:tensorflow:loss = 349.76797, step = 6001 (2.538 sec)
# INFO:tensorflow:global_step/sec: 68.0081
# INFO:tensorflow:loss = 344.92664, step = 6101 (1.470 sec)
# INFO:tensorflow:global_step/sec: 70.3064
# INFO:tensorflow:loss = 364.32767, step = 6201 (1.422 sec)
# INFO:tensorflow:global_step/sec: 107.505
# INFO:tensorflow:loss = 459.61423, step = 6301 (0.930 sec)
# INFO:tensorflow:global_step/sec: 113.997
# INFO:tensorflow:loss = 385.37036, step = 6401 (0.877 sec)
# INFO:tensorflow:global_step/sec: 93.6421
# INFO:tensorflow:loss = 374.74612, step = 6501 (1.068 sec)
# INFO:tensorflow:global_step/sec: 99.0354
# INFO:tensorflow:loss = 339.39294, step = 6601 (1.010 sec)
# INFO:tensorflow:global_step/sec: 82.9768
# INFO:tensorflow:loss = 258.33163, step = 6701 (1.205 sec)
# INFO:tensorflow:global_step/sec: 90.2881
# INFO:tensorflow:loss = 358.1059, step = 6801 (1.107 sec)
# INFO:tensorflow:global_step/sec: 110.138
# INFO:tensorflow:loss = 454.96243, step = 6901 (0.908 sec)
# INFO:tensorflow:Saving checkpoints for 7000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:27:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:27:13
# INFO:tensorflow:Saving dict for global step 7000: global_step = 7000, loss = 309.54413
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7000: ./workspace/models/cooc2emb-01/model.ckpt-7000
# INFO:tensorflow:global_step/sec: 37.2537
# INFO:tensorflow:loss = 498.05838, step = 7001 (2.685 sec)
# INFO:tensorflow:global_step/sec: 83.7807
# INFO:tensorflow:loss = 349.599, step = 7101 (1.193 sec)
# INFO:tensorflow:global_step/sec: 106.29
# INFO:tensorflow:loss = 344.48615, step = 7201 (0.941 sec)
# INFO:tensorflow:global_step/sec: 111.925
# INFO:tensorflow:loss = 389.30157, step = 7301 (0.894 sec)
# INFO:tensorflow:global_step/sec: 104.33
# INFO:tensorflow:loss = 295.05008, step = 7401 (0.958 sec)
# INFO:tensorflow:global_step/sec: 119.041
# INFO:tensorflow:loss = 390.86365, step = 7501 (0.840 sec)
# INFO:tensorflow:global_step/sec: 88.1593
# INFO:tensorflow:loss = 348.70886, step = 7601 (1.134 sec)
# INFO:tensorflow:global_step/sec: 98.2155
# INFO:tensorflow:loss = 375.59442, step = 7701 (1.018 sec)
# INFO:tensorflow:global_step/sec: 91.575
# INFO:tensorflow:loss = 311.32367, step = 7801 (1.092 sec)
# INFO:tensorflow:global_step/sec: 91.5399
# INFO:tensorflow:loss = 289.5175, step = 7901 (1.092 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:27:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:27:25
# INFO:tensorflow:Saving dict for global step 8000: global_step = 8000, loss = 330.31424
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: ./workspace/models/cooc2emb-01/model.ckpt-8000
# INFO:tensorflow:global_step/sec: 42.7597
# INFO:tensorflow:loss = 326.72177, step = 8001 (2.339 sec)
# INFO:tensorflow:global_step/sec: 107.129
# INFO:tensorflow:loss = 279.05383, step = 8101 (0.933 sec)
# INFO:tensorflow:global_step/sec: 117.726
# INFO:tensorflow:loss = 425.1886, step = 8201 (0.851 sec)
# INFO:tensorflow:global_step/sec: 100.374
# INFO:tensorflow:loss = 361.6381, step = 8301 (0.996 sec)
# INFO:tensorflow:global_step/sec: 85.279
# INFO:tensorflow:loss = 314.26498, step = 8401 (1.171 sec)
# INFO:tensorflow:global_step/sec: 113.839
# INFO:tensorflow:loss = 277.59705, step = 8501 (0.878 sec)
# INFO:tensorflow:global_step/sec: 110.053
# INFO:tensorflow:loss = 334.10712, step = 8601 (0.910 sec)
# INFO:tensorflow:global_step/sec: 93.3867
# INFO:tensorflow:loss = 355.8028, step = 8701 (1.070 sec)
# INFO:tensorflow:global_step/sec: 98.9329
# INFO:tensorflow:loss = 360.5116, step = 8801 (1.011 sec)
# INFO:tensorflow:global_step/sec: 124.908
# INFO:tensorflow:loss = 341.77664, step = 8901 (0.801 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:27:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:27:36
# INFO:tensorflow:Saving dict for global step 9000: global_step = 9000, loss = 336.13763
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: ./workspace/models/cooc2emb-01/model.ckpt-9000
# INFO:tensorflow:global_step/sec: 45.5469
# INFO:tensorflow:loss = 384.42258, step = 9001 (2.197 sec)
# INFO:tensorflow:global_step/sec: 111.203
# INFO:tensorflow:loss = 339.41785, step = 9101 (0.897 sec)
# INFO:tensorflow:global_step/sec: 123.456
# INFO:tensorflow:loss = 373.16754, step = 9201 (0.810 sec)
# INFO:tensorflow:global_step/sec: 123.944
# INFO:tensorflow:loss = 363.72968, step = 9301 (0.807 sec)
# INFO:tensorflow:global_step/sec: 127.906
# INFO:tensorflow:loss = 276.84094, step = 9401 (0.782 sec)
# INFO:tensorflow:global_step/sec: 127.703
# INFO:tensorflow:loss = 310.58994, step = 9501 (0.783 sec)
# INFO:tensorflow:global_step/sec: 128.757
# INFO:tensorflow:loss = 308.97833, step = 9601 (0.776 sec)
# INFO:tensorflow:global_step/sec: 129.659
# INFO:tensorflow:loss = 307.43384, step = 9701 (0.771 sec)
# INFO:tensorflow:global_step/sec: 125.63
# INFO:tensorflow:loss = 418.1223, step = 9801 (0.796 sec)
# INFO:tensorflow:global_step/sec: 113.711
# INFO:tensorflow:loss = 334.2912, step = 9901 (0.879 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:27:45Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:27:45
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, loss = 350.46036
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: ./workspace/models/cooc2emb-01/model.ckpt-10000
# INFO:tensorflow:global_step/sec: 43.5224
# INFO:tensorflow:loss = 306.53525, step = 10001 (2.301 sec)
# INFO:tensorflow:global_step/sec: 101.126
# INFO:tensorflow:loss = 302.7192, step = 10101 (0.986 sec)
# INFO:tensorflow:global_step/sec: 83.6899
# INFO:tensorflow:loss = 391.2718, step = 10201 (1.195 sec)
# INFO:tensorflow:global_step/sec: 98.1012
# INFO:tensorflow:loss = 263.38962, step = 10301 (1.020 sec)
# INFO:tensorflow:global_step/sec: 94.9983
# INFO:tensorflow:loss = 354.26443, step = 10401 (1.052 sec)
# INFO:tensorflow:global_step/sec: 86.1262
# INFO:tensorflow:loss = 282.25714, step = 10501 (1.162 sec)
# INFO:tensorflow:global_step/sec: 76.2781
# INFO:tensorflow:loss = 291.9619, step = 10601 (1.310 sec)
# INFO:tensorflow:global_step/sec: 86.6544
# INFO:tensorflow:loss = 310.047, step = 10701 (1.159 sec)
# INFO:tensorflow:global_step/sec: 105.403
# INFO:tensorflow:loss = 222.57574, step = 10801 (0.944 sec)
# INFO:tensorflow:global_step/sec: 110.023
# INFO:tensorflow:loss = 219.14082, step = 10901 (0.909 sec)
# INFO:tensorflow:Saving checkpoints for 11000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:27:57Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-11000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:27:58
# INFO:tensorflow:Saving dict for global step 11000: global_step = 11000, loss = 150.64124
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11000: ./workspace/models/cooc2emb-01/model.ckpt-11000
# INFO:tensorflow:global_step/sec: 41.8201
# INFO:tensorflow:loss = 307.34085, step = 11001 (2.393 sec)
# INFO:tensorflow:global_step/sec: 89.7698
# INFO:tensorflow:loss = 239.09824, step = 11101 (1.112 sec)
# INFO:tensorflow:global_step/sec: 107.259
# INFO:tensorflow:loss = 148.78085, step = 11201 (0.933 sec)
# INFO:tensorflow:global_step/sec: 106.639
# INFO:tensorflow:loss = 257.75082, step = 11301 (0.938 sec)
# INFO:tensorflow:global_step/sec: 101.727
# INFO:tensorflow:loss = 264.37027, step = 11401 (0.982 sec)
# INFO:tensorflow:global_step/sec: 95.2106
# INFO:tensorflow:loss = 193.50266, step = 11501 (1.050 sec)
# INFO:tensorflow:global_step/sec: 99.4376
# INFO:tensorflow:loss = 271.08313, step = 11601 (1.006 sec)
# INFO:tensorflow:global_step/sec: 94.3719
# INFO:tensorflow:loss = 223.59032, step = 11701 (1.060 sec)
# INFO:tensorflow:global_step/sec: 106.898
# INFO:tensorflow:loss = 283.15994, step = 11801 (0.935 sec)
# INFO:tensorflow:global_step/sec: 97.9746
# INFO:tensorflow:loss = 255.41096, step = 11901 (1.021 sec)
# INFO:tensorflow:Saving checkpoints for 12000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:28:09Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-12000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:28:09
# INFO:tensorflow:Saving dict for global step 12000: global_step = 12000, loss = 152.21274
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12000: ./workspace/models/cooc2emb-01/model.ckpt-12000
# INFO:tensorflow:global_step/sec: 34.9498
# INFO:tensorflow:loss = 255.0119, step = 12001 (2.861 sec)
# INFO:tensorflow:global_step/sec: 89.0158
# INFO:tensorflow:loss = 179.383, step = 12101 (1.123 sec)
# INFO:tensorflow:global_step/sec: 83.2991
# INFO:tensorflow:loss = 218.23225, step = 12201 (1.202 sec)
# INFO:tensorflow:global_step/sec: 83.5604
# INFO:tensorflow:loss = 158.9813, step = 12301 (1.195 sec)
# INFO:tensorflow:global_step/sec: 104.402
# INFO:tensorflow:loss = 215.11626, step = 12401 (0.958 sec)
# INFO:tensorflow:global_step/sec: 104.626
# INFO:tensorflow:loss = 221.09305, step = 12501 (0.956 sec)
# INFO:tensorflow:global_step/sec: 93.776
# INFO:tensorflow:loss = 196.14758, step = 12601 (1.066 sec)
# INFO:tensorflow:global_step/sec: 104.677
# INFO:tensorflow:loss = 297.16574, step = 12701 (0.956 sec)
# INFO:tensorflow:global_step/sec: 105.727
# INFO:tensorflow:loss = 186.45477, step = 12801 (0.946 sec)
# INFO:tensorflow:global_step/sec: 105.391
# INFO:tensorflow:loss = 269.72363, step = 12901 (0.949 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:28:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:28:21
# INFO:tensorflow:Saving dict for global step 13000: global_step = 13000, loss = 152.6368
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13000: ./workspace/models/cooc2emb-01/model.ckpt-13000
# INFO:tensorflow:global_step/sec: 48.2836
# INFO:tensorflow:loss = 114.93041, step = 13001 (2.071 sec)
# INFO:tensorflow:global_step/sec: 111.567
# INFO:tensorflow:loss = 222.70157, step = 13101 (0.896 sec)
# INFO:tensorflow:global_step/sec: 114.778
# INFO:tensorflow:loss = 185.13202, step = 13201 (0.871 sec)
# INFO:tensorflow:global_step/sec: 115.991
# INFO:tensorflow:loss = 247.92998, step = 13301 (0.862 sec)
# INFO:tensorflow:global_step/sec: 118.955
# INFO:tensorflow:loss = 275.43304, step = 13401 (0.841 sec)
# INFO:tensorflow:global_step/sec: 115.986
# INFO:tensorflow:loss = 216.3549, step = 13501 (0.862 sec)
# INFO:tensorflow:global_step/sec: 113.722
# INFO:tensorflow:loss = 134.9022, step = 13601 (0.880 sec)
# INFO:tensorflow:global_step/sec: 102.968
# INFO:tensorflow:loss = 217.2843, step = 13701 (0.971 sec)
# INFO:tensorflow:global_step/sec: 98.1628
# INFO:tensorflow:loss = 208.727, step = 13801 (1.019 sec)
# INFO:tensorflow:global_step/sec: 88.4015
# INFO:tensorflow:loss = 123.66484, step = 13901 (1.131 sec)
# INFO:tensorflow:Saving checkpoints for 14000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:28:31Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:28:32
# INFO:tensorflow:Saving dict for global step 14000: global_step = 14000, loss = 147.46959
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14000: ./workspace/models/cooc2emb-01/model.ckpt-14000
# INFO:tensorflow:global_step/sec: 39.451
# INFO:tensorflow:loss = 182.6676, step = 14001 (2.535 sec)
# INFO:tensorflow:global_step/sec: 101.676
# INFO:tensorflow:loss = 250.59608, step = 14101 (0.983 sec)
# INFO:tensorflow:global_step/sec: 109.525
# INFO:tensorflow:loss = 219.41154, step = 14201 (0.913 sec)
# INFO:tensorflow:global_step/sec: 106.547
# INFO:tensorflow:loss = 171.81042, step = 14301 (0.938 sec)
# INFO:tensorflow:global_step/sec: 129.396
# INFO:tensorflow:loss = 225.82927, step = 14401 (0.773 sec)
# INFO:tensorflow:global_step/sec: 131.556
# INFO:tensorflow:loss = 260.7607, step = 14501 (0.760 sec)
# INFO:tensorflow:global_step/sec: 128.264
# INFO:tensorflow:loss = 215.52771, step = 14601 (0.779 sec)
# INFO:tensorflow:global_step/sec: 125.615
# INFO:tensorflow:loss = 178.82104, step = 14701 (0.796 sec)
# INFO:tensorflow:global_step/sec: 125.116
# INFO:tensorflow:loss = 221.12349, step = 14801 (0.800 sec)
# INFO:tensorflow:global_step/sec: 127.292
# INFO:tensorflow:loss = 187.41751, step = 14901 (0.786 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:28:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:28:41
# INFO:tensorflow:Saving dict for global step 15000: global_step = 15000, loss = 145.81749
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15000: ./workspace/models/cooc2emb-01/model.ckpt-15000
# INFO:tensorflow:global_step/sec: 46.6052
# INFO:tensorflow:loss = 170.22147, step = 15001 (2.145 sec)
# INFO:tensorflow:global_step/sec: 90.9883
# INFO:tensorflow:loss = 204.65633, step = 15101 (1.099 sec)
# INFO:tensorflow:global_step/sec: 88.0889
# INFO:tensorflow:loss = 194.68684, step = 15201 (1.135 sec)
# INFO:tensorflow:global_step/sec: 116.051
# INFO:tensorflow:loss = 229.6149, step = 15301 (0.861 sec)
# INFO:tensorflow:global_step/sec: 102.612
# INFO:tensorflow:loss = 208.47235, step = 15401 (0.975 sec)
# INFO:tensorflow:global_step/sec: 132.95
# INFO:tensorflow:loss = 224.2191, step = 15501 (0.752 sec)
# INFO:tensorflow:global_step/sec: 125.714
# INFO:tensorflow:loss = 219.73395, step = 15601 (0.797 sec)
# INFO:tensorflow:global_step/sec: 114.325
# INFO:tensorflow:loss = 131.23875, step = 15701 (0.873 sec)
# INFO:tensorflow:global_step/sec: 111.705
# INFO:tensorflow:loss = 186.85133, step = 15801 (0.895 sec)
# INFO:tensorflow:global_step/sec: 111.726
# INFO:tensorflow:loss = 194.1289, step = 15901 (0.895 sec)
# INFO:tensorflow:Saving checkpoints for 16000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:28:51Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-16000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:28:52
# INFO:tensorflow:Saving dict for global step 16000: global_step = 16000, loss = 142.41364
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16000: ./workspace/models/cooc2emb-01/model.ckpt-16000
# INFO:tensorflow:global_step/sec: 47.4963
# INFO:tensorflow:loss = 310.83466, step = 16001 (2.105 sec)
# INFO:tensorflow:global_step/sec: 107.945
# INFO:tensorflow:loss = 232.41068, step = 16101 (0.927 sec)
# INFO:tensorflow:global_step/sec: 114.035
# INFO:tensorflow:loss = 227.70465, step = 16201 (0.877 sec)
# INFO:tensorflow:global_step/sec: 112.797
# INFO:tensorflow:loss = 211.82945, step = 16301 (0.887 sec)
# INFO:tensorflow:global_step/sec: 114.116
# INFO:tensorflow:loss = 198.81412, step = 16401 (0.876 sec)
# INFO:tensorflow:global_step/sec: 111.717
# INFO:tensorflow:loss = 333.93423, step = 16501 (0.895 sec)
# INFO:tensorflow:global_step/sec: 114.624
# INFO:tensorflow:loss = 215.35083, step = 16601 (0.873 sec)
# INFO:tensorflow:global_step/sec: 111.23
# INFO:tensorflow:loss = 194.62878, step = 16701 (0.900 sec)
# INFO:tensorflow:global_step/sec: 114.865
# INFO:tensorflow:loss = 211.39664, step = 16801 (0.870 sec)
# INFO:tensorflow:global_step/sec: 113.213
# INFO:tensorflow:loss = 182.85355, step = 16901 (0.884 sec)
# INFO:tensorflow:Saving checkpoints for 17000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:29:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-17000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:29:02
# INFO:tensorflow:Saving dict for global step 17000: global_step = 17000, loss = 141.99782
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17000: ./workspace/models/cooc2emb-01/model.ckpt-17000
# INFO:tensorflow:global_step/sec: 47.7158
# INFO:tensorflow:loss = 169.77742, step = 17001 (2.096 sec)
# INFO:tensorflow:global_step/sec: 109.913
# INFO:tensorflow:loss = 218.81027, step = 17101 (0.910 sec)
# INFO:tensorflow:global_step/sec: 113.996
# INFO:tensorflow:loss = 195.1891, step = 17201 (0.877 sec)
# INFO:tensorflow:global_step/sec: 93.0698
# INFO:tensorflow:loss = 266.95953, step = 17301 (1.075 sec)
# INFO:tensorflow:global_step/sec: 100.48
# INFO:tensorflow:loss = 259.98633, step = 17401 (0.996 sec)
# INFO:tensorflow:global_step/sec: 110.822
# INFO:tensorflow:loss = 149.43785, step = 17501 (0.902 sec)
# INFO:tensorflow:global_step/sec: 110.994
# INFO:tensorflow:loss = 203.02101, step = 17601 (0.901 sec)
# INFO:tensorflow:global_step/sec: 110.127
# INFO:tensorflow:loss = 232.47626, step = 17701 (0.908 sec)
# INFO:tensorflow:global_step/sec: 115.619
# INFO:tensorflow:loss = 187.56784, step = 17801 (0.865 sec)
# INFO:tensorflow:global_step/sec: 113.328
# INFO:tensorflow:loss = 255.08318, step = 17901 (0.882 sec)
# INFO:tensorflow:Saving checkpoints for 18000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:29:12Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-18000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:29:12
# INFO:tensorflow:Saving dict for global step 18000: global_step = 18000, loss = 140.82266
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18000: ./workspace/models/cooc2emb-01/model.ckpt-18000
# INFO:tensorflow:global_step/sec: 47.3412
# INFO:tensorflow:loss = 141.19899, step = 18001 (2.112 sec)
# INFO:tensorflow:global_step/sec: 103.078
# INFO:tensorflow:loss = 184.75446, step = 18101 (0.970 sec)
# INFO:tensorflow:global_step/sec: 112.142
# INFO:tensorflow:loss = 239.67426, step = 18201 (0.892 sec)
# INFO:tensorflow:global_step/sec: 99.7431
# INFO:tensorflow:loss = 240.33984, step = 18301 (1.003 sec)
# INFO:tensorflow:global_step/sec: 111.985
# INFO:tensorflow:loss = 227.41895, step = 18401 (0.893 sec)
# INFO:tensorflow:global_step/sec: 110.451
# INFO:tensorflow:loss = 187.84702, step = 18501 (0.905 sec)
# INFO:tensorflow:global_step/sec: 90.0029
# INFO:tensorflow:loss = 268.23642, step = 18601 (1.116 sec)
# INFO:tensorflow:global_step/sec: 93.7042
# INFO:tensorflow:loss = 160.54256, step = 18701 (1.063 sec)
# INFO:tensorflow:global_step/sec: 112.26
# INFO:tensorflow:loss = 172.2928, step = 18801 (0.891 sec)
# INFO:tensorflow:global_step/sec: 116.032
# INFO:tensorflow:loss = 227.22673, step = 18901 (0.862 sec)
# INFO:tensorflow:Saving checkpoints for 19000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:29:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-19000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:29:23
# INFO:tensorflow:Saving dict for global step 19000: global_step = 19000, loss = 136.00525
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 19000: ./workspace/models/cooc2emb-01/model.ckpt-19000
# INFO:tensorflow:global_step/sec: 44.3468
# INFO:tensorflow:loss = 197.82623, step = 19001 (2.255 sec)
# INFO:tensorflow:global_step/sec: 113.029
# INFO:tensorflow:loss = 245.51782, step = 19101 (0.885 sec)
# INFO:tensorflow:global_step/sec: 115.696
# INFO:tensorflow:loss = 265.53995, step = 19201 (0.864 sec)
# INFO:tensorflow:global_step/sec: 112.691
# INFO:tensorflow:loss = 208.06613, step = 19301 (0.888 sec)
# INFO:tensorflow:global_step/sec: 117.984
# INFO:tensorflow:loss = 163.8868, step = 19401 (0.847 sec)
# INFO:tensorflow:global_step/sec: 85.3817
# INFO:tensorflow:loss = 189.29092, step = 19501 (1.171 sec)
# INFO:tensorflow:global_step/sec: 95.275
# INFO:tensorflow:loss = 222.8305, step = 19601 (1.050 sec)
# INFO:tensorflow:global_step/sec: 92.3429
# INFO:tensorflow:loss = 164.90453, step = 19701 (1.083 sec)
# INFO:tensorflow:global_step/sec: 110.224
# INFO:tensorflow:loss = 205.77007, step = 19801 (0.907 sec)
# INFO:tensorflow:global_step/sec: 116.143
# INFO:tensorflow:loss = 146.19247, step = 19901 (0.861 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:29:33Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:29:34
# INFO:tensorflow:Saving dict for global step 20000: global_step = 20000, loss = 136.15645
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: ./workspace/models/cooc2emb-01/model.ckpt-20000
# INFO:tensorflow:global_step/sec: 49.9885
# INFO:tensorflow:loss = 223.23427, step = 20001 (2.000 sec)
# INFO:tensorflow:global_step/sec: 89.0855
# INFO:tensorflow:loss = 263.28033, step = 20101 (1.123 sec)
# INFO:tensorflow:global_step/sec: 103.886
# INFO:tensorflow:loss = 243.59251, step = 20201 (0.963 sec)
# INFO:tensorflow:global_step/sec: 100.103
# INFO:tensorflow:loss = 215.33171, step = 20301 (0.999 sec)
# INFO:tensorflow:global_step/sec: 102.648
# INFO:tensorflow:loss = 237.67117, step = 20401 (0.974 sec)
# INFO:tensorflow:global_step/sec: 104.452
# INFO:tensorflow:loss = 223.0299, step = 20501 (0.958 sec)
# INFO:tensorflow:global_step/sec: 101.263
# INFO:tensorflow:loss = 235.06616, step = 20601 (0.987 sec)
# ...
# INFO:tensorflow:global_step/sec: 114.942
# INFO:tensorflow:loss = 38.337097, step = 42301 (0.869 sec)
# INFO:tensorflow:global_step/sec: 115.58
# INFO:tensorflow:loss = 40.716125, step = 42401 (0.865 sec)
# INFO:tensorflow:global_step/sec: 115.082
# INFO:tensorflow:loss = 42.924015, step = 42501 (0.869 sec)
# INFO:tensorflow:global_step/sec: 113.117
# INFO:tensorflow:loss = 40.527225, step = 42601 (0.884 sec)
# INFO:tensorflow:global_step/sec: 112.385
# INFO:tensorflow:loss = 45.661293, step = 42701 (0.889 sec)
# INFO:tensorflow:global_step/sec: 110.453
# INFO:tensorflow:loss = 44.674496, step = 42801 (0.905 sec)
# INFO:tensorflow:global_step/sec: 107.003
# INFO:tensorflow:loss = 38.990345, step = 42901 (0.935 sec)
# INFO:tensorflow:Saving checkpoints for 43000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:33:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-43000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:33:36
# INFO:tensorflow:Saving dict for global step 43000: global_step = 43000, loss = 32.267303
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 43000: ./workspace/models/cooc2emb-01/model.ckpt-43000
# INFO:tensorflow:global_step/sec: 52.5428
# INFO:tensorflow:loss = 49.43773, step = 43001 (1.904 sec)
# INFO:tensorflow:global_step/sec: 128.396
# INFO:tensorflow:loss = 37.10923, step = 43101 (0.778 sec)
# INFO:tensorflow:global_step/sec: 117.063
# INFO:tensorflow:loss = 46.445297, step = 43201 (0.855 sec)
# INFO:tensorflow:global_step/sec: 118.355
# INFO:tensorflow:loss = 43.247715, step = 43301 (0.845 sec)
# INFO:tensorflow:global_step/sec: 115.217
# INFO:tensorflow:loss = 42.38227, step = 43401 (0.867 sec)
# INFO:tensorflow:global_step/sec: 113.169
# INFO:tensorflow:loss = 46.32397, step = 43501 (0.884 sec)
# INFO:tensorflow:global_step/sec: 113.335
# INFO:tensorflow:loss = 40.085148, step = 43601 (0.882 sec)
# INFO:tensorflow:global_step/sec: 114.324
# INFO:tensorflow:loss = 43.497704, step = 43701 (0.875 sec)
# INFO:tensorflow:global_step/sec: 113.488
# INFO:tensorflow:loss = 40.959206, step = 43801 (0.881 sec)
# INFO:tensorflow:global_step/sec: 116.186
# INFO:tensorflow:loss = 42.807354, step = 43901 (0.861 sec)
# INFO:tensorflow:Saving checkpoints for 44000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:33:45Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:33:46
# INFO:tensorflow:Saving dict for global step 44000: global_step = 44000, loss = 32.991783
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: ./workspace/models/cooc2emb-01/model.ckpt-44000
# INFO:tensorflow:global_step/sec: 42.8943
# INFO:tensorflow:loss = 40.564194, step = 44001 (2.331 sec)
# INFO:tensorflow:global_step/sec: 106.627
# INFO:tensorflow:loss = 38.215977, step = 44101 (0.938 sec)
# INFO:tensorflow:global_step/sec: 116.384
# INFO:tensorflow:loss = 39.067528, step = 44201 (0.859 sec)
# INFO:tensorflow:global_step/sec: 114.133
# INFO:tensorflow:loss = 33.87243, step = 44301 (0.877 sec)
# INFO:tensorflow:global_step/sec: 114.1
# INFO:tensorflow:loss = 37.19136, step = 44401 (0.876 sec)
# INFO:tensorflow:global_step/sec: 113.921
# INFO:tensorflow:loss = 32.811836, step = 44501 (0.878 sec)
# INFO:tensorflow:global_step/sec: 111.052
# INFO:tensorflow:loss = 38.200768, step = 44601 (0.900 sec)
# INFO:tensorflow:global_step/sec: 110.558
# INFO:tensorflow:loss = 45.524616, step = 44701 (0.904 sec)
# INFO:tensorflow:global_step/sec: 112.591
# INFO:tensorflow:loss = 34.609783, step = 44801 (0.889 sec)
# INFO:tensorflow:global_step/sec: 113.861
# INFO:tensorflow:loss = 58.5333, step = 44901 (0.878 sec)
# INFO:tensorflow:Saving checkpoints for 45000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:33:55Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-45000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:33:56
# INFO:tensorflow:Saving dict for global step 45000: global_step = 45000, loss = 32.33921
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45000: ./workspace/models/cooc2emb-01/model.ckpt-45000
# INFO:tensorflow:global_step/sec: 45.9605
# INFO:tensorflow:loss = 40.481865, step = 45001 (2.176 sec)
# INFO:tensorflow:global_step/sec: 113.127
# INFO:tensorflow:loss = 41.53682, step = 45101 (0.883 sec)
# INFO:tensorflow:global_step/sec: 119.951
# INFO:tensorflow:loss = 38.282784, step = 45201 (0.833 sec)
# INFO:tensorflow:global_step/sec: 121.915
# INFO:tensorflow:loss = 39.144447, step = 45301 (0.821 sec)
# INFO:tensorflow:global_step/sec: 108.973
# INFO:tensorflow:loss = 40.093716, step = 45401 (0.917 sec)
# INFO:tensorflow:global_step/sec: 109.106
# INFO:tensorflow:loss = 35.329346, step = 45501 (0.917 sec)
# INFO:tensorflow:global_step/sec: 120.114
# INFO:tensorflow:loss = 39.366676, step = 45601 (0.832 sec)
# INFO:tensorflow:global_step/sec: 136.072
# INFO:tensorflow:loss = 32.745605, step = 45701 (0.735 sec)
# INFO:tensorflow:global_step/sec: 119.888
# INFO:tensorflow:loss = 36.750557, step = 45801 (0.834 sec)
# INFO:tensorflow:global_step/sec: 122.434
# INFO:tensorflow:loss = 39.27853, step = 45901 (0.817 sec)
# INFO:tensorflow:Saving checkpoints for 46000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:34:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-46000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:34:05
# INFO:tensorflow:Saving dict for global step 46000: global_step = 46000, loss = 33.368282
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46000: ./workspace/models/cooc2emb-01/model.ckpt-46000
# INFO:tensorflow:global_step/sec: 52.3644
# INFO:tensorflow:loss = 32.427776, step = 46001 (1.910 sec)
# INFO:tensorflow:global_step/sec: 91.0781
# INFO:tensorflow:loss = 33.64977, step = 46101 (1.098 sec)
# INFO:tensorflow:global_step/sec: 90.0133
# INFO:tensorflow:loss = 51.502834, step = 46201 (1.110 sec)
# INFO:tensorflow:global_step/sec: 83.1566
# INFO:tensorflow:loss = 37.40036, step = 46301 (1.203 sec)
# INFO:tensorflow:global_step/sec: 99.7628
# INFO:tensorflow:loss = 41.558777, step = 46401 (1.002 sec)
# INFO:tensorflow:global_step/sec: 101.906
# INFO:tensorflow:loss = 39.541447, step = 46501 (0.982 sec)
# INFO:tensorflow:global_step/sec: 103.175
# INFO:tensorflow:loss = 38.198334, step = 46601 (0.969 sec)
# INFO:tensorflow:global_step/sec: 103.375
# INFO:tensorflow:loss = 39.278946, step = 46701 (0.968 sec)
# INFO:tensorflow:global_step/sec: 103.975
# INFO:tensorflow:loss = 34.408566, step = 46801 (0.962 sec)
# INFO:tensorflow:global_step/sec: 101.778
# INFO:tensorflow:loss = 37.18661, step = 46901 (0.982 sec)
# INFO:tensorflow:Saving checkpoints for 47000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:34:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-47000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:34:17
# INFO:tensorflow:Saving dict for global step 47000: global_step = 47000, loss = 31.9676
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 47000: ./workspace/models/cooc2emb-01/model.ckpt-47000
# INFO:tensorflow:global_step/sec: 45.958
# INFO:tensorflow:loss = 36.038593, step = 47001 (2.176 sec)
# INFO:tensorflow:global_step/sec: 114.892
# INFO:tensorflow:loss = 44.139194, step = 47101 (0.870 sec)
# INFO:tensorflow:global_step/sec: 112.642
# INFO:tensorflow:loss = 35.522896, step = 47201 (0.888 sec)
# INFO:tensorflow:global_step/sec: 115.985
# INFO:tensorflow:loss = 36.018597, step = 47301 (0.862 sec)
# INFO:tensorflow:global_step/sec: 117.348
# INFO:tensorflow:loss = 36.36285, step = 47401 (0.852 sec)
# INFO:tensorflow:global_step/sec: 112.951
# INFO:tensorflow:loss = 40.463707, step = 47501 (0.885 sec)
# INFO:tensorflow:global_step/sec: 112.951
# INFO:tensorflow:loss = 37.24968, step = 47601 (0.885 sec)
# INFO:tensorflow:global_step/sec: 114.857
# INFO:tensorflow:loss = 42.831745, step = 47701 (0.871 sec)
# INFO:tensorflow:global_step/sec: 113.59
# INFO:tensorflow:loss = 41.694958, step = 47801 (0.880 sec)
# INFO:tensorflow:global_step/sec: 114.667
# INFO:tensorflow:loss = 41.67531, step = 47901 (0.872 sec)
# INFO:tensorflow:Saving checkpoints for 48000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:34:26Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-48000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:34:27
# INFO:tensorflow:Saving dict for global step 48000: global_step = 48000, loss = 32.14336
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48000: ./workspace/models/cooc2emb-01/model.ckpt-48000
# INFO:tensorflow:global_step/sec: 51.3017
# INFO:tensorflow:loss = 39.708004, step = 48001 (1.949 sec)
# INFO:tensorflow:global_step/sec: 109.488
# INFO:tensorflow:loss = 38.865078, step = 48101 (0.913 sec)
# INFO:tensorflow:global_step/sec: 117.7
# INFO:tensorflow:loss = 33.667194, step = 48201 (0.850 sec)
# INFO:tensorflow:global_step/sec: 113.952
# INFO:tensorflow:loss = 30.141937, step = 48301 (0.877 sec)
# INFO:tensorflow:global_step/sec: 112.292
# INFO:tensorflow:loss = 31.266487, step = 48401 (0.891 sec)
# INFO:tensorflow:global_step/sec: 112.825
# INFO:tensorflow:loss = 39.823467, step = 48501 (0.886 sec)
# INFO:tensorflow:global_step/sec: 112.322
# INFO:tensorflow:loss = 38.02265, step = 48601 (0.890 sec)
# INFO:tensorflow:global_step/sec: 109.352
# INFO:tensorflow:loss = 40.105167, step = 48701 (0.915 sec)
# INFO:tensorflow:global_step/sec: 113.131
# INFO:tensorflow:loss = 32.140656, step = 48801 (0.884 sec)
# INFO:tensorflow:global_step/sec: 108.643
# INFO:tensorflow:loss = 46.356007, step = 48901 (0.921 sec)
# INFO:tensorflow:Saving checkpoints for 49000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:34:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-49000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:34:37
# INFO:tensorflow:Saving dict for global step 49000: global_step = 49000, loss = 32.071167
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 49000: ./workspace/models/cooc2emb-01/model.ckpt-49000
# INFO:tensorflow:global_step/sec: 39.6854
# INFO:tensorflow:loss = 33.67617, step = 49001 (2.519 sec)
# INFO:tensorflow:global_step/sec: 84.1848
# INFO:tensorflow:loss = 32.280666, step = 49101 (1.188 sec)
# INFO:tensorflow:global_step/sec: 105.546
# INFO:tensorflow:loss = 35.54435, step = 49201 (0.947 sec)
# INFO:tensorflow:global_step/sec: 120.865
# INFO:tensorflow:loss = 33.29363, step = 49301 (0.827 sec)
# INFO:tensorflow:global_step/sec: 120.684
# INFO:tensorflow:loss = 37.928875, step = 49401 (0.828 sec)
# INFO:tensorflow:global_step/sec: 105.115
# INFO:tensorflow:loss = 32.449604, step = 49501 (0.952 sec)
# INFO:tensorflow:global_step/sec: 103.642
# INFO:tensorflow:loss = 41.62351, step = 49601 (0.965 sec)
# INFO:tensorflow:global_step/sec: 103.851
# INFO:tensorflow:loss = 33.73361, step = 49701 (0.963 sec)
# INFO:tensorflow:global_step/sec: 103.6
# INFO:tensorflow:loss = 33.315372, step = 49801 (0.965 sec)
# INFO:tensorflow:global_step/sec: 93.2451
# INFO:tensorflow:loss = 32.29182, step = 49901 (1.073 sec)
# INFO:tensorflow:Saving checkpoints for 50000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-27T02:34:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-50000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-27-02:34:48
# INFO:tensorflow:Saving dict for global step 50000: global_step = 50000, loss = 32.80314
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50000: ./workspace/models/cooc2emb-01/model.ckpt-50000
# INFO:tensorflow:Loss for final step: 43.453007.
# .......................................
# Experiment finished at 01:34:48
#
# Experiment elapsed time: 545.102906 seconds

# %% [markdown]
# <img src="loss.png" width="600" height="600"/>

# %% [markdown]
# ## 8. Extract embeddings

# %%
def extract_embeddings():
    
    with tf.Session() as sess:
        saver = tf.train.import_meta_graph(os.path.join(model_dir, 'model.ckpt-{}.meta'.format(params.traning_steps)))
        saver.restore(sess, os.path.join(model_dir, 'model.ckpt-{}'.format(params.traning_steps)))
        graph = tf.get_default_graph()
        weights_tensor = graph.get_tensor_by_name('input_layer_1/item2_embedding/embedding_weights:0')
        weights = np.array(sess.run(weights_tensor))

    return weights

# %%
embeddings = extract_embeddings()
print(len(embeddings))
print(embeddings[0])
# Out:
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-50000
# 39195
# [-0.13656929 -0.08152047  0.22075112 -0.08936733 -0.25698322 -0.00394824
#  -0.01086133  0.00339999 -0.05643786  0.31033006 -0.05168191 -0.0300671
#   0.01123126  0.22518325  0.08868477 -0.00723081 -0.23095499  0.1212828
#   0.00407882 -0.06277223  0.04385442  0.17758256 -0.04478771  0.1413052
#  -0.23489681  0.04716527  0.13687761  0.05283307 -0.21793135 -0.04481634
#  -0.0370245   0.26175183]

# %%
vocab_path = os.path.join(COOC_DIR,'vocab.txt')
output_path = os.path.join(WORKSPACE,'embeddings.tsv')

def write_embeddings_to_tsv():
    with open(output_path, 'w') as out_f:
        with open(vocab_path) as vocab_f:
            for index, item in enumerate(vocab_f):
                embedding = embeddings[index]
                print('\t'.join([item.strip()] + [str(x) for x in embedding]), file=out_f)
                
write_embeddings_to_tsv()

# %%
# !head {output_path}
# Out:
# 3140490	-0.13656929	-0.08152047	0.22075112	-0.08936733	-0.25698322	-0.0039482424	-0.0108613325	0.003399993	-0.056437857	0.31033006	-0.051681906	-0.030067096	0.011231261	0.22518325	0.08868477	-0.00723081	-0.23095499	0.1212828	0.004078818	-0.06277223	0.043854423	0.17758256	-0.04478771	0.1413052	-0.23489681	0.047165267	0.13687761	0.052833073	-0.21793135	-0.044816345	-0.0370245	0.26175183
# 1174666	0.013843778	-0.27829817	-0.20373544	0.2345063	0.13281359	0.35718116	0.2595925	-0.012942535	-0.43445885	-0.19701801	0.34873945	-0.13490969	-0.40343148	0.073161945	0.40497667	-0.18959127	-0.3336594	0.13334094	0.0339188	-0.026429988	0.041407272	-0.0064272597	0.025063872	0.13757876	0.24225596	0.16204597	-0.06984314	-0.23530872	-0.0049144193	-0.15068308	-0.173307	0.18084238
# 4124042	0.20764865	0.08293786	-0.28368247	-0.20892073	0.057472624	0.15269594	0.6306407	-0.33692354	0.07106056	0.27661732	0.20864043	0.3706322	0.25792092	-0.14687982	0.20227244	-0.21646985	-0.2637002	0.33540612	-0.26416937	0.090075396	-0.24331671	-0.14356567	0.12342163	0.30456284	-0.43078604	0.17142278	-0.023616474	0.05122156	-0.23926522	-0.12552382	0.029526034	0.008887074
# 1176202	0.028052542	0.0044358033	0.01991756	0.03610339	-0.11406699	0.31224558	-0.020070434	0.24580543	-0.16577901	0.034190215	0.0075098462	-0.0037033616	-0.07884914	-0.12659357	-0.21156938	-0.1551096	0.08344189	0.16782433	-0.00040267335	-0.056752145	-0.05185374	0.14483643	-0.10537491	-0.09594965	-0.021212846	0.0831757	0.2511644	-0.066282265	-0.045584057	0.08891031	-0.055056613	0.19356032
# 4190858	-0.08447688	0.36294582	0.075147286	-0.36523017	0.20442022	0.15934542	0.2907542	-0.05345141	0.11031952	0.09656261	-0.125128	0.40021214	0.2984326	0.045708653	0.1770578	-0.29364434	-0.38627046	0.020399014	-0.015922865	0.101497814	-0.29718423	-0.056882318	0.059978873	0.20774005	-0.22976582	0.29894063	0.2135657	-0.08903673	-0.20934191	0.016632596	0.014961422	0.23036556
# 1110922	-0.038079966	0.116711825	0.10149417	-0.109429	-0.11853312	0.10727644	0.021821847	0.047738936	-0.33788982	-0.4481544	0.099815354	-0.20134021	-0.25212908	0.31727615	-0.05077985	0.18472916	-0.44626847	-0.13848864	-0.23933779	0.27392262	-0.24389179	-0.26272914	0.1736184	0.19617915	-0.19997902	0.14956939	0.1492794	0.2920245	-0.26707754	-0.013324908	0.019975048	-0.1308424
# 914570	0.31365842	-0.013960709	-0.2386306	0.08701006	0.06908094	-0.006929998	0.28032973	0.20846356	-0.3795045	0.042097565	0.24249786	-0.37662104	-0.11030186	0.27040234	-0.047579996	-0.097533494	0.08700015	0.22324926	-0.14681602	0.11757641	-0.07774833	0.019938257	0.157157	-0.1263651	0.22963792	0.17267588	0.047808588	0.12074635	-0.0056382013	0.28160363	-0.05406182	0.30495656
# 980106	-0.17240576	0.02278889	-0.3777997	0.019928778	0.038571287	-0.0584026	0.050939836	-0.036376532	-0.27886322	-0.11438538	0.19136381	0.2167813	-0.0069550476	-0.16042921	-0.2419523	-0.26454824	-0.68563545	0.15689978	-0.37147167	-0.087868124	-0.191555	0.38935533	-0.06951914	-0.07620521	-0.16543248	0.078090824	-0.044855017	0.18282251	-0.17825153	0.34513652	-0.49384427	-0.16277806
# 63370	0.1766649	-0.037191737	0.38912848	0.1486428	0.29284182	-0.19695371	0.030636419	-0.3619198	0.46615472	0.09690791	0.013154496	-0.41641018	-0.23573534	0.106596924	0.19408247	0.022893468	-0.045541536	0.027160801	0.0040978165	0.13535579	-0.45685488	0.55662245	0.07370594	0.13419682	-0.0015207118	0.009185916	0.5011587	-0.09722054	-0.3977062	-0.38483432	-0.18918149	-0.30305207
# 849802	0.08577131	-0.34955654	0.00933352	-0.12734956	-0.19915204	-0.3190022	0.24033993	-0.13246737	0.24979992	0.20218672	-0.18585669	-0.33520958	0.23085725	0.45409238	0.29079124	-0.20518741	-0.3271757	-0.5727342	-0.43059564	0.30086106	-0.17471196	0.0223288	-0.18066998	0.10847459	-0.37460452	0.22489478	0.30562264	0.23276958	-0.14578483	-0.29784843	-0.58411217	-0.24248049

# %% [markdown]
# ## 9. Export saved model as item-embedding lookup

# %%
def make_serving_input_receiver_fn():
    return tf.estimator.export.build_raw_serving_input_receiver_fn(
        {'item1': tf.placeholder(shape=[None], dtype=tf.string)}
    )

export_dir = os.path.join(model_dir, 'export')

if tf.gfile.Exists(export_dir):
    tf.gfile.DeleteRecursively(export_dir)
        
estimator.export_savedmodel(
    export_dir_base=export_dir,
    serving_input_receiver_fn=make_serving_input_receiver_fn()
)
# Out:
# WARNING:tensorflow:From <ipython-input-17-b3db3f31d5d7>:13: Estimator.export_savedmodel (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function has been renamed, use `export_saved_model` instead.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predictions', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-50000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets written to: ./workspace/models/cooc2emb-01/export/temp-b'1569548683'/assets
# INFO:tensorflow:SavedModel written to: ./workspace/models/cooc2emb-01/export/temp-b'1569548683'/saved_model.pb
# b'./workspace/models/cooc2emb-01/export/1569548683'

# %%
export_dir = os.path.join(model_dir, "export")
saved_model_dir = os.path.join(
    export_dir, [f for f in os.listdir(export_dir) if f.isdigit()][0])

print(saved_model_dir)

predictor_fn = tf.contrib.predictor.from_saved_model(
    export_dir = saved_model_dir,
)

output = predictor_fn({'item1': ['56430']})
print(output)
# Out:
# ./workspace/models/cooc2emb-01/export/1569548683
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/contrib/predictor/saved_model_predictor.py:153: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/export/1569548683/variables/variables
# {'output': array([[ 0.3423961 , -0.19566412,  0.18098071,  0.05013943, -0.42272353,
#          0.52389747,  0.41435465,  0.15142418, -0.26902387,  0.09728196,
#         -0.21906653, -0.21496587, -0.41003945,  0.07338266, -0.03579715,
#         -0.22150756, -0.6477336 ,  0.01614388, -0.5906194 ,  0.26229614,
#         -0.16781282,  0.15035729, -0.39879233,  0.12073212, -0.19785355,
#          0.1135684 , -0.22071159,  0.35201356,  0.18471922,  0.4401823 ,
#         -0.03474559, -0.20988251]], dtype=float32)}
