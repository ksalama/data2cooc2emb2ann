# %% [markdown]
# # Training Embeddings for Playlist Tracks
#
# This tutorial shows how to learn **item embeddings** from co-occurrence statistics.
#
# We use the following model architecture, a long with the conditional cost function used by the [Swivel](https://arxiv.org/pdf/1602.02215.pdf) algorithm.
#
# The learnt embeddings are then extracted from the model and saved as TSV file.
#
# <img src="cooc2emb.png" width="600" height="400"/>
#
# The following are the steps of this tutorial:
#
#
# 1. Define input data metadata
# 2. Implement data input function
# 3. Create feature columns
# 4. Create a custome estimator
# 5. Define the train and evaluate experiment
# 6. Set the experiment parameters
# 7. Run the experiment
# 8. Extract the learnt embeddings from the model
# 9. Export the saved model to serve as an embedding lookup
#
#
# <a href="https://colab.research.google.com/github/ksalama/data2cooc2emb2ann/blob/master/02-Training_Embeddings_for_Playlist_Tracks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Setup

# %%
# !pip install -r requirements.txt

# %%
import os
import math
import numpy as np
import tensorflow as tf
from tensorflow import data
from datetime import datetime

# %%
WORKSPACE = './workspace'
COOC_DIR = '{}/cooc'.format(WORKSPACE)
MODELS_DIR = '{}/models'.format(WORKSPACE)
SEED = 19831060

# %%
# !echo "Files:"
# !ls {COOC_DIR}/
# !echo ""

# !echo "info:"
# !head {COOC_DIR}/info.log
# !echo ""

# !echo "vocab file:"
# !head {COOC_DIR}/vocab.txt
# Out:
# Files:
# cooc-00000-of-00001.tfrecords info2.log
# info.log                      vocab.txt
#
# info:
# P: 2249477
# N: 486352
# max: 13.33242
# min: 2.2812
#
# vocab file:
# 3140490
# 1174666
# 4124042
# 1176202
# 4190858
# 1110922
# 914570
# 980106
# 63370
# 849802

# %% [markdown]
# ## 1.  Metadata

# %%
FEATURES_SCHEMA = {
    'item1': tf.FixedLenFeature(dtype=tf.string, shape=()),
    'item2': tf.FixedLenFeature(dtype=tf.string, shape=()),
    'score': tf.FixedLenFeature(dtype=tf.float32, shape=()),
    'weight': tf.FixedLenFeature(dtype=tf.float32, shape=()),
    'type': tf.FixedLenFeature(dtype=tf.string, shape=())
}

WEIGHT_FEATURE_NAME = 'weight'
TARGET_FEATURE_NAME = 'score'

# %% [markdown]
# ## 2.  Data Input Function

# %%
def make_input_fn(file_pattern, 
                  batch_size=128, num_epochs=1, mode=tf.estimator.ModeKeys.EVAL):

    def _input_fn():
        dataset = tf.data.experimental.make_batched_features_dataset(
            file_pattern,
            batch_size,
            features=FEATURES_SCHEMA,
            label_key=TARGET_FEATURE_NAME,
            reader=tf.data.TFRecordDataset,
            shuffle_buffer_size=batch_size * 10,
            reader_num_threads=1,
            parser_num_threads=2,
            num_epochs=num_epochs,
            shuffle=(mode==tf.estimator.ModeKeys.TRAIN),
            sloppy_ordering=True,
            drop_final_batch=True
        )
        return dataset
    
    return _input_fn

# %%
# tf.enable_eager_execution()

# DATA_FILES = "{}/cooc-*.tfrecords".format(COOC_DIR)

# dataset = make_input_fn(DATA_FILES, batch_size=5)()
# for features, target in dataset.take(1):
#     print()
#     print("Input features:")
#     for key in features:
#         print("-{}:{}".format(key, features[key]))
#     print("Targets:")
#     print(target)

# %% [markdown]
# ## 3. Feature Columns

# %%
def create_feature_columns(embedding_size, vocab1_file, vocab2_file):
    
    feature_columns = []
    
    feature_columns.append(
        tf.feature_column.embedding_column(
            tf.feature_column.categorical_column_with_vocabulary_file(
                key='item1', 
                vocabulary_file=vocab1_file
            ), 
            embedding_size
        )
    )
    
    feature_columns.append(
        tf.feature_column.embedding_column(
            tf.feature_column.categorical_column_with_vocabulary_file(
                key='item2', 
                vocabulary_file=vocab2_file
            ), 
            embedding_size
        )
    )
        
    return feature_columns

# %% [markdown]
# ## 4.  Custom Estimator

# %%
def compute_loss(labels, predictions, weights, types):
    
    def _positive_sample_cost(errors, weights):
        return 0.5 * weights * tf.math.square(errors)
    
    def _negative_sample_cost(errors, weights):
        return weights * tf.math.log(1 + tf.exp(errors))
    
    errors = predictions - labels
    
    p_loss = _positive_sample_cost(errors, weights)
    n_loss = _negative_sample_cost(errors, weights)
    loss = tf.where(types == 'P', p_loss, n_loss)
    
    return tf.reduce_sum(loss)

def model_fn(features, labels, mode, params):
    
    items1 = features['item1']
    feature_columns = create_feature_columns(
        params.embedding_size, params.vocab1_file, params.vocab2_file)
    
    # TODO: add bias to the input_layer
    item1_layer = tf.feature_column.input_layer(
        features={'item1': items1}, feature_columns=[feature_columns[0]])
    
    if mode != tf.estimator.ModeKeys.PREDICT:
        items2 = features['item2']
        item2_layer = tf.feature_column.input_layer(
            features={'item2': items2}, feature_columns=[feature_columns[1]])
        
        dot_product = tf.keras.layers.Dot(axes=1)([item1_layer, item2_layer])
        logits = (params.max_value - params.min_value) * tf.sigmoid(dot_product) + params.min_value 

    predictions = None
    export_outputs = None
    loss = None
    train_op = None

    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions =  item1_layer
        export_outputs = {'predictions': tf.estimator.export.PredictOutput(predictions)}
    else:
        types = features['type']
        weights = features[WEIGHT_FEATURE_NAME]
        
#         loss = tf.losses.mean_squared_error(
#             labels=labels, 
#             predictions=tf.squeeze(logits),
#             weights=weights
#         )

        loss = compute_loss(
            labels=labels, 
            predictions=tf.squeeze(logits), 
            weights=weights, 
            types=types
        )
        
        train_op=tf.train.AdamOptimizer(params.learning_rate).minimize(
            loss=loss, global_step=tf.train.get_global_step())
    
    return tf.estimator.EstimatorSpec(
        mode=mode,
        predictions=predictions,
        export_outputs=export_outputs,
        loss=loss,
        train_op=train_op
    )


def create_estimator(params, run_config):
    
    estimator = tf.estimator.Estimator(
        model_fn,
        params=params,
        config=run_config
    )
    
    return estimator

# %% [markdown]
# ## 5. Experiment

# %%
def run_experiment(params, run_config):
    
    train_data_files = params.train_data_files
    eval_data_files = params.eval_data_files
    
    # TrainSpec ####################################
    train_input_fn = make_input_fn(
        train_data_files,
        batch_size=params.batch_size,
        num_epochs=None,
        mode=tf.estimator.ModeKeys.TRAIN
    )
    
    train_spec = tf.estimator.TrainSpec(
        input_fn = train_input_fn,
        max_steps=params.traning_steps
    )
    ###############################################    
    
    # EvalSpec ####################################
    eval_input_fn = make_input_fn(
        eval_data_files,
        num_epochs=None, #1
        batch_size=params.batch_size,
    )

    eval_spec = tf.estimator.EvalSpec(
        name=datetime.utcnow().strftime("%H%M%S"),
        input_fn = eval_input_fn,
        steps=params.eval_steps,
        start_delay_secs=0,
        throttle_secs=params.eval_throttle_secs
    )
    ###############################################

    tf.logging.set_verbosity(tf.logging.INFO)
    
    if tf.gfile.Exists(run_config.model_dir):
        print("Removing previous artefacts...")
        tf.gfile.DeleteRecursively(run_config.model_dir)
            
    print("")
    estimator = create_estimator(params, run_config)
    print("")
    
    time_start = datetime.utcnow() 
    print("Experiment started at {}".format(time_start.strftime("%H:%M:%S")))
    print(".......................................") 

    tf.estimator.train_and_evaluate(
        estimator=estimator,
        train_spec=train_spec, 
        eval_spec=eval_spec
    )

    time_end = datetime.utcnow() 
    print(".......................................")
    print("Experiment finished at {}".format(time_end.strftime("%H:%M:%S")))
    print("")
    time_elapsed = time_end - time_start
    print("Experiment elapsed time: {} seconds".format(time_elapsed.total_seconds()))
    
    return estimator

# %% [markdown]
# ## 6. Parameters

# %%
MODEL_NAME = 'cooc2emb-01'
model_dir = os.path.join(MODELS_DIR, MODEL_NAME)
info_file = os.path.join(COOC_DIR, 'info.log')
min_value = 15
max_value = -5

info_map = {}

if os.path.exists(info_file):
    try:
        with open(info_file) as f:
            for line in f.readlines():
                key, value = line.split(":")
                info_map[key] = float(value)
        min_value = math.floor(info_map['min'])
        max_value = math.ceil(info_map['max'])
    except: pass
    
class HParams():
    pass

params  = HParams()
params.train_data_files = "{}/cooc-*.tfrecords".format(COOC_DIR)
params.eval_data_files = "{}/cooc-*.tfrecords".format(COOC_DIR)
params.vocab1_file = os.path.join(COOC_DIR,'vocab.txt')
params.vocab2_file = os.path.join(COOC_DIR,'vocab.txt')
params.embedding_size = 32
params.min_value = min_value
params.max_value = max_value
params.batch_size = 265
params.traning_steps = 50000
params.learning_rate = 0.0005
params.eval_steps = 1
params.eval_throttle_secs = 0

print(vars(params))

run_config = tf.estimator.RunConfig(
    tf_random_seed=SEED,
    save_checkpoints_steps=1000,
    keep_checkpoint_max=3,
    model_dir=model_dir,
)
# Out:
# {'train_data_files': './workspace/cooc/cooc-*.tfrecords', 'eval_data_files': './workspace/cooc/cooc-*.tfrecords', 'vocab1_file': './workspace/cooc/vocab.txt', 'vocab2_file': './workspace/cooc/vocab.txt', 'embedding_size': 32, 'min_value': 2, 'max_value': 14, 'batch_size': 265, 'traning_steps': 50000, 'learning_rate': 0.0005, 'eval_steps': 1, 'eval_throttle_secs': 0}

# %% [markdown]
# ## 7. Run

# %%
estimator = run_experiment(params, run_config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './workspace/models/cooc2emb-01', '_tf_random_seed': 19831060, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x12dd7d278>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
#
# Experiment started at 19:02:38
# .......................................
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:loss = 159.35309, step = 1
# INFO:tensorflow:global_step/sec: 95.6625
# INFO:tensorflow:loss = 213.2619, step = 101 (1.048 sec)
# INFO:tensorflow:global_step/sec: 111.126
# INFO:tensorflow:loss = 149.46344, step = 201 (0.898 sec)
# INFO:tensorflow:global_step/sec: 127.592
# INFO:tensorflow:loss = 453.29068, step = 301 (0.784 sec)
# INFO:tensorflow:global_step/sec: 127.046
# INFO:tensorflow:loss = 246.77722, step = 401 (0.788 sec)
# INFO:tensorflow:global_step/sec: 112.659
# INFO:tensorflow:loss = 227.56117, step = 501 (0.887 sec)
# INFO:tensorflow:global_step/sec: 120.794
# INFO:tensorflow:loss = 366.48212, step = 601 (0.829 sec)
# INFO:tensorflow:global_step/sec: 122.334
# INFO:tensorflow:loss = 177.5117, step = 701 (0.817 sec)
# INFO:tensorflow:global_step/sec: 105.442
# INFO:tensorflow:loss = 252.28075, step = 801 (0.949 sec)
# INFO:tensorflow:global_step/sec: 94.9638
# INFO:tensorflow:loss = 222.66974, step = 901 (1.053 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:02:50Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:02:51
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 207.46225
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./workspace/models/cooc2emb-01/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 41.8591
# INFO:tensorflow:loss = 195.17894, step = 1001 (2.390 sec)
# INFO:tensorflow:global_step/sec: 111.522
# INFO:tensorflow:loss = 257.74625, step = 1101 (0.895 sec)
# INFO:tensorflow:global_step/sec: 106.098
# INFO:tensorflow:loss = 258.17554, step = 1201 (0.943 sec)
# INFO:tensorflow:global_step/sec: 110.728
# INFO:tensorflow:loss = 193.50385, step = 1301 (0.903 sec)
# INFO:tensorflow:global_step/sec: 109.422
# INFO:tensorflow:loss = 217.4227, step = 1401 (0.913 sec)
# INFO:tensorflow:global_step/sec: 117.566
# INFO:tensorflow:loss = 233.81021, step = 1501 (0.851 sec)
# INFO:tensorflow:global_step/sec: 126.087
# INFO:tensorflow:loss = 156.65369, step = 1601 (0.793 sec)
# INFO:tensorflow:global_step/sec: 124.397
# INFO:tensorflow:loss = 254.23898, step = 1701 (0.804 sec)
# INFO:tensorflow:global_step/sec: 126.488
# INFO:tensorflow:loss = 181.20068, step = 1801 (0.791 sec)
# INFO:tensorflow:global_step/sec: 124.536
# INFO:tensorflow:loss = 171.20587, step = 1901 (0.803 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:03:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:03:00
# INFO:tensorflow:Saving dict for global step 2000: global_step = 2000, loss = 207.87106
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: ./workspace/models/cooc2emb-01/model.ckpt-2000
# INFO:tensorflow:global_step/sec: 52.7824
# INFO:tensorflow:loss = 312.6568, step = 2001 (1.898 sec)
# INFO:tensorflow:global_step/sec: 105.159
# INFO:tensorflow:loss = 186.93063, step = 2101 (0.948 sec)
# INFO:tensorflow:global_step/sec: 113.796
# INFO:tensorflow:loss = 217.95438, step = 2201 (0.879 sec)
# INFO:tensorflow:global_step/sec: 125.696
# INFO:tensorflow:loss = 260.5613, step = 2301 (0.796 sec)
# INFO:tensorflow:global_step/sec: 128.869
# INFO:tensorflow:loss = 169.85008, step = 2401 (0.776 sec)
# INFO:tensorflow:global_step/sec: 116.528
# INFO:tensorflow:loss = 235.08105, step = 2501 (0.859 sec)
# INFO:tensorflow:global_step/sec: 115.691
# INFO:tensorflow:loss = 178.3451, step = 2601 (0.864 sec)
# INFO:tensorflow:global_step/sec: 121.98
# INFO:tensorflow:loss = 209.54198, step = 2701 (0.820 sec)
# INFO:tensorflow:global_step/sec: 130.158
# INFO:tensorflow:loss = 228.95447, step = 2801 (0.768 sec)
# INFO:tensorflow:global_step/sec: 119.45
# INFO:tensorflow:loss = 165.19992, step = 2901 (0.837 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into ./workspace/models/cooc2emb-01/model.ckpt.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:03:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:03:10
# INFO:tensorflow:Saving dict for global step 3000: global_step = 3000, loss = 207.46689
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: ./workspace/models/cooc2emb-01/model.ckpt-3000
# INFO:tensorflow:global_step/sec: 48.3319
# INFO:tensorflow:loss = 231.64137, step = 3001 (2.069 sec)
# INFO:tensorflow:global_step/sec: 113.068
# INFO:tensorflow:loss = 239.54126, step = 3101 (0.884 sec)
# INFO:tensorflow:global_step/sec: 121.623
# INFO:tensorflow:loss = 229.84946, step = 3201 (0.822 sec)
# INFO:tensorflow:global_step/sec: 118.773
# INFO:tensorflow:loss = 194.0849, step = 3301 (0.842 sec)
# INFO:tensorflow:global_step/sec: 122.637
# INFO:tensorflow:loss = 213.67398, step = 3401 (0.815 sec)
# INFO:tensorflow:global_step/sec: 122.263
# INFO:tensorflow:loss = 224.94846, step = 3501 (0.818 sec)
# INFO:tensorflow:global_step/sec: 120.809
# INFO:tensorflow:loss = 212.71466, step = 3601 (0.828 sec)
# INFO:tensorflow:global_step/sec: 121.954
# INFO:tensorflow:loss = 231.46684, step = 3701 (0.820 sec)
# INFO:tensorflow:global_step/sec: 121.156
# INFO:tensorflow:loss = 381.93808, step = 3801 (0.825 sec)
# INFO:tensorflow:global_step/sec: 123.153
# INFO:tensorflow:loss = 198.2857, step = 3901 (0.812 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:03:19Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:03:19
# INFO:tensorflow:Saving dict for global step 4000: global_step = 4000, loss = 209.09358
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: ./workspace/models/cooc2emb-01/model.ckpt-4000
# INFO:tensorflow:global_step/sec: 54.355
# INFO:tensorflow:loss = 201.11287, step = 4001 (1.840 sec)
# INFO:tensorflow:global_step/sec: 121.183
# INFO:tensorflow:loss = 157.74806, step = 4101 (0.825 sec)
# INFO:tensorflow:global_step/sec: 132.044
# INFO:tensorflow:loss = 205.05206, step = 4201 (0.757 sec)
# INFO:tensorflow:global_step/sec: 131.652
# INFO:tensorflow:loss = 177.50493, step = 4301 (0.760 sec)
# INFO:tensorflow:global_step/sec: 128.279
# INFO:tensorflow:loss = 216.57748, step = 4401 (0.779 sec)
# INFO:tensorflow:global_step/sec: 122.975
# INFO:tensorflow:loss = 200.1335, step = 4501 (0.813 sec)
# INFO:tensorflow:global_step/sec: 129.72
# INFO:tensorflow:loss = 202.289, step = 4601 (0.771 sec)
# INFO:tensorflow:global_step/sec: 129.812
# INFO:tensorflow:loss = 321.47644, step = 4701 (0.771 sec)
# INFO:tensorflow:global_step/sec: 127.85
# INFO:tensorflow:loss = 256.7675, step = 4801 (0.782 sec)
# INFO:tensorflow:global_step/sec: 131.2
# INFO:tensorflow:loss = 233.16702, step = 4901 (0.762 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:03:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:03:28
# INFO:tensorflow:Saving dict for global step 5000: global_step = 5000, loss = 208.40488
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: ./workspace/models/cooc2emb-01/model.ckpt-5000
# INFO:tensorflow:global_step/sec: 51.5623
# INFO:tensorflow:loss = 215.00482, step = 5001 (1.940 sec)
# INFO:tensorflow:global_step/sec: 110.278
# INFO:tensorflow:loss = 228.73398, step = 5101 (0.907 sec)
# INFO:tensorflow:global_step/sec: 115.279
# INFO:tensorflow:loss = 146.88734, step = 5201 (0.867 sec)
# INFO:tensorflow:global_step/sec: 115.08
# INFO:tensorflow:loss = 223.717, step = 5301 (0.869 sec)
# INFO:tensorflow:global_step/sec: 111.475
# INFO:tensorflow:loss = 183.93953, step = 5401 (0.897 sec)
# INFO:tensorflow:global_step/sec: 118.24
# INFO:tensorflow:loss = 240.51714, step = 5501 (0.846 sec)
# INFO:tensorflow:global_step/sec: 127.719
# INFO:tensorflow:loss = 193.9824, step = 5601 (0.784 sec)
# INFO:tensorflow:global_step/sec: 125.08
# INFO:tensorflow:loss = 225.27705, step = 5701 (0.799 sec)
# INFO:tensorflow:global_step/sec: 129.088
# INFO:tensorflow:loss = 175.11926, step = 5801 (0.775 sec)
# INFO:tensorflow:global_step/sec: 113.798
# INFO:tensorflow:loss = 183.68767, step = 5901 (0.879 sec)
# INFO:tensorflow:Saving checkpoints for 6000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:03:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:03:38
# INFO:tensorflow:Saving dict for global step 6000: global_step = 6000, loss = 208.57545
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: ./workspace/models/cooc2emb-01/model.ckpt-6000
# INFO:tensorflow:global_step/sec: 51.2942
# INFO:tensorflow:loss = 226.52849, step = 6001 (1.950 sec)
# INFO:tensorflow:global_step/sec: 103.096
# INFO:tensorflow:loss = 249.45703, step = 6101 (0.969 sec)
# INFO:tensorflow:global_step/sec: 119.328
# INFO:tensorflow:loss = 166.27847, step = 6201 (0.838 sec)
# INFO:tensorflow:global_step/sec: 123.579
# INFO:tensorflow:loss = 307.5921, step = 6301 (0.809 sec)
# INFO:tensorflow:global_step/sec: 103.77
# INFO:tensorflow:loss = 177.04556, step = 6401 (0.964 sec)
# INFO:tensorflow:global_step/sec: 109.539
# INFO:tensorflow:loss = 278.55032, step = 6501 (0.913 sec)
# INFO:tensorflow:global_step/sec: 106.951
# INFO:tensorflow:loss = 221.36201, step = 6601 (0.935 sec)
# INFO:tensorflow:global_step/sec: 121.656
# INFO:tensorflow:loss = 194.14867, step = 6701 (0.822 sec)
# INFO:tensorflow:global_step/sec: 120.383
# INFO:tensorflow:loss = 175.89194, step = 6801 (0.831 sec)
# INFO:tensorflow:global_step/sec: 118.184
# INFO:tensorflow:loss = 308.78305, step = 6901 (0.846 sec)
# INFO:tensorflow:Saving checkpoints for 7000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:03:47Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:03:48
# INFO:tensorflow:Saving dict for global step 7000: global_step = 7000, loss = 208.71376
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7000: ./workspace/models/cooc2emb-01/model.ckpt-7000
# INFO:tensorflow:global_step/sec: 51.2363
# INFO:tensorflow:loss = 126.58723, step = 7001 (1.953 sec)
# INFO:tensorflow:global_step/sec: 109.428
# INFO:tensorflow:loss = 203.24863, step = 7101 (0.913 sec)
# INFO:tensorflow:global_step/sec: 121.095
# INFO:tensorflow:loss = 224.10477, step = 7201 (0.826 sec)
# INFO:tensorflow:global_step/sec: 131.111
# INFO:tensorflow:loss = 146.8731, step = 7301 (0.763 sec)
# INFO:tensorflow:global_step/sec: 129.951
# INFO:tensorflow:loss = 175.83353, step = 7401 (0.770 sec)
# INFO:tensorflow:global_step/sec: 131.237
# INFO:tensorflow:loss = 162.24089, step = 7501 (0.762 sec)
# INFO:tensorflow:global_step/sec: 129
# INFO:tensorflow:loss = 171.27118, step = 7601 (0.775 sec)
# INFO:tensorflow:global_step/sec: 117.551
# INFO:tensorflow:loss = 263.03635, step = 7701 (0.851 sec)
# INFO:tensorflow:global_step/sec: 123.199
# INFO:tensorflow:loss = 144.85307, step = 7801 (0.812 sec)
# INFO:tensorflow:global_step/sec: 132.24
# INFO:tensorflow:loss = 170.26524, step = 7901 (0.756 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:03:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:03:57
# INFO:tensorflow:Saving dict for global step 8000: global_step = 8000, loss = 210.93016
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: ./workspace/models/cooc2emb-01/model.ckpt-8000
# INFO:tensorflow:global_step/sec: 51.1525
# INFO:tensorflow:loss = 217.88022, step = 8001 (1.955 sec)
# INFO:tensorflow:global_step/sec: 115.912
# INFO:tensorflow:loss = 199.0332, step = 8101 (0.862 sec)
# INFO:tensorflow:global_step/sec: 115.078
# INFO:tensorflow:loss = 117.86704, step = 8201 (0.869 sec)
# INFO:tensorflow:global_step/sec: 113.268
# INFO:tensorflow:loss = 215.09819, step = 8301 (0.882 sec)
# INFO:tensorflow:global_step/sec: 121.96
# INFO:tensorflow:loss = 233.31767, step = 8401 (0.820 sec)
# INFO:tensorflow:global_step/sec: 126.654
# INFO:tensorflow:loss = 212.77574, step = 8501 (0.789 sec)
# INFO:tensorflow:global_step/sec: 130.306
# INFO:tensorflow:loss = 212.4197, step = 8601 (0.768 sec)
# INFO:tensorflow:global_step/sec: 126.296
# INFO:tensorflow:loss = 240.51207, step = 8701 (0.792 sec)
# INFO:tensorflow:global_step/sec: 115.664
# INFO:tensorflow:loss = 186.14142, step = 8801 (0.865 sec)
# INFO:tensorflow:global_step/sec: 107.934
# INFO:tensorflow:loss = 209.4485, step = 8901 (0.927 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:04:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:04:06
# INFO:tensorflow:Saving dict for global step 9000: global_step = 9000, loss = 212.08762
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: ./workspace/models/cooc2emb-01/model.ckpt-9000
# INFO:tensorflow:global_step/sec: 49.9742
# INFO:tensorflow:loss = 158.06355, step = 9001 (2.002 sec)
# INFO:tensorflow:global_step/sec: 122.725
# INFO:tensorflow:loss = 184.11682, step = 9101 (0.813 sec)
# INFO:tensorflow:global_step/sec: 132.317
# INFO:tensorflow:loss = 223.45538, step = 9201 (0.756 sec)
# INFO:tensorflow:global_step/sec: 126.186
# INFO:tensorflow:loss = 191.21518, step = 9301 (0.793 sec)
# INFO:tensorflow:global_step/sec: 129.257
# INFO:tensorflow:loss = 186.7617, step = 9401 (0.773 sec)
# INFO:tensorflow:global_step/sec: 131.266
# INFO:tensorflow:loss = 182.49107, step = 9501 (0.762 sec)
# INFO:tensorflow:global_step/sec: 132.635
# INFO:tensorflow:loss = 220.35275, step = 9601 (0.754 sec)
# INFO:tensorflow:global_step/sec: 130.447
# INFO:tensorflow:loss = 159.33919, step = 9701 (0.767 sec)
# INFO:tensorflow:global_step/sec: 127.319
# INFO:tensorflow:loss = 210.60805, step = 9801 (0.785 sec)
# INFO:tensorflow:global_step/sec: 130.942
# INFO:tensorflow:loss = 230.41296, step = 9901 (0.765 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:04:15Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:04:15
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, loss = 215.84523
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: ./workspace/models/cooc2emb-01/model.ckpt-10000
# INFO:tensorflow:global_step/sec: 51.4247
# INFO:tensorflow:loss = 174.1067, step = 10001 (1.947 sec)
# INFO:tensorflow:global_step/sec: 118.736
# INFO:tensorflow:loss = 151.50853, step = 10101 (0.839 sec)
# INFO:tensorflow:global_step/sec: 127.964
# INFO:tensorflow:loss = 259.64246, step = 10201 (0.781 sec)
# INFO:tensorflow:global_step/sec: 112.221
# INFO:tensorflow:loss = 299.18222, step = 10301 (0.891 sec)
# INFO:tensorflow:global_step/sec: 112.999
# INFO:tensorflow:loss = 227.87651, step = 10401 (0.885 sec)
# INFO:tensorflow:global_step/sec: 117.388
# INFO:tensorflow:loss = 142.8643, step = 10501 (0.852 sec)
# INFO:tensorflow:global_step/sec: 116.1
# INFO:tensorflow:loss = 209.58044, step = 10601 (0.861 sec)
# INFO:tensorflow:global_step/sec: 117.585
# INFO:tensorflow:loss = 163.22035, step = 10701 (0.850 sec)
# INFO:tensorflow:global_step/sec: 115.288
# INFO:tensorflow:loss = 162.2433, step = 10801 (0.867 sec)
# INFO:tensorflow:global_step/sec: 115.387
# INFO:tensorflow:loss = 221.52094, step = 10901 (0.866 sec)
# INFO:tensorflow:Saving checkpoints for 11000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:04:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-11000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:04:25
# INFO:tensorflow:Saving dict for global step 11000: global_step = 11000, loss = 167.13309
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11000: ./workspace/models/cooc2emb-01/model.ckpt-11000
# INFO:tensorflow:global_step/sec: 47.7313
# INFO:tensorflow:loss = 167.06326, step = 11001 (2.096 sec)
# INFO:tensorflow:global_step/sec: 108.515
# INFO:tensorflow:loss = 261.6709, step = 11101 (0.920 sec)
# INFO:tensorflow:global_step/sec: 114.574
# INFO:tensorflow:loss = 240.81813, step = 11201 (0.873 sec)
# INFO:tensorflow:global_step/sec: 117.264
# INFO:tensorflow:loss = 201.26619, step = 11301 (0.853 sec)
# INFO:tensorflow:global_step/sec: 117.613
# INFO:tensorflow:loss = 142.66801, step = 11401 (0.850 sec)
# INFO:tensorflow:global_step/sec: 116.552
# INFO:tensorflow:loss = 257.04593, step = 11501 (0.858 sec)
# INFO:tensorflow:global_step/sec: 132.665
# INFO:tensorflow:loss = 129.23802, step = 11601 (0.753 sec)
# INFO:tensorflow:global_step/sec: 123.619
# INFO:tensorflow:loss = 212.71115, step = 11701 (0.809 sec)
# INFO:tensorflow:global_step/sec: 116.654
# INFO:tensorflow:loss = 147.43509, step = 11801 (0.857 sec)
# INFO:tensorflow:global_step/sec: 116.755
# INFO:tensorflow:loss = 147.03365, step = 11901 (0.856 sec)
# INFO:tensorflow:Saving checkpoints for 12000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:04:34Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-12000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:04:35
# INFO:tensorflow:Saving dict for global step 12000: global_step = 12000, loss = 161.91684
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12000: ./workspace/models/cooc2emb-01/model.ckpt-12000
# INFO:tensorflow:global_step/sec: 48.4614
# INFO:tensorflow:loss = 142.82527, step = 12001 (2.064 sec)
# INFO:tensorflow:global_step/sec: 110.428
# INFO:tensorflow:loss = 261.02454, step = 12101 (0.905 sec)
# INFO:tensorflow:global_step/sec: 115.97
# INFO:tensorflow:loss = 152.58313, step = 12201 (0.862 sec)
# INFO:tensorflow:global_step/sec: 115.251
# INFO:tensorflow:loss = 306.4797, step = 12301 (0.868 sec)
# INFO:tensorflow:global_step/sec: 117.111
# INFO:tensorflow:loss = 150.10341, step = 12401 (0.854 sec)
# INFO:tensorflow:global_step/sec: 113.572
# INFO:tensorflow:loss = 306.48184, step = 12501 (0.881 sec)
# INFO:tensorflow:global_step/sec: 115.278
# INFO:tensorflow:loss = 159.98514, step = 12601 (0.867 sec)
# INFO:tensorflow:global_step/sec: 112.587
# INFO:tensorflow:loss = 116.23571, step = 12701 (0.888 sec)
# INFO:tensorflow:global_step/sec: 113.966
# INFO:tensorflow:loss = 189.10649, step = 12801 (0.878 sec)
# INFO:tensorflow:global_step/sec: 115.79
# INFO:tensorflow:loss = 127.15163, step = 12901 (0.863 sec)
# INFO:tensorflow:Saving checkpoints for 13000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:04:44Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:04:45
# INFO:tensorflow:Saving dict for global step 13000: global_step = 13000, loss = 154.51625
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13000: ./workspace/models/cooc2emb-01/model.ckpt-13000
# INFO:tensorflow:global_step/sec: 48.7087
# INFO:tensorflow:loss = 324.70575, step = 13001 (2.053 sec)
# INFO:tensorflow:global_step/sec: 115.644
# INFO:tensorflow:loss = 125.978035, step = 13101 (0.865 sec)
# INFO:tensorflow:global_step/sec: 104.978
# INFO:tensorflow:loss = 163.3188, step = 13201 (0.953 sec)
# INFO:tensorflow:global_step/sec: 111.923
# INFO:tensorflow:loss = 192.55103, step = 13301 (0.894 sec)
# INFO:tensorflow:global_step/sec: 103.319
# INFO:tensorflow:loss = 113.12377, step = 13401 (0.968 sec)
# INFO:tensorflow:global_step/sec: 101.59
# INFO:tensorflow:loss = 201.0084, step = 13501 (0.985 sec)
# INFO:tensorflow:global_step/sec: 102.798
# INFO:tensorflow:loss = 198.99608, step = 13601 (0.972 sec)
# INFO:tensorflow:global_step/sec: 101.997
# INFO:tensorflow:loss = 143.5568, step = 13701 (0.980 sec)
# INFO:tensorflow:global_step/sec: 115.426
# INFO:tensorflow:loss = 157.8294, step = 13801 (0.867 sec)
# INFO:tensorflow:global_step/sec: 106.691
# INFO:tensorflow:loss = 193.5107, step = 13901 (0.937 sec)
# INFO:tensorflow:Saving checkpoints for 14000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:04:55Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:04:55
# INFO:tensorflow:Saving dict for global step 14000: global_step = 14000, loss = 145.99045
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14000: ./workspace/models/cooc2emb-01/model.ckpt-14000
# INFO:tensorflow:global_step/sec: 47.1122
# INFO:tensorflow:loss = 198.40785, step = 14001 (2.123 sec)
# INFO:tensorflow:global_step/sec: 122.361
# INFO:tensorflow:loss = 107.043274, step = 14101 (0.818 sec)
# INFO:tensorflow:global_step/sec: 131.2
# INFO:tensorflow:loss = 158.71332, step = 14201 (0.761 sec)
# INFO:tensorflow:global_step/sec: 130.661
# INFO:tensorflow:loss = 216.76912, step = 14301 (0.765 sec)
# INFO:tensorflow:global_step/sec: 128.491
# INFO:tensorflow:loss = 172.87112, step = 14401 (0.778 sec)
# INFO:tensorflow:global_step/sec: 116.22
# INFO:tensorflow:loss = 110.671555, step = 14501 (0.860 sec)
# INFO:tensorflow:global_step/sec: 115.574
# INFO:tensorflow:loss = 127.604095, step = 14601 (0.865 sec)
# INFO:tensorflow:global_step/sec: 117.035
# INFO:tensorflow:loss = 194.98393, step = 14701 (0.854 sec)
# INFO:tensorflow:global_step/sec: 123.073
# INFO:tensorflow:loss = 155.8022, step = 14801 (0.812 sec)
# INFO:tensorflow:global_step/sec: 131.896
# INFO:tensorflow:loss = 130.3294, step = 14901 (0.758 sec)
# INFO:tensorflow:Saving checkpoints for 15000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:05:04Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:05:04
# INFO:tensorflow:Saving dict for global step 15000: global_step = 15000, loss = 137.20885
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15000: ./workspace/models/cooc2emb-01/model.ckpt-15000
# INFO:tensorflow:global_step/sec: 53.6109
# INFO:tensorflow:loss = 220.28937, step = 15001 (1.866 sec)
# INFO:tensorflow:global_step/sec: 123.148
# INFO:tensorflow:loss = 124.6447, step = 15101 (0.811 sec)
# INFO:tensorflow:global_step/sec: 132.333
# INFO:tensorflow:loss = 102.39223, step = 15201 (0.755 sec)
# INFO:tensorflow:global_step/sec: 130.032
# INFO:tensorflow:loss = 89.27941, step = 15301 (0.769 sec)
# INFO:tensorflow:global_step/sec: 133.029
# INFO:tensorflow:loss = 132.35013, step = 15401 (0.752 sec)
# INFO:tensorflow:global_step/sec: 130.943
# INFO:tensorflow:loss = 93.633965, step = 15501 (0.764 sec)
# INFO:tensorflow:global_step/sec: 122.702
# INFO:tensorflow:loss = 104.82235, step = 15601 (0.815 sec)
# INFO:tensorflow:global_step/sec: 117.221
# INFO:tensorflow:loss = 245.27763, step = 15701 (0.853 sec)
# INFO:tensorflow:global_step/sec: 117.689
# INFO:tensorflow:loss = 152.45248, step = 15801 (0.850 sec)
# INFO:tensorflow:global_step/sec: 118.329
# INFO:tensorflow:loss = 120.06522, step = 15901 (0.845 sec)
# INFO:tensorflow:Saving checkpoints for 16000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:05:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-16000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:05:14
# INFO:tensorflow:Saving dict for global step 16000: global_step = 16000, loss = 129.17528
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16000: ./workspace/models/cooc2emb-01/model.ckpt-16000
# INFO:tensorflow:global_step/sec: 48.3512
# INFO:tensorflow:loss = 103.31078, step = 16001 (2.070 sec)
# INFO:tensorflow:global_step/sec: 120.138
# INFO:tensorflow:loss = 140.83032, step = 16101 (0.831 sec)
# INFO:tensorflow:global_step/sec: 116.28
# INFO:tensorflow:loss = 127.8064, step = 16201 (0.860 sec)
# INFO:tensorflow:global_step/sec: 117.502
# INFO:tensorflow:loss = 103.93265, step = 16301 (0.851 sec)
# INFO:tensorflow:global_step/sec: 116.547
# INFO:tensorflow:loss = 146.22835, step = 16401 (0.858 sec)
# INFO:tensorflow:global_step/sec: 115.405
# INFO:tensorflow:loss = 70.73563, step = 16501 (0.867 sec)
# INFO:tensorflow:global_step/sec: 115.389
# INFO:tensorflow:loss = 92.54684, step = 16601 (0.866 sec)
# INFO:tensorflow:global_step/sec: 116.212
# INFO:tensorflow:loss = 92.333084, step = 16701 (0.860 sec)
# INFO:tensorflow:global_step/sec: 116.122
# INFO:tensorflow:loss = 96.858315, step = 16801 (0.861 sec)
# INFO:tensorflow:global_step/sec: 114.811
# INFO:tensorflow:loss = 110.21439, step = 16901 (0.871 sec)
# INFO:tensorflow:Saving checkpoints for 17000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:05:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-17000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:05:23
# INFO:tensorflow:Saving dict for global step 17000: global_step = 17000, loss = 120.109695
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17000: ./workspace/models/cooc2emb-01/model.ckpt-17000
# INFO:tensorflow:global_step/sec: 52.6028
# INFO:tensorflow:loss = 168.89995, step = 17001 (1.902 sec)
# INFO:tensorflow:global_step/sec: 119.982
# INFO:tensorflow:loss = 102.55412, step = 17101 (0.832 sec)
# INFO:tensorflow:global_step/sec: 131.978
# INFO:tensorflow:loss = 121.17509, step = 17201 (0.758 sec)
# INFO:tensorflow:global_step/sec: 131.248
# INFO:tensorflow:loss = 100.55637, step = 17301 (0.762 sec)
# INFO:tensorflow:global_step/sec: 130.841
# INFO:tensorflow:loss = 101.457825, step = 17401 (0.764 sec)
# INFO:tensorflow:global_step/sec: 130.784
# INFO:tensorflow:loss = 156.76262, step = 17501 (0.765 sec)
# INFO:tensorflow:global_step/sec: 133.012
# INFO:tensorflow:loss = 98.89266, step = 17601 (0.752 sec)
# INFO:tensorflow:global_step/sec: 131.166
# INFO:tensorflow:loss = 93.47428, step = 17701 (0.762 sec)
# INFO:tensorflow:global_step/sec: 122.882
# INFO:tensorflow:loss = 79.42298, step = 17801 (0.814 sec)
# INFO:tensorflow:global_step/sec: 125.13
# INFO:tensorflow:loss = 64.44637, step = 17901 (0.799 sec)
# INFO:tensorflow:Saving checkpoints for 18000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:05:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-18000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:05:32
# INFO:tensorflow:Saving dict for global step 18000: global_step = 18000, loss = 112.70111
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18000: ./workspace/models/cooc2emb-01/model.ckpt-18000
# INFO:tensorflow:global_step/sec: 47.4828
# INFO:tensorflow:loss = 218.07686, step = 18001 (2.106 sec)
# INFO:tensorflow:global_step/sec: 102.155
# INFO:tensorflow:loss = 111.60154, step = 18101 (0.979 sec)
# INFO:tensorflow:global_step/sec: 99.318
# INFO:tensorflow:loss = 73.7074, step = 18201 (1.007 sec)
# INFO:tensorflow:global_step/sec: 104.612
# INFO:tensorflow:loss = 79.656425, step = 18301 (0.956 sec)
# INFO:tensorflow:global_step/sec: 103.222
# INFO:tensorflow:loss = 62.305515, step = 18401 (0.969 sec)
# INFO:tensorflow:global_step/sec: 101.847
# INFO:tensorflow:loss = 88.93393, step = 18501 (0.982 sec)
# INFO:tensorflow:global_step/sec: 104.551
# INFO:tensorflow:loss = 82.494545, step = 18601 (0.957 sec)
# INFO:tensorflow:global_step/sec: 101.225
# INFO:tensorflow:loss = 105.16354, step = 18701 (0.988 sec)
# INFO:tensorflow:global_step/sec: 105.202
# INFO:tensorflow:loss = 91.96976, step = 18801 (0.951 sec)
# INFO:tensorflow:global_step/sec: 104.878
# INFO:tensorflow:loss = 75.828026, step = 18901 (0.954 sec)
# INFO:tensorflow:Saving checkpoints for 19000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:05:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-19000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:05:43
# INFO:tensorflow:Saving dict for global step 19000: global_step = 19000, loss = 106.58977
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 19000: ./workspace/models/cooc2emb-01/model.ckpt-19000
# INFO:tensorflow:global_step/sec: 46.4682
# INFO:tensorflow:loss = 100.34781, step = 19001 (2.152 sec)
# INFO:tensorflow:global_step/sec: 114.643
# INFO:tensorflow:loss = 55.541286, step = 19101 (0.872 sec)
# INFO:tensorflow:global_step/sec: 111.429
# INFO:tensorflow:loss = 60.613125, step = 19201 (0.897 sec)
# INFO:tensorflow:global_step/sec: 128.765
# INFO:tensorflow:loss = 104.84202, step = 19301 (0.777 sec)
# INFO:tensorflow:global_step/sec: 118.056
# INFO:tensorflow:loss = 71.510124, step = 19401 (0.848 sec)
# INFO:tensorflow:global_step/sec: 107.482
# INFO:tensorflow:loss = 99.960594, step = 19501 (0.930 sec)
# INFO:tensorflow:global_step/sec: 107.08
# INFO:tensorflow:loss = 69.829155, step = 19601 (0.934 sec)
# INFO:tensorflow:global_step/sec: 108.675
# INFO:tensorflow:loss = 93.70269, step = 19701 (0.920 sec)
# INFO:tensorflow:global_step/sec: 107.765
# INFO:tensorflow:loss = 74.388, step = 19801 (0.928 sec)
# INFO:tensorflow:global_step/sec: 108.347
# INFO:tensorflow:loss = 99.80997, step = 19901 (0.922 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:05:53Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:05:53
# INFO:tensorflow:Saving dict for global step 20000: global_step = 20000, loss = 101.24137
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: ./workspace/models/cooc2emb-01/model.ckpt-20000
# INFO:tensorflow:global_step/sec: 52.7663
# INFO:tensorflow:loss = 76.72036, step = 20001 (1.896 sec)
# INFO:tensorflow:global_step/sec: 113.736
# INFO:tensorflow:loss = 63.347065, step = 20101 (0.878 sec)
# INFO:tensorflow:global_step/sec: 121.594
# INFO:tensorflow:loss = 61.799072, step = 20201 (0.822 sec)
# INFO:tensorflow:global_step/sec: 121.729
# INFO:tensorflow:loss = 73.84619, step = 20301 (0.822 sec)
# INFO:tensorflow:global_step/sec: 110.767
# INFO:tensorflow:loss = 71.85986, step = 20401 (0.903 sec)
# INFO:tensorflow:global_step/sec: 105.26
# INFO:tensorflow:loss = 70.78618, step = 20501 (0.950 sec)
# INFO:tensorflow:global_step/sec: 96.0513
# INFO:tensorflow:loss = 62.879192, step = 20601 (1.043 sec)
# INFO:tensorflow:global_step/sec: 98.8821
# INFO:tensorflow:loss = 82.82383, step = 20701 (1.011 sec)
# INFO:tensorflow:global_step/sec: 98.8541
# INFO:tensorflow:loss = 44.201145, step = 20801 (1.010 sec)
# INFO:tensorflow:global_step/sec: 95.1227
# INFO:tensorflow:loss = 76.698715, step = 20901 (1.053 sec)
# INFO:tensorflow:Saving checkpoints for 21000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:06:04Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-21000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:06:04
# INFO:tensorflow:Saving dict for global step 21000: global_step = 21000, loss = 29.74913
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 21000: ./workspace/models/cooc2emb-01/model.ckpt-21000
# INFO:tensorflow:global_step/sec: 42.0047
# INFO:tensorflow:loss = 37.76803, step = 21001 (2.380 sec)
# INFO:tensorflow:global_step/sec: 101.566
# INFO:tensorflow:loss = 47.35503, step = 21101 (0.983 sec)
# INFO:tensorflow:global_step/sec: 102.582
# INFO:tensorflow:loss = 57.954872, step = 21201 (0.975 sec)
# INFO:tensorflow:global_step/sec: 104.951
# INFO:tensorflow:loss = 39.775944, step = 21301 (0.959 sec)
# INFO:tensorflow:global_step/sec: 108.498
# INFO:tensorflow:loss = 81.60442, step = 21401 (0.915 sec)
# INFO:tensorflow:global_step/sec: 109.467
# INFO:tensorflow:loss = 62.66434, step = 21501 (0.914 sec)
# INFO:tensorflow:global_step/sec: 114.082
# INFO:tensorflow:loss = 38.56661, step = 21601 (0.876 sec)
# INFO:tensorflow:global_step/sec: 116.683
# INFO:tensorflow:loss = 54.684235, step = 21701 (0.857 sec)
# INFO:tensorflow:global_step/sec: 117.108
# INFO:tensorflow:loss = 110.56422, step = 21801 (0.854 sec)
# INFO:tensorflow:global_step/sec: 118.831
# INFO:tensorflow:loss = 44.687202, step = 21901 (0.842 sec)
# INFO:tensorflow:Saving checkpoints for 22000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:06:14Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-22000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:06:14
# INFO:tensorflow:Saving dict for global step 22000: global_step = 22000, loss = 26.328798
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 22000: ./workspace/models/cooc2emb-01/model.ckpt-22000
# INFO:tensorflow:global_step/sec: 49.5084
# INFO:tensorflow:loss = 34.22978, step = 22001 (2.020 sec)
# INFO:tensorflow:global_step/sec: 110.64
# INFO:tensorflow:loss = 61.16197, step = 22101 (0.904 sec)
# INFO:tensorflow:global_step/sec: 116.844
# INFO:tensorflow:loss = 44.997623, step = 22201 (0.855 sec)
# INFO:tensorflow:global_step/sec: 112.931
# INFO:tensorflow:loss = 43.620365, step = 22301 (0.886 sec)
# INFO:tensorflow:global_step/sec: 117.324
# INFO:tensorflow:loss = 43.03385, step = 22401 (0.852 sec)
# INFO:tensorflow:global_step/sec: 116.454
# INFO:tensorflow:loss = 29.822945, step = 22501 (0.859 sec)
# INFO:tensorflow:global_step/sec: 117.523
# INFO:tensorflow:loss = 44.571438, step = 22601 (0.851 sec)
# INFO:tensorflow:global_step/sec: 118.634
# INFO:tensorflow:loss = 37.6521, step = 22701 (0.843 sec)
# INFO:tensorflow:global_step/sec: 118.063
# INFO:tensorflow:loss = 38.929375, step = 22801 (0.847 sec)
# INFO:tensorflow:global_step/sec: 115.528
# INFO:tensorflow:loss = 59.298355, step = 22901 (0.866 sec)
# INFO:tensorflow:Saving checkpoints for 23000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# ...
# INFO:tensorflow:global_step/sec: 110.459
# INFO:tensorflow:loss = 1.5645425, step = 42301 (0.906 sec)
# INFO:tensorflow:global_step/sec: 111.18
# INFO:tensorflow:loss = 2.4566798, step = 42401 (0.900 sec)
# INFO:tensorflow:global_step/sec: 117.807
# INFO:tensorflow:loss = 2.4425933, step = 42501 (0.849 sec)
# INFO:tensorflow:global_step/sec: 118.781
# INFO:tensorflow:loss = 1.8707012, step = 42601 (0.842 sec)
# INFO:tensorflow:global_step/sec: 127.77
# INFO:tensorflow:loss = 1.7330694, step = 42701 (0.784 sec)
# INFO:tensorflow:global_step/sec: 81.3354
# INFO:tensorflow:loss = 1.8788009, step = 42801 (1.229 sec)
# INFO:tensorflow:global_step/sec: 108.279
# INFO:tensorflow:loss = 2.0416179, step = 42901 (0.924 sec)
# INFO:tensorflow:Saving checkpoints for 43000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:09:47Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-43000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:09:48
# INFO:tensorflow:Saving dict for global step 43000: global_step = 43000, loss = 1.2447677
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 43000: ./workspace/models/cooc2emb-01/model.ckpt-43000
# INFO:tensorflow:global_step/sec: 48.776
# INFO:tensorflow:loss = 2.1874661, step = 43001 (2.051 sec)
# INFO:tensorflow:global_step/sec: 107.044
# INFO:tensorflow:loss = 1.478217, step = 43101 (0.934 sec)
# INFO:tensorflow:global_step/sec: 112.782
# INFO:tensorflow:loss = 1.2863625, step = 43201 (0.886 sec)
# INFO:tensorflow:global_step/sec: 110.221
# INFO:tensorflow:loss = 3.198644, step = 43301 (0.907 sec)
# INFO:tensorflow:global_step/sec: 114.398
# INFO:tensorflow:loss = 1.4821606, step = 43401 (0.874 sec)
# INFO:tensorflow:global_step/sec: 101.197
# INFO:tensorflow:loss = 1.9250195, step = 43501 (0.988 sec)
# INFO:tensorflow:global_step/sec: 94.9598
# INFO:tensorflow:loss = 1.9153377, step = 43601 (1.053 sec)
# INFO:tensorflow:global_step/sec: 112.529
# INFO:tensorflow:loss = 1.598685, step = 43701 (0.888 sec)
# INFO:tensorflow:global_step/sec: 95.3327
# INFO:tensorflow:loss = 2.0256188, step = 43801 (1.049 sec)
# INFO:tensorflow:global_step/sec: 110.951
# INFO:tensorflow:loss = 2.1093667, step = 43901 (0.901 sec)
# INFO:tensorflow:Saving checkpoints for 44000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:09:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:09:58
# INFO:tensorflow:Saving dict for global step 44000: global_step = 44000, loss = 1.228081
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: ./workspace/models/cooc2emb-01/model.ckpt-44000
# INFO:tensorflow:global_step/sec: 56.0836
# INFO:tensorflow:loss = 1.9463851, step = 44001 (1.783 sec)
# INFO:tensorflow:global_step/sec: 76.2156
# INFO:tensorflow:loss = 2.4886556, step = 44101 (1.312 sec)
# INFO:tensorflow:global_step/sec: 93.4003
# INFO:tensorflow:loss = 3.5987377, step = 44201 (1.072 sec)
# INFO:tensorflow:global_step/sec: 70.2242
# INFO:tensorflow:loss = 2.0854924, step = 44301 (1.423 sec)
# INFO:tensorflow:global_step/sec: 88.5653
# INFO:tensorflow:loss = 2.0369785, step = 44401 (1.129 sec)
# INFO:tensorflow:global_step/sec: 113.748
# INFO:tensorflow:loss = 2.664149, step = 44501 (0.879 sec)
# INFO:tensorflow:global_step/sec: 107.014
# INFO:tensorflow:loss = 1.180393, step = 44601 (0.935 sec)
# INFO:tensorflow:global_step/sec: 100.521
# INFO:tensorflow:loss = 1.7239628, step = 44701 (0.995 sec)
# INFO:tensorflow:global_step/sec: 88.4468
# INFO:tensorflow:loss = 1.8185942, step = 44801 (1.131 sec)
# INFO:tensorflow:global_step/sec: 99.237
# INFO:tensorflow:loss = 1.4670107, step = 44901 (1.008 sec)
# INFO:tensorflow:Saving checkpoints for 45000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:10:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-45000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:10:11
# INFO:tensorflow:Saving dict for global step 45000: global_step = 45000, loss = 1.2142804
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45000: ./workspace/models/cooc2emb-01/model.ckpt-45000
# INFO:tensorflow:global_step/sec: 35.2581
# INFO:tensorflow:loss = 1.6724194, step = 45001 (2.837 sec)
# INFO:tensorflow:global_step/sec: 79.4003
# INFO:tensorflow:loss = 3.715233, step = 45101 (1.259 sec)
# INFO:tensorflow:global_step/sec: 107.241
# INFO:tensorflow:loss = 3.0396693, step = 45201 (0.932 sec)
# INFO:tensorflow:global_step/sec: 95.0017
# INFO:tensorflow:loss = 1.9099541, step = 45301 (1.053 sec)
# INFO:tensorflow:global_step/sec: 109.318
# INFO:tensorflow:loss = 2.7516518, step = 45401 (0.915 sec)
# INFO:tensorflow:global_step/sec: 111.686
# INFO:tensorflow:loss = 1.7080389, step = 45501 (0.895 sec)
# INFO:tensorflow:global_step/sec: 110.033
# INFO:tensorflow:loss = 1.4051639, step = 45601 (0.909 sec)
# INFO:tensorflow:global_step/sec: 118.062
# INFO:tensorflow:loss = 1.8286713, step = 45701 (0.848 sec)
# INFO:tensorflow:global_step/sec: 102.424
# INFO:tensorflow:loss = 1.8867172, step = 45801 (0.976 sec)
# INFO:tensorflow:global_step/sec: 112.149
# INFO:tensorflow:loss = 0.9794486, step = 45901 (0.892 sec)
# INFO:tensorflow:Saving checkpoints for 46000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:10:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-46000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:10:21
# INFO:tensorflow:Saving dict for global step 46000: global_step = 46000, loss = 1.2016624
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46000: ./workspace/models/cooc2emb-01/model.ckpt-46000
# INFO:tensorflow:global_step/sec: 49.057
# INFO:tensorflow:loss = 4.3809123, step = 46001 (2.039 sec)
# INFO:tensorflow:global_step/sec: 77.6037
# INFO:tensorflow:loss = 2.8062935, step = 46101 (1.288 sec)
# INFO:tensorflow:global_step/sec: 68.5721
# INFO:tensorflow:loss = 1.8977907, step = 46201 (1.459 sec)
# INFO:tensorflow:global_step/sec: 77.8015
# INFO:tensorflow:loss = 1.5346011, step = 46301 (1.285 sec)
# INFO:tensorflow:global_step/sec: 73.3
# INFO:tensorflow:loss = 2.2976255, step = 46401 (1.365 sec)
# INFO:tensorflow:global_step/sec: 110.859
# INFO:tensorflow:loss = 1.7107052, step = 46501 (0.902 sec)
# INFO:tensorflow:global_step/sec: 103.386
# INFO:tensorflow:loss = 2.7176557, step = 46601 (0.967 sec)
# INFO:tensorflow:global_step/sec: 91.2713
# INFO:tensorflow:loss = 1.3156722, step = 46701 (1.096 sec)
# INFO:tensorflow:global_step/sec: 93.6487
# INFO:tensorflow:loss = 1.8671103, step = 46801 (1.068 sec)
# INFO:tensorflow:global_step/sec: 110.929
# INFO:tensorflow:loss = 2.0232952, step = 46901 (0.901 sec)
# INFO:tensorflow:Saving checkpoints for 47000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:10:34Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-47000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:10:34
# INFO:tensorflow:Saving dict for global step 47000: global_step = 47000, loss = 1.1920537
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 47000: ./workspace/models/cooc2emb-01/model.ckpt-47000
# INFO:tensorflow:global_step/sec: 39.7464
# INFO:tensorflow:loss = 2.5168297, step = 47001 (2.517 sec)
# INFO:tensorflow:global_step/sec: 95.7664
# INFO:tensorflow:loss = 1.8986119, step = 47101 (1.044 sec)
# INFO:tensorflow:global_step/sec: 74.2319
# INFO:tensorflow:loss = 0.7443742, step = 47201 (1.347 sec)
# INFO:tensorflow:global_step/sec: 87.339
# INFO:tensorflow:loss = 1.7566651, step = 47301 (1.145 sec)
# INFO:tensorflow:global_step/sec: 100.764
# INFO:tensorflow:loss = 1.4925989, step = 47401 (0.992 sec)
# INFO:tensorflow:global_step/sec: 93.9121
# INFO:tensorflow:loss = 1.1386359, step = 47501 (1.066 sec)
# INFO:tensorflow:global_step/sec: 99.8382
# INFO:tensorflow:loss = 4.219945, step = 47601 (1.003 sec)
# INFO:tensorflow:global_step/sec: 103.645
# INFO:tensorflow:loss = 0.868945, step = 47701 (0.963 sec)
# INFO:tensorflow:global_step/sec: 85.1217
# INFO:tensorflow:loss = 2.1794643, step = 47801 (1.177 sec)
# INFO:tensorflow:global_step/sec: 71.5026
# INFO:tensorflow:loss = 1.18096, step = 47901 (1.397 sec)
# INFO:tensorflow:Saving checkpoints for 48000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:10:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-48000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:10:47
# INFO:tensorflow:Saving dict for global step 48000: global_step = 48000, loss = 1.1819469
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48000: ./workspace/models/cooc2emb-01/model.ckpt-48000
# INFO:tensorflow:global_step/sec: 38.3537
# INFO:tensorflow:loss = 1.9475672, step = 48001 (2.607 sec)
# INFO:tensorflow:global_step/sec: 66.8592
# INFO:tensorflow:loss = 1.3619143, step = 48101 (1.495 sec)
# INFO:tensorflow:global_step/sec: 65.8507
# INFO:tensorflow:loss = 2.3992617, step = 48201 (1.519 sec)
# INFO:tensorflow:global_step/sec: 76.0328
# INFO:tensorflow:loss = 4.3166556, step = 48301 (1.315 sec)
# INFO:tensorflow:global_step/sec: 68.5563
# INFO:tensorflow:loss = 1.0231736, step = 48401 (1.460 sec)
# INFO:tensorflow:global_step/sec: 73.9979
# INFO:tensorflow:loss = 1.8855752, step = 48501 (1.354 sec)
# INFO:tensorflow:global_step/sec: 69.3592
# INFO:tensorflow:loss = 1.5179805, step = 48601 (1.438 sec)
# INFO:tensorflow:global_step/sec: 66.9975
# INFO:tensorflow:loss = 1.0876136, step = 48701 (1.493 sec)
# INFO:tensorflow:global_step/sec: 88.2581
# INFO:tensorflow:loss = 0.8464193, step = 48801 (1.133 sec)
# INFO:tensorflow:global_step/sec: 86.787
# INFO:tensorflow:loss = 1.3110478, step = 48901 (1.153 sec)
# INFO:tensorflow:Saving checkpoints for 49000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:11:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-49000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:11:02
# INFO:tensorflow:Saving dict for global step 49000: global_step = 49000, loss = 1.1723249
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 49000: ./workspace/models/cooc2emb-01/model.ckpt-49000
# INFO:tensorflow:global_step/sec: 32.7942
# INFO:tensorflow:loss = 4.2472973, step = 49001 (3.048 sec)
# INFO:tensorflow:global_step/sec: 78.5023
# INFO:tensorflow:loss = 1.2502836, step = 49101 (1.274 sec)
# INFO:tensorflow:global_step/sec: 80.1851
# INFO:tensorflow:loss = 1.2488506, step = 49201 (1.246 sec)
# INFO:tensorflow:global_step/sec: 87.7274
# INFO:tensorflow:loss = 2.439986, step = 49301 (1.140 sec)
# INFO:tensorflow:global_step/sec: 91.6865
# INFO:tensorflow:loss = 1.3493389, step = 49401 (1.092 sec)
# INFO:tensorflow:global_step/sec: 87.7107
# INFO:tensorflow:loss = 0.7437781, step = 49501 (1.140 sec)
# INFO:tensorflow:global_step/sec: 77.5623
# INFO:tensorflow:loss = 1.854312, step = 49601 (1.289 sec)
# INFO:tensorflow:global_step/sec: 91.1393
# INFO:tensorflow:loss = 2.0271685, step = 49701 (1.097 sec)
# INFO:tensorflow:global_step/sec: 115.453
# INFO:tensorflow:loss = 1.7406492, step = 49801 (0.867 sec)
# INFO:tensorflow:global_step/sec: 100.636
# INFO:tensorflow:loss = 1.1839925, step = 49901 (0.993 sec)
# INFO:tensorflow:Saving checkpoints for 50000 into ./workspace/models/cooc2emb-01/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-09-26T20:11:14Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-50000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finished evaluation at 2019-09-26-20:11:15
# INFO:tensorflow:Saving dict for global step 50000: global_step = 50000, loss = 1.1639881
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50000: ./workspace/models/cooc2emb-01/model.ckpt-50000
# INFO:tensorflow:Loss for final step: 2.971315.
# .......................................
# Experiment finished at 19:11:15
#
# Experiment elapsed time: 517.112996 seconds

# %% [markdown]
# <img src="loss.png" width="600" height="400"/>

# %% [markdown]
# ## 8. Extract embeddings

# %%
def extract_embeddings():
    
    with tf.Session() as sess:
        saver = tf.train.import_meta_graph(os.path.join(model_dir, 'model.ckpt-{}.meta'.format(params.traning_steps)))
        saver.restore(sess, os.path.join(model_dir, 'model.ckpt-{}'.format(params.traning_steps)))
        graph = tf.get_default_graph()
        weights_tensor = graph.get_tensor_by_name('input_layer_1/item2_embedding/embedding_weights:0')
        weights = np.array(sess.run(weights_tensor))

    return weights

# %%
embeddings = extract_embeddings()
print(len(embeddings))
print(embeddings[0])
# Out:
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-50000
# 39195
# [ 0.15476117 -0.22028464  0.5029515   0.08361941  0.01662882  0.20098309
#   0.02289918  0.30216253 -0.145497    0.54127693 -0.03063745  0.09072404
#  -0.02569989  0.23658207 -0.14141276 -0.18085752 -0.02175103  0.18658789
#   0.3142943  -0.1167581  -0.24651718  0.3543694  -0.05479481 -0.04769993
#  -0.26089588  0.03063611  0.573654   -0.03463669 -0.44228756  0.09221426
#  -0.26482692  0.33758983]

# %%
vocab_path = os.path.join(COOC_DIR,'vocab.txt')
output_path = os.path.join(WORKSPACE,'embeddings.tsv')

def write_embeddings_to_tsv():
    with open(output_path, 'w') as out_f:
        with open(vocab_path) as vocab_f:
            for index, item in enumerate(vocab_f):
                embedding = embeddings[index]
                print('\t'.join([item.strip()] + [str(x) for x in embedding]), file=out_f)
                
write_embeddings_to_tsv()

# %%
# !head {output_path}
# Out:
# 3140490	0.15476117	-0.22028464	0.5029515	0.08361941	0.016628817	0.20098309	0.022899184	0.30216253	-0.145497	0.54127693	-0.030637449	0.090724036	-0.02569989	0.23658207	-0.14141276	-0.18085752	-0.02175103	0.18658789	0.3142943	-0.1167581	-0.24651718	0.3543694	-0.05479481	-0.047699932	-0.26089588	0.030636115	0.573654	-0.034636687	-0.44228756	0.092214264	-0.26482692	0.33758983
# 1174666	-0.17831224	-0.42993304	-0.0839878	0.29915634	0.03356193	0.31322202	-0.042066813	-0.051706303	-0.37178084	0.14129065	0.080491856	-0.06896243	-0.30283847	0.026865078	0.13399	-0.18424447	-0.091643706	0.030812453	-0.025963543	-0.20992623	0.087224096	-0.013801538	-0.27795655	-0.021292964	0.0033754818	-0.022404164	0.21593037	-0.14364143	-0.0361688	0.117180236	-0.09234736	0.14837469
# 4124042	0.18704276	-0.08447446	0.062283743	0.085570484	0.040571995	0.22841203	0.18322597	0.019756168	0.06682893	0.29113013	-0.11036961	0.51800394	-0.12652962	0.055464357	-0.09905837	-0.38206455	0.2718967	0.23420781	0.072959624	-0.25740308	-0.21231253	0.027478922	-0.25742635	-0.0619688	-0.36919057	-0.30173525	0.1327098	-0.3244755	-0.31591454	0.29335058	0.079018675	0.089456275
# 1176202	0.23756051	-0.15284579	0.15357672	0.36362562	0.190962	0.53040385	-0.29105943	0.4177087	-0.3701599	0.13835754	-0.20051272	0.32900938	-0.11981596	0.037261542	-0.2939429	-0.4003653	0.2848979	0.47390887	0.23196001	-0.29594633	-0.23655497	0.27233824	-0.36258134	-0.3136232	-0.07312718	0.07702181	0.44898048	-0.2362938	-0.29985625	0.17188117	-0.14968863	0.4632868
# 4190858	0.23127057	-0.038936008	0.17111316	0.06864763	0.25983164	0.15450066	-0.23768829	0.28063694	-0.10117853	0.26061848	-0.035488177	0.5160187	-0.05019999	0.29552424	0.038143698	-0.48484254	-0.027304256	0.12304927	0.2601276	-0.19858591	-0.2647166	0.39915505	-0.34151554	-0.13082099	-0.28700048	-0.07833944	0.26434225	-0.2324649	-0.5219168	-0.008048732	0.12332294	0.3077273
# 1110922	-0.1424547	-0.0827389	0.23742321	0.08999608	-0.19102046	0.24286367	-0.12836997	0.056610856	-0.23373441	-0.2982125	-0.036101893	-0.0018889948	-0.052682403	0.14994368	0.053656615	0.38417268	-0.2962215	-0.12962435	-0.16693301	0.074474916	-0.15747002	-0.09504348	-0.025774254	0.14144473	-0.27236483	0.06316191	0.013350696	0.09257712	-0.21241993	-0.06796961	-0.17946865	-0.1218905
# 914570	0.32291922	-0.44689637	0.21758397	0.45439366	0.106108785	0.15285408	-0.21955396	0.33991858	-0.31866094	0.19799839	0.12002056	0.00061614567	-0.39514768	0.14000578	-0.28851694	-0.012238052	0.33851245	0.28632593	0.30431697	-0.28086725	-0.27506778	0.2540976	-0.061097756	-0.35009396	0.052332472	0.017619906	0.3726393	-0.33058983	-0.12398154	0.43696246	-0.23366156	0.33203873
# 980106	-0.014764194	-0.2171277	0.01967085	0.40212035	-0.16944693	0.18005851	-0.39872023	0.25440124	-0.4586314	0.1346427	-0.14428326	0.25505027	0.07058468	0.057876796	-0.4920196	-0.3490769	-0.048201308	0.125092	-0.06613344	-0.35850784	-0.32575735	0.36913696	-0.2800541	-0.32152858	0.043020584	-0.2299568	0.25018695	-0.1466294	-0.36901945	0.46693477	-0.34623364	-0.032407567
# 63370	0.12717709	-0.50683105	0.17691928	0.37264147	0.007114533	0.035833273	-0.3006811	0.1387947	0.035322417	0.071606204	-0.12222665	0.009738667	0.0023425084	0.33480635	-0.27089563	-0.27181694	0.34762892	-0.12109788	0.2012517	-0.029604424	-0.24767606	0.4489378	-0.328343	-0.14445674	-0.030327823	-0.16665299	0.3639688	-0.3088746	-0.28986934	0.11245142	-0.1448093	0.00019165564
# 849802	-0.14484377	-0.29649028	0.1123304	-0.067631006	0.011059308	-0.09694631	0.29229248	-0.10947653	0.07078201	0.04227387	-0.23487583	0.12228205	0.071154	0.27106595	0.13838759	-0.18796836	0.11978857	-0.18755373	-0.015718218	0.011812104	-0.09885799	0.11088576	-0.22892612	-0.08530757	-0.2956806	0.13402517	0.38149616	-0.0074416944	-0.32394233	-0.060075365	-0.35010552	-0.202343

# %% [markdown]
# ## 9. Export saved model as item-embedding lookup

# %%
def make_serving_input_receiver_fn():
    return tf.estimator.export.build_raw_serving_input_receiver_fn(
        {'item1': tf.placeholder(shape=[None], dtype=tf.string)}
    )

export_dir = os.path.join(model_dir, 'export')

if tf.gfile.Exists(export_dir):
    tf.gfile.DeleteRecursively(export_dir)
        
estimator.export_savedmodel(
    export_dir_base=export_dir,
    serving_input_receiver_fn=make_serving_input_receiver_fn()
)
# Out:
# WARNING:tensorflow:From <ipython-input-24-b3db3f31d5d7>:13: Estimator.export_savedmodel (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function has been renamed, use `export_saved_model` instead.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:vocabulary_size = 39195 in item1 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:vocabulary_size = 39195 in item2 is inferred from the number of elements in the vocabulary_file ./workspace/cooc/vocab.txt.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predictions', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/model.ckpt-50000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets written to: ./workspace/models/cooc2emb-01/export/temp-b'1569525078'/assets
# INFO:tensorflow:SavedModel written to: ./workspace/models/cooc2emb-01/export/temp-b'1569525078'/saved_model.pb
# b'./workspace/models/cooc2emb-01/export/1569525078'

# %%
export_dir = os.path.join(model_dir, "export")
saved_model_dir = os.path.join(
    export_dir, [f for f in os.listdir(export_dir) if f.isdigit()][0])

print(saved_model_dir)

predictor_fn = tf.contrib.predictor.from_saved_model(
    export_dir = saved_model_dir,
)

output = predictor_fn({'item1': ['56430']})
print(output)
# Out:
# ./workspace/models/cooc2emb-01/export/1569525078
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /Users/khalidsalama/Technology/GoogleCloud/GCP-Github/kfp-components/google/tf_hub/tabular2cooc/venv/lib/python3.6/site-packages/tensorflow/contrib/predictor/saved_model_predictor.py:153: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# INFO:tensorflow:Restoring parameters from ./workspace/models/cooc2emb-01/export/1569525078/variables/variables
# {'output': array([[-0.4528324 ,  0.30650634, -0.6440126 , -0.3283458 , -0.04250643,
#         -0.19180682,  0.04424484, -0.2118475 ,  0.47607163, -0.12407511,
#          0.0424717 , -0.11153425, -0.17166878, -0.31536543,  0.12750565,
#         -0.10377702, -0.42000312, -0.17117882,  0.09818746,  0.40603584,
#          0.18366164, -0.43566263,  0.07607986,  0.21299475,  0.2541353 ,
#          0.1096778 , -0.05498634,  0.30682164,  0.48747426, -0.13290294,
#         -0.00922322, -0.20080437]], dtype=float32)}
